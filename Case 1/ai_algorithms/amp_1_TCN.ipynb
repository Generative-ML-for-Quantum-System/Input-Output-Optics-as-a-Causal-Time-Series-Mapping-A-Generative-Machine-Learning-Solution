# %% [markdown]
# ### Case 1: Modeling the input $\to$ output relation for the transverse Ising model (Hamiltonian below) based on a pre-calculated data set for $\mathcal{D}(A = 1)$ of the input $h^{i}(t) = A \sin\left(\omega^{(i)} t \right)$,
# $\mathcal{D}(A) = \left\{  \mathbf{h}^{(i)} \to \mathbf{Y}^{(i)} \right\}_{i=1}^n$
#
# \begin{equation}
# \begin{split}
#     \hat{H}_{\textit{t}} = & -\frac{1}{2}  h(t) \sum ^{N}_{n=1}\hat{\sigma} _{x}\left( n\right) -\frac{1}{2}\sum ^{N-1}_{n=1} J_{z}^{\left( n\right) }\hat{\sigma} _{z}\left( n\right) \hat{ \sigma} _{z}\left( n+1\right) \\ & - \frac{1}{2} J_{z}^{\left( N\right) }\hat{\sigma} _{z}\left( N\right) \hat{ \sigma} _{z}\left( 1\right),
# \end{split}
# \end{equation}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from qutip import *
from tcn import TCN, tcn_full_summary
from tqdm import tqdm
import time

from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score,r2_score
from keras.losses import Huber
import keras.backend as K

from utilis import QuCal, pre_processing, plot_losses
from model import TCN_autoencoder
# Out:
# 2025-01-04 16:49:07.440335: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-04 16:49:07.575559: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
# The output of the system can be calculated using qutip. The code for the same can be found in utilis ipynb file.

# %%
Y = np.load('../dataset/Data_Y.npy', allow_pickle=True)
Y.shape
# Out:
# (3700, 512, 1)

# %%
full_ω, t, E = QuCal()
# Out:
# lowest frequency for the data:  4.260000000000001
# number of frewuencies: 3700

# %%
scaled_X_train, scaled_y_train,scaled_X_test,scaled_y_test, omega_y_test = pre_processing(Y , full_ω,t, F0 = 1 )
# Out:
# 100%|██████████████████████████████████████| 3700/3700 [00:00<00:00, 117334.72it/s]
# omega values for input data:  (3700,)
# x data : (3700, 512)
# scaled_X_train:  (2960, 512, 1)
# scaled_y_train:  (2960, 512, 1)
# scaled_X_test:  (740, 512, 1)
# scaled_y_test:  (740, 512, 1)
# scaled_X_train max:  1.0
# scaled_X_train min:  3.661721e-11
# scaled_y_train max:  1.0
# scaled_y_train min :  0.0

# %%
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0"])

with mirrored_strategy.scope():
    

    TCN_AE = TCN_autoencoder(input_size=512,f1 = 5,f2 = 5, lf = 3,latent_space_tcn = True,last_2_layer_dense = False)
    #Compile the model
    TCN_AE.compile(optimizer=Adam(learning_rate = 0.001), loss=Huber(delta=1.0), metrics=['accuracy'])



#Define a callback to save the best model
checkpoint_filepath = 'outputs/best_1d_tcn_model_v10_bkp.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

#Display the model architecture
TCN_AE.summary()
# Out:
# 2025-01-04 16:49:14.505928: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-04 16:49:14.956738: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46614 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:1d:00.0, compute capability: 8.6
# 2025-01-04 16:49:14.957404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46614 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:1e:00.0, compute capability: 8.6
# 2025-01-04 16:49:14.957965: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46614 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:1f:00.0, compute capability: 8.6
# 2025-01-04 16:49:14.958486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 46614 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:20:00.0, compute capability: 8.6
# 2025-01-04 16:49:14.959021: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 46614 MB memory:  -> device: 4, name: NVIDIA RTX A6000, pci bus id: 0000:21:00.0, compute capability: 8.6
# 2025-01-04 16:49:14.959479: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 46614 MB memory:  -> device: 5, name: NVIDIA RTX A6000, pci bus id: 0000:22:00.0, compute capability: 8.6
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512, 1)]          0
#
#  tcn (TCN)                   (None, 512, 5)            430
#
#  max_pooling1d (MaxPooling1D  (None, 256, 5)           0
#  )
#
#  tcn_1 (TCN)                 (None, 256, 5)            480
#
#  max_pooling1d_1 (MaxPooling  (None, 128, 5)           0
#  1D)
#
#  tcn_2 (TCN)                 (None, 128, 3)            216
#
#  tcn_3 (TCN)                 (None, 128, 5)            470
#
#  up_sampling1d (UpSampling1D  (None, 256, 5)           0
#  )
#
#  tcn_4 (TCN)                 (None, 256, 5)            480
#
#  up_sampling1d_1 (UpSampling  (None, 512, 5)           0
#  1D)
#
#  dense (Dense)               (None, 512, 1)            6
#
# =================================================================
# Total params: 2,082
# Trainable params: 2,082
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ##### Train the model
tic = time.perf_counter()
for n in ([7,6,5,4,3]):  
    # training in a cycle with increasing batch size  . IF i increase the size to 10 from 7 then the train process just stops after 5th cycle and this is because of the GPU memory issue.

    batch_size = 2**n  
    
    history = TCN_AE.fit(scaled_X_train, scaled_y_train,
        epochs=50,
        batch_size=batch_size,
        validation_data=(scaled_X_test, scaled_y_test),callbacks=[model_checkpoint_callback])
    
    loss_save = history.history['loss']
    val_loss_save = history.history['val_loss']
    if n in ([6,5,4,3]):
        
        loss_sum = np.concatenate((loss_sum, loss_save), axis = 0)
        val_loss_sum = np.concatenate((val_loss_sum, val_loss_save), axis = 0)
    else:
   
        loss_sum = loss_save
        val_loss_sum = val_loss_save  

    plot_losses(loss_sum,val_loss_sum)

toc = time.perf_counter()
print(f"Execution time {toc - tic:0.4f} seconds")
# Out:
# Epoch 1/50
# 2025-01-04 16:49:26.394804: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8801
# 2025-01-04 16:49:27.082468: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:648] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 24/24 [==============================] - ETA: 0s - loss: 0.1314 - accuracy: 6.5984e-07
# Epoch 1: val_loss improved from inf to 0.08723, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 13s 159ms/step - loss: 0.1314 - accuracy: 6.5984e-07 - val_loss: 0.0872 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0725 - accuracy: 6.6343e-07
# Epoch 2: val_loss improved from 0.08723 to 0.05496, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0724 - accuracy: 6.5984e-07 - val_loss: 0.0550 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0451 - accuracy: 6.6343e-07
# Epoch 3: val_loss improved from 0.05496 to 0.03401, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0450 - accuracy: 6.5984e-07 - val_loss: 0.0340 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0298 - accuracy: 6.6343e-07
# Epoch 4: val_loss improved from 0.03401 to 0.02574, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0298 - accuracy: 6.5984e-07 - val_loss: 0.0257 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0257 - accuracy: 6.6343e-07
# Epoch 5: val_loss improved from 0.02574 to 0.02504, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0257 - accuracy: 6.5984e-07 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0255 - accuracy: 6.6343e-07
# Epoch 6: val_loss improved from 0.02504 to 0.02503, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0255 - accuracy: 6.5984e-07 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0255 - accuracy: 6.6343e-07
# Epoch 7: val_loss improved from 0.02503 to 0.02501, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0255 - accuracy: 6.5984e-07 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0255 - accuracy: 6.6343e-07
# Epoch 8: val_loss improved from 0.02501 to 0.02500, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0255 - accuracy: 6.5984e-07 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0254 - accuracy: 6.6343e-07
# Epoch 9: val_loss improved from 0.02500 to 0.02499, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0255 - accuracy: 6.6343e-07
# Epoch 10: val_loss improved from 0.02499 to 0.02499, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0254 - accuracy: 6.6343e-07
# Epoch 11: val_loss improved from 0.02499 to 0.02498, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0254 - accuracy: 6.6343e-07
# Epoch 12: val_loss improved from 0.02498 to 0.02497, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0254 - accuracy: 6.6343e-07
# Epoch 13: val_loss improved from 0.02497 to 0.02496, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0254 - accuracy: 6.6343e-07
# Epoch 14: val_loss improved from 0.02496 to 0.02495, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0249 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0254 - accuracy: 6.6343e-07
# Epoch 15: val_loss improved from 0.02495 to 0.02493, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0249 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0254 - accuracy: 6.6343e-07
# Epoch 16: val_loss improved from 0.02493 to 0.02492, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0249 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0253 - accuracy: 6.6343e-07
# Epoch 17: val_loss improved from 0.02492 to 0.02491, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0249 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0254 - accuracy: 6.6343e-07
# Epoch 18: val_loss improved from 0.02491 to 0.02489, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0253 - accuracy: 6.5984e-07 - val_loss: 0.0249 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0253 - accuracy: 6.6343e-07
# Epoch 19: val_loss improved from 0.02489 to 0.02488, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0253 - accuracy: 6.5984e-07 - val_loss: 0.0249 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0253 - accuracy: 6.6343e-07
# Epoch 20: val_loss improved from 0.02488 to 0.02486, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0253 - accuracy: 6.5984e-07 - val_loss: 0.0249 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0253 - accuracy: 6.6343e-07
# Epoch 21: val_loss improved from 0.02486 to 0.02484, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0253 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0253 - accuracy: 6.6343e-07
# Epoch 22: val_loss improved from 0.02484 to 0.02482, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0253 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0252 - accuracy: 6.6343e-07
# Epoch 23: val_loss improved from 0.02482 to 0.02480, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0253 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0252 - accuracy: 6.6343e-07
# Epoch 24: val_loss improved from 0.02480 to 0.02478, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0252 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0252 - accuracy: 6.6343e-07
# Epoch 25: val_loss improved from 0.02478 to 0.02475, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0252 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0252 - accuracy: 6.6343e-07
# Epoch 26: val_loss improved from 0.02475 to 0.02472, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0252 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0251 - accuracy: 6.6343e-07
# Epoch 27: val_loss improved from 0.02472 to 0.02469, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0251 - accuracy: 6.6343e-07
# Epoch 28: val_loss improved from 0.02469 to 0.02465, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0251 - accuracy: 6.6343e-07
# Epoch 29: val_loss improved from 0.02465 to 0.02460, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 30: val_loss improved from 0.02460 to 0.02455, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0249 - accuracy: 6.6343e-07
# Epoch 31: val_loss improved from 0.02455 to 0.02449, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0249 - accuracy: 6.6343e-07
# Epoch 32: val_loss improved from 0.02449 to 0.02442, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 33: val_loss improved from 0.02442 to 0.02434, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0247 - accuracy: 1.3269e-06
# Epoch 34: val_loss improved from 0.02434 to 0.02425, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0247 - accuracy: 1.3197e-06 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0246 - accuracy: 1.3269e-06
# Epoch 35: val_loss improved from 0.02425 to 0.02415, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0246 - accuracy: 1.3197e-06 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0245 - accuracy: 1.3269e-06
# Epoch 36: val_loss improved from 0.02415 to 0.02404, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0245 - accuracy: 1.3197e-06 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0244 - accuracy: 1.3269e-06
# Epoch 37: val_loss improved from 0.02404 to 0.02393, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0244 - accuracy: 1.3197e-06 - val_loss: 0.0239 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0242 - accuracy: 1.3269e-06
# Epoch 38: val_loss improved from 0.02393 to 0.02381, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0243 - accuracy: 1.3197e-06 - val_loss: 0.0238 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0242 - accuracy: 1.3269e-06
# Epoch 39: val_loss improved from 0.02381 to 0.02369, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0242 - accuracy: 1.3197e-06 - val_loss: 0.0237 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0240 - accuracy: 1.3269e-06
# Epoch 40: val_loss improved from 0.02369 to 0.02353, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0240 - accuracy: 1.3197e-06 - val_loss: 0.0235 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0239 - accuracy: 1.3269e-06
# Epoch 41: val_loss improved from 0.02353 to 0.02335, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0239 - accuracy: 1.3197e-06 - val_loss: 0.0234 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0237 - accuracy: 1.3269e-06
# Epoch 42: val_loss improved from 0.02335 to 0.02316, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0237 - accuracy: 1.3197e-06 - val_loss: 0.0232 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0236 - accuracy: 1.3269e-06
# Epoch 43: val_loss improved from 0.02316 to 0.02293, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0236 - accuracy: 1.3197e-06 - val_loss: 0.0229 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0234 - accuracy: 1.3269e-06
# Epoch 44: val_loss improved from 0.02293 to 0.02272, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0234 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0232 - accuracy: 1.3269e-06
# Epoch 45: val_loss improved from 0.02272 to 0.02254, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0230 - accuracy: 1.3269e-06
# Epoch 46: val_loss improved from 0.02254 to 0.02240, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0231 - accuracy: 1.3197e-06 - val_loss: 0.0224 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0229 - accuracy: 1.3269e-06
# Epoch 47: val_loss improved from 0.02240 to 0.02228, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0229 - accuracy: 1.3197e-06 - val_loss: 0.0223 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0228 - accuracy: 1.3269e-06
# Epoch 48: val_loss improved from 0.02228 to 0.02216, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0228 - accuracy: 1.3197e-06 - val_loss: 0.0222 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0227 - accuracy: 1.3269e-06
# Epoch 49: val_loss improved from 0.02216 to 0.02206, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0227 - accuracy: 1.3197e-06 - val_loss: 0.0221 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0226 - accuracy: 1.3269e-06
# Epoch 50: val_loss improved from 0.02206 to 0.02194, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0226 - accuracy: 1.3197e-06 - val_loss: 0.0219 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0224 - accuracy: 1.3197e-06
# Epoch 1: val_loss improved from 0.02194 to 0.02170, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0224 - accuracy: 1.3197e-06 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 1.3197e-06
# Epoch 2: val_loss improved from 0.02170 to 0.02127, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0220 - accuracy: 1.3197e-06 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 1.3269e-06
# Epoch 3: val_loss improved from 0.02127 to 0.02041, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0214 - accuracy: 1.3197e-06 - val_loss: 0.0204 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0200 - accuracy: 1.3197e-06
# Epoch 4: val_loss improved from 0.02041 to 0.01876, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 44ms/step - loss: 0.0200 - accuracy: 1.3197e-06 - val_loss: 0.0188 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 1.3197e-06
# Epoch 5: val_loss improved from 0.01876 to 0.01620, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0179 - accuracy: 1.3197e-06 - val_loss: 0.0162 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0152 - accuracy: 1.3197e-06
# Epoch 6: val_loss improved from 0.01620 to 0.01377, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0152 - accuracy: 1.3197e-06 - val_loss: 0.0138 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 1.3197e-06
# Epoch 7: val_loss improved from 0.01377 to 0.01218, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0133 - accuracy: 1.3197e-06 - val_loss: 0.0122 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0118 - accuracy: 1.3197e-06
# Epoch 8: val_loss improved from 0.01218 to 0.01096, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0118 - accuracy: 1.3197e-06 - val_loss: 0.0110 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 1.3197e-06
# Epoch 9: val_loss improved from 0.01096 to 0.00992, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0107 - accuracy: 1.3197e-06 - val_loss: 0.0099 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 1.3197e-06
# Epoch 10: val_loss improved from 0.00992 to 0.00958, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0097 - accuracy: 1.3197e-06 - val_loss: 0.0096 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 1.3197e-06
# Epoch 11: val_loss improved from 0.00958 to 0.00858, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0092 - accuracy: 1.3197e-06 - val_loss: 0.0086 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0086 - accuracy: 1.3197e-06
# Epoch 12: val_loss improved from 0.00858 to 0.00851, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0086 - accuracy: 1.3197e-06 - val_loss: 0.0085 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 1.3197e-06
# Epoch 13: val_loss improved from 0.00851 to 0.00795, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0084 - accuracy: 1.3197e-06 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 1.3197e-06
# Epoch 14: val_loss improved from 0.00795 to 0.00788, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0080 - accuracy: 1.3197e-06 - val_loss: 0.0079 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 1.3197e-06
# Epoch 15: val_loss improved from 0.00788 to 0.00760, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0078 - accuracy: 1.3197e-06 - val_loss: 0.0076 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 1.3197e-06
# Epoch 16: val_loss improved from 0.00760 to 0.00719, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0074 - accuracy: 1.3197e-06 - val_loss: 0.0072 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 1.3197e-06
# Epoch 17: val_loss improved from 0.00719 to 0.00703, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0073 - accuracy: 1.3197e-06 - val_loss: 0.0070 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 1.3197e-06
# Epoch 18: val_loss improved from 0.00703 to 0.00677, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0071 - accuracy: 1.3197e-06 - val_loss: 0.0068 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 1.3197e-06
# Epoch 19: val_loss improved from 0.00677 to 0.00656, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0069 - accuracy: 1.3197e-06 - val_loss: 0.0066 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 1.3197e-06
# Epoch 20: val_loss improved from 0.00656 to 0.00638, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0066 - accuracy: 1.3197e-06 - val_loss: 0.0064 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 1.3197e-06
# Epoch 21: val_loss improved from 0.00638 to 0.00617, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0064 - accuracy: 1.3197e-06 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 1.3197e-06
# Epoch 22: val_loss improved from 0.00617 to 0.00606, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0063 - accuracy: 1.3197e-06 - val_loss: 0.0061 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 1.3197e-06
# Epoch 23: val_loss improved from 0.00606 to 0.00586, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0061 - accuracy: 1.3197e-06 - val_loss: 0.0059 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0059 - accuracy: 1.3197e-06
# Epoch 24: val_loss improved from 0.00586 to 0.00564, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0059 - accuracy: 1.3197e-06 - val_loss: 0.0056 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.3197e-06
# Epoch 25: val_loss did not improve from 0.00564
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0060 - accuracy: 1.3197e-06 - val_loss: 0.0062 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.0056 - accuracy: 1.3563e-06
# Epoch 26: val_loss improved from 0.00564 to 0.00548, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0056 - accuracy: 1.3197e-06 - val_loss: 0.0055 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 1.3197e-06
# Epoch 27: val_loss improved from 0.00548 to 0.00536, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0054 - accuracy: 1.3197e-06 - val_loss: 0.0054 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.3197e-06
# Epoch 28: val_loss improved from 0.00536 to 0.00495, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0051 - accuracy: 1.3197e-06 - val_loss: 0.0050 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 1.3197e-06
# Epoch 29: val_loss did not improve from 0.00495
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0049 - accuracy: 1.3197e-06 - val_loss: 0.0056 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0050 - accuracy: 1.3197e-06
# Epoch 30: val_loss improved from 0.00495 to 0.00458, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0050 - accuracy: 1.3197e-06 - val_loss: 0.0046 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 1.3197e-06
# Epoch 31: val_loss improved from 0.00458 to 0.00442, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0046 - accuracy: 1.3197e-06 - val_loss: 0.0044 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 1.3197e-06
# Epoch 32: val_loss did not improve from 0.00442
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0045 - accuracy: 1.3197e-06 - val_loss: 0.0047 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0044 - accuracy: 1.3197e-06
# Epoch 33: val_loss improved from 0.00442 to 0.00411, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0044 - accuracy: 1.3197e-06 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 1.3197e-06
# Epoch 34: val_loss improved from 0.00411 to 0.00394, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0042 - accuracy: 1.3197e-06 - val_loss: 0.0039 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 1.3197e-06
# Epoch 35: val_loss improved from 0.00394 to 0.00384, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0042 - accuracy: 1.3197e-06 - val_loss: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.3197e-06
# Epoch 36: val_loss improved from 0.00384 to 0.00368, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0039 - accuracy: 1.3197e-06 - val_loss: 0.0037 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0039 - accuracy: 1.3197e-06
# Epoch 37: val_loss did not improve from 0.00368
# 47/47 [==============================] - 2s 43ms/step - loss: 0.0039 - accuracy: 1.3197e-06 - val_loss: 0.0039 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.3197e-06
# Epoch 38: val_loss improved from 0.00368 to 0.00349, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0036 - accuracy: 1.3197e-06 - val_loss: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 1.3197e-06
# Epoch 39: val_loss improved from 0.00349 to 0.00348, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0040 - accuracy: 1.3197e-06 - val_loss: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 1.3197e-06
# Epoch 40: val_loss improved from 0.00348 to 0.00327, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0035 - accuracy: 1.3197e-06 - val_loss: 0.0033 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 1.3197e-06
# Epoch 41: val_loss did not improve from 0.00327
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0034 - accuracy: 1.3197e-06 - val_loss: 0.0034 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 1.3197e-06
# Epoch 42: val_loss improved from 0.00327 to 0.00307, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0032 - accuracy: 1.3197e-06 - val_loss: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 1.3197e-06
# Epoch 43: val_loss did not improve from 0.00307
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0031 - accuracy: 1.3197e-06 - val_loss: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 1.3197e-06
# Epoch 44: val_loss improved from 0.00307 to 0.00292, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0031 - accuracy: 1.3197e-06 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.3197e-06
# Epoch 45: val_loss improved from 0.00292 to 0.00284, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0030 - accuracy: 1.3197e-06 - val_loss: 0.0028 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.3197e-06
# Epoch 46: val_loss did not improve from 0.00284
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0030 - accuracy: 1.3197e-06 - val_loss: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.3197e-06
# Epoch 47: val_loss improved from 0.00284 to 0.00274, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0030 - accuracy: 1.3197e-06 - val_loss: 0.0027 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 1.3197e-06
# Epoch 48: val_loss improved from 0.00274 to 0.00271, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0027 - accuracy: 1.3197e-06 - val_loss: 0.0027 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.3197e-06
# Epoch 49: val_loss improved from 0.00271 to 0.00267, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0026 - accuracy: 1.3197e-06 - val_loss: 0.0027 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.3197e-06
# Epoch 50: val_loss did not improve from 0.00267
# 47/47 [==============================] - 2s 42ms/step - loss: 0.0026 - accuracy: 1.3197e-06 - val_loss: 0.0028 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0028 - accuracy: 1.3269e-06
# Epoch 1: val_loss did not improve from 0.00267
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0028 - accuracy: 1.3197e-06 - val_loss: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0026 - accuracy: 1.3197e-06
# Epoch 2: val_loss improved from 0.00267 to 0.00250, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 41ms/step - loss: 0.0026 - accuracy: 1.3197e-06 - val_loss: 0.0025 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.3197e-06
# Epoch 3: val_loss did not improve from 0.00250
# 93/93 [==============================] - 4s 40ms/step - loss: 0.0024 - accuracy: 1.3197e-06 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.3197e-06
# Epoch 4: val_loss improved from 0.00250 to 0.00243, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 43ms/step - loss: 0.0023 - accuracy: 1.3197e-06 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.3197e-06
# Epoch 5: val_loss improved from 0.00243 to 0.00211, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 41ms/step - loss: 0.0022 - accuracy: 1.3197e-06 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 1.3197e-06
# Epoch 6: val_loss did not improve from 0.00211
# 93/93 [==============================] - 4s 42ms/step - loss: 0.0023 - accuracy: 1.3197e-06 - val_loss: 0.0024 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 1.3197e-06
# Epoch 7: val_loss improved from 0.00211 to 0.00201, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 48ms/step - loss: 0.0021 - accuracy: 1.3197e-06 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.3197e-06
# Epoch 8: val_loss improved from 0.00201 to 0.00196, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0020 - accuracy: 1.3197e-06 - val_loss: 0.0020 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 1.3197e-06
# Epoch 9: val_loss improved from 0.00196 to 0.00188, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0022 - accuracy: 1.3197e-06 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.3197e-06
# Epoch 10: val_loss improved from 0.00188 to 0.00184, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0019 - accuracy: 1.3197e-06 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 1.3197e-06
# Epoch 11: val_loss did not improve from 0.00184
# 93/93 [==============================] - 4s 44ms/step - loss: 0.0019 - accuracy: 1.3197e-06 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.3197e-06
# Epoch 12: val_loss improved from 0.00184 to 0.00174, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0018 - accuracy: 1.3197e-06 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.3197e-06
# Epoch 13: val_loss improved from 0.00174 to 0.00173, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0018 - accuracy: 1.3197e-06 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.3197e-06
# Epoch 14: val_loss did not improve from 0.00173
# 93/93 [==============================] - 4s 44ms/step - loss: 0.0017 - accuracy: 1.3197e-06 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 1.3197e-06
# Epoch 15: val_loss improved from 0.00173 to 0.00166, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0017 - accuracy: 1.3197e-06 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.3197e-06
# Epoch 16: val_loss did not improve from 0.00166
# 93/93 [==============================] - 4s 43ms/step - loss: 0.0016 - accuracy: 1.3197e-06 - val_loss: 0.0017 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.3197e-06
# Epoch 17: val_loss improved from 0.00166 to 0.00156, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0016 - accuracy: 1.3197e-06 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.3197e-06
# Epoch 18: val_loss improved from 0.00156 to 0.00153, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0016 - accuracy: 1.3197e-06 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.3197e-06
# Epoch 19: val_loss did not improve from 0.00153
# 93/93 [==============================] - 4s 44ms/step - loss: 0.0016 - accuracy: 1.3197e-06 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 1.3197e-06
# Epoch 20: val_loss improved from 0.00153 to 0.00146, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0018 - accuracy: 1.3197e-06 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.3197e-06
# Epoch 21: val_loss improved from 0.00146 to 0.00141, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0014 - accuracy: 1.3197e-06 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.3197e-06
# Epoch 22: val_loss did not improve from 0.00141
# 93/93 [==============================] - 4s 43ms/step - loss: 0.0014 - accuracy: 1.3197e-06 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.3197e-06
# Epoch 23: val_loss did not improve from 0.00141
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0014 - accuracy: 1.3197e-06 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.3197e-06
# Epoch 24: val_loss improved from 0.00141 to 0.00131, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0014 - accuracy: 1.3197e-06 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.3197e-06
# Epoch 25: val_loss improved from 0.00131 to 0.00128, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0014 - accuracy: 1.3197e-06 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.3197e-06
# Epoch 26: val_loss did not improve from 0.00128
# 93/93 [==============================] - 4s 43ms/step - loss: 0.0014 - accuracy: 1.3197e-06 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.3197e-06
# Epoch 27: val_loss improved from 0.00128 to 0.00126, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0013 - accuracy: 1.3197e-06 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.3197e-06
# Epoch 28: val_loss improved from 0.00126 to 0.00120, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0013 - accuracy: 1.3197e-06 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0013 - accuracy: 1.3414e-06
# Epoch 29: val_loss improved from 0.00120 to 0.00118, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0013 - accuracy: 1.3197e-06 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.3197e-06
# Epoch 30: val_loss did not improve from 0.00118
# 93/93 [==============================] - 4s 44ms/step - loss: 0.0012 - accuracy: 1.3197e-06 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.3197e-06
# Epoch 31: val_loss improved from 0.00118 to 0.00115, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0012 - accuracy: 1.3197e-06 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.3197e-06
# Epoch 32: val_loss improved from 0.00115 to 0.00111, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0012 - accuracy: 1.3197e-06 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.3197e-06
# Epoch 33: val_loss did not improve from 0.00111
# 93/93 [==============================] - 4s 44ms/step - loss: 0.0011 - accuracy: 1.3197e-06 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.3197e-06
# Epoch 34: val_loss improved from 0.00111 to 0.00108, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0011 - accuracy: 1.3197e-06 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.3197e-06
# Epoch 35: val_loss did not improve from 0.00108
# 93/93 [==============================] - 4s 44ms/step - loss: 0.0013 - accuracy: 1.3197e-06 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.3197e-06
# Epoch 36: val_loss improved from 0.00108 to 0.00103, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0011 - accuracy: 1.3197e-06 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.3197e-06
# Epoch 37: val_loss improved from 0.00103 to 0.00102, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0010 - accuracy: 1.3197e-06 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0011 - accuracy: 1.3269e-06
# Epoch 38: val_loss improved from 0.00102 to 0.00101, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0011 - accuracy: 1.3197e-06 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.3197e-06
# Epoch 39: val_loss improved from 0.00101 to 0.00099, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0010 - accuracy: 1.3197e-06 - val_loss: 9.8840e-04 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.3197e-06
# Epoch 40: val_loss improved from 0.00099 to 0.00098, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0010 - accuracy: 1.3197e-06 - val_loss: 9.8484e-04 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.3197e-06
# Epoch 41: val_loss improved from 0.00098 to 0.00096, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0010 - accuracy: 1.3197e-06 - val_loss: 9.5650e-04 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.3197e-06
# Epoch 42: val_loss did not improve from 0.00096
# 93/93 [==============================] - 4s 44ms/step - loss: 0.0010 - accuracy: 1.3197e-06 - val_loss: 9.6635e-04 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 92/93 [============================>.] - ETA: 0s - loss: 9.3008e-04 - accuracy: 1.3269e-06
# Epoch 43: val_loss improved from 0.00096 to 0.00092, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# ...
# 185/185 [==============================] - 7s 40ms/step - loss: 2.0889e-04 - accuracy: 1.3197e-06 - val_loss: 1.9025e-04 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 369/370 [============================>.] - ETA: 0s - loss: 4.3822e-04 - accuracy: 1.3233e-06
# Epoch 1: val_loss did not improve from 0.00019
# 370/370 [==============================] - 15s 39ms/step - loss: 4.3800e-04 - accuracy: 1.3197e-06 - val_loss: 2.4868e-04 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 370/370 [==============================] - ETA: 0s - loss: 2.3079e-04 - accuracy: 1.3197e-06
# Epoch 2: val_loss did not improve from 0.00019
# 370/370 [==============================] - 14s 38ms/step - loss: 2.3079e-04 - accuracy: 1.3197e-06 - val_loss: 2.6212e-04 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.2157e-04 - accuracy: 1.3233e-06
# Epoch 3: val_loss did not improve from 0.00019
# 370/370 [==============================] - 14s 39ms/step - loss: 2.2148e-04 - accuracy: 1.3197e-06 - val_loss: 2.3510e-04 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 370/370 [==============================] - ETA: 0s - loss: 2.4912e-04 - accuracy: 1.3197e-06
# Epoch 4: val_loss did not improve from 0.00019
# 370/370 [==============================] - 15s 39ms/step - loss: 2.4912e-04 - accuracy: 1.3197e-06 - val_loss: 1.9091e-04 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.2446e-04 - accuracy: 1.3233e-06
# Epoch 5: val_loss did not improve from 0.00019
# 370/370 [==============================] - 15s 40ms/step - loss: 2.2456e-04 - accuracy: 1.3197e-06 - val_loss: 3.8358e-04 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.0929e-04 - accuracy: 1.3233e-06
# Epoch 6: val_loss did not improve from 0.00019
# 370/370 [==============================] - 15s 39ms/step - loss: 2.0923e-04 - accuracy: 1.3197e-06 - val_loss: 3.5826e-04 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.0484e-04 - accuracy: 1.3233e-06
# Epoch 7: val_loss did not improve from 0.00019
# 370/370 [==============================] - 15s 39ms/step - loss: 2.0516e-04 - accuracy: 1.3197e-06 - val_loss: 1.9097e-04 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 370/370 [==============================] - ETA: 0s - loss: 2.4950e-04 - accuracy: 1.3197e-06
# Epoch 8: val_loss improved from 0.00019 to 0.00016, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 40ms/step - loss: 2.4950e-04 - accuracy: 1.3197e-06 - val_loss: 1.5565e-04 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.8591e-04 - accuracy: 1.3233e-06
# Epoch 9: val_loss did not improve from 0.00016
# 370/370 [==============================] - 14s 39ms/step - loss: 1.8600e-04 - accuracy: 1.3197e-06 - val_loss: 2.4379e-04 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.5850e-04 - accuracy: 1.3233e-06
# Epoch 10: val_loss did not improve from 0.00016
# 370/370 [==============================] - 15s 40ms/step - loss: 2.5839e-04 - accuracy: 1.3197e-06 - val_loss: 1.8616e-04 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 370/370 [==============================] - ETA: 0s - loss: 2.1340e-04 - accuracy: 1.3197e-06
# Epoch 11: val_loss improved from 0.00016 to 0.00015, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 40ms/step - loss: 2.1340e-04 - accuracy: 1.3197e-06 - val_loss: 1.5103e-04 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.8934e-04 - accuracy: 1.3233e-06
# Epoch 12: val_loss did not improve from 0.00015
# 370/370 [==============================] - 15s 40ms/step - loss: 1.8956e-04 - accuracy: 1.3197e-06 - val_loss: 1.5153e-04 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 370/370 [==============================] - ETA: 0s - loss: 1.9438e-04 - accuracy: 1.3197e-06
# Epoch 13: val_loss did not improve from 0.00015
# 370/370 [==============================] - 15s 40ms/step - loss: 1.9438e-04 - accuracy: 1.3197e-06 - val_loss: 2.0014e-04 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.0241e-04 - accuracy: 1.3233e-06
# Epoch 14: val_loss did not improve from 0.00015
# 370/370 [==============================] - 15s 40ms/step - loss: 2.0261e-04 - accuracy: 1.3197e-06 - val_loss: 3.1652e-04 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.9825e-04 - accuracy: 1.3233e-06
# Epoch 15: val_loss did not improve from 0.00015
# 370/370 [==============================] - 15s 40ms/step - loss: 1.9822e-04 - accuracy: 1.3197e-06 - val_loss: 1.6563e-04 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.6825e-04 - accuracy: 1.3233e-06
# Epoch 16: val_loss did not improve from 0.00015
# 370/370 [==============================] - 15s 40ms/step - loss: 1.6875e-04 - accuracy: 1.3197e-06 - val_loss: 1.8730e-04 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 370/370 [==============================] - ETA: 0s - loss: 2.0777e-04 - accuracy: 1.3197e-06
# Epoch 17: val_loss did not improve from 0.00015
# 370/370 [==============================] - 15s 40ms/step - loss: 2.0777e-04 - accuracy: 1.3197e-06 - val_loss: 1.9926e-04 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 370/370 [==============================] - ETA: 0s - loss: 1.9064e-04 - accuracy: 1.3197e-06
# Epoch 18: val_loss improved from 0.00015 to 0.00013, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 40ms/step - loss: 1.9064e-04 - accuracy: 1.3197e-06 - val_loss: 1.3116e-04 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.7269e-04 - accuracy: 1.3233e-06
# Epoch 19: val_loss did not improve from 0.00013
# 370/370 [==============================] - 15s 40ms/step - loss: 1.7247e-04 - accuracy: 1.3197e-06 - val_loss: 1.5504e-04 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.5913e-04 - accuracy: 1.3233e-06
# Epoch 20: val_loss did not improve from 0.00013
# 370/370 [==============================] - 15s 40ms/step - loss: 1.5922e-04 - accuracy: 1.3197e-06 - val_loss: 2.9811e-04 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.5309e-04 - accuracy: 1.3233e-06
# Epoch 21: val_loss improved from 0.00013 to 0.00012, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 40ms/step - loss: 1.5302e-04 - accuracy: 1.3197e-06 - val_loss: 1.2173e-04 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.4936e-04 - accuracy: 1.3233e-06
# Epoch 22: val_loss improved from 0.00012 to 0.00012, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 39ms/step - loss: 1.4937e-04 - accuracy: 1.3197e-06 - val_loss: 1.2113e-04 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.5981e-04 - accuracy: 1.3233e-06
# Epoch 23: val_loss did not improve from 0.00012
# 370/370 [==============================] - 14s 39ms/step - loss: 1.6059e-04 - accuracy: 1.3197e-06 - val_loss: 2.6684e-04 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.1244e-04 - accuracy: 1.3233e-06
# Epoch 24: val_loss did not improve from 0.00012
# 370/370 [==============================] - 15s 40ms/step - loss: 2.1534e-04 - accuracy: 1.3197e-06 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.9112e-04 - accuracy: 1.3233e-06
# Epoch 25: val_loss improved from 0.00012 to 0.00012, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 40ms/step - loss: 1.9087e-04 - accuracy: 1.3197e-06 - val_loss: 1.1813e-04 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.4825e-04 - accuracy: 1.3233e-06
# Epoch 26: val_loss did not improve from 0.00012
# 370/370 [==============================] - 15s 40ms/step - loss: 1.4840e-04 - accuracy: 1.3197e-06 - val_loss: 1.2664e-04 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.4919e-04 - accuracy: 1.3233e-06
# Epoch 27: val_loss did not improve from 0.00012
# 370/370 [==============================] - 15s 40ms/step - loss: 1.4905e-04 - accuracy: 1.3197e-06 - val_loss: 1.2097e-04 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.2742e-04 - accuracy: 1.3233e-06
# Epoch 28: val_loss did not improve from 0.00012
# 370/370 [==============================] - 15s 40ms/step - loss: 1.2731e-04 - accuracy: 1.3197e-06 - val_loss: 1.3589e-04 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 370/370 [==============================] - ETA: 0s - loss: 1.6487e-04 - accuracy: 1.3197e-06
# Epoch 29: val_loss did not improve from 0.00012
# 370/370 [==============================] - 15s 40ms/step - loss: 1.6487e-04 - accuracy: 1.3197e-06 - val_loss: 1.3414e-04 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.3192e-04 - accuracy: 1.3233e-06
# Epoch 30: val_loss improved from 0.00012 to 0.00010, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 40ms/step - loss: 1.3181e-04 - accuracy: 1.3197e-06 - val_loss: 1.0133e-04 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.4851e-04 - accuracy: 1.3233e-06
# Epoch 31: val_loss did not improve from 0.00010
# 370/370 [==============================] - 15s 40ms/step - loss: 1.4850e-04 - accuracy: 1.3197e-06 - val_loss: 1.0909e-04 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.4866e-04 - accuracy: 1.3233e-06
# Epoch 32: val_loss did not improve from 0.00010
# 370/370 [==============================] - 15s 40ms/step - loss: 1.4857e-04 - accuracy: 1.3197e-06 - val_loss: 1.4215e-04 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.4103e-04 - accuracy: 1.3233e-06
# Epoch 33: val_loss did not improve from 0.00010
# 370/370 [==============================] - 15s 40ms/step - loss: 1.4102e-04 - accuracy: 1.3197e-06 - val_loss: 1.5616e-04 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.2448e-04 - accuracy: 1.3233e-06
# Epoch 34: val_loss did not improve from 0.00010
# 370/370 [==============================] - 15s 40ms/step - loss: 1.2449e-04 - accuracy: 1.3197e-06 - val_loss: 2.3144e-04 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 370/370 [==============================] - ETA: 0s - loss: 1.5428e-04 - accuracy: 1.3197e-06
# Epoch 35: val_loss did not improve from 0.00010
# 370/370 [==============================] - 15s 40ms/step - loss: 1.5428e-04 - accuracy: 1.3197e-06 - val_loss: 1.1306e-04 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 370/370 [==============================] - ETA: 0s - loss: 1.2205e-04 - accuracy: 1.3197e-06
# Epoch 36: val_loss improved from 0.00010 to 0.00010, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 41ms/step - loss: 1.2205e-04 - accuracy: 1.3197e-06 - val_loss: 1.0127e-04 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.3360e-04 - accuracy: 1.3233e-06
# Epoch 37: val_loss did not improve from 0.00010
# 370/370 [==============================] - 15s 40ms/step - loss: 1.3358e-04 - accuracy: 1.3197e-06 - val_loss: 1.2443e-04 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.4498e-04 - accuracy: 1.3233e-06
# Epoch 38: val_loss did not improve from 0.00010
# 370/370 [==============================] - 15s 40ms/step - loss: 1.4500e-04 - accuracy: 1.3197e-06 - val_loss: 1.5924e-04 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 370/370 [==============================] - ETA: 0s - loss: 1.5209e-04 - accuracy: 1.3197e-06
# Epoch 39: val_loss did not improve from 0.00010
# 370/370 [==============================] - 15s 40ms/step - loss: 1.5209e-04 - accuracy: 1.3197e-06 - val_loss: 3.0394e-04 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.0798e-04 - accuracy: 1.3233e-06
# Epoch 40: val_loss improved from 0.00010 to 0.00009, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 40ms/step - loss: 1.0801e-04 - accuracy: 1.3197e-06 - val_loss: 9.1462e-05 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.0822e-04 - accuracy: 1.3233e-06
# Epoch 41: val_loss did not improve from 0.00009
# 370/370 [==============================] - 15s 40ms/step - loss: 1.0817e-04 - accuracy: 1.3197e-06 - val_loss: 1.3647e-04 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 370/370 [==============================] - ETA: 0s - loss: 1.2382e-04 - accuracy: 1.3197e-06
# Epoch 42: val_loss did not improve from 0.00009
# 370/370 [==============================] - 15s 40ms/step - loss: 1.2382e-04 - accuracy: 1.3197e-06 - val_loss: 1.0541e-04 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 370/370 [==============================] - ETA: 0s - loss: 1.2075e-04 - accuracy: 1.3197e-06
# Epoch 43: val_loss did not improve from 0.00009
# 370/370 [==============================] - 15s 40ms/step - loss: 1.2075e-04 - accuracy: 1.3197e-06 - val_loss: 1.5309e-04 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.7250e-04 - accuracy: 1.3233e-06
# Epoch 44: val_loss did not improve from 0.00009
# 370/370 [==============================] - 15s 40ms/step - loss: 1.7241e-04 - accuracy: 1.3197e-06 - val_loss: 1.5548e-04 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 370/370 [==============================] - ETA: 0s - loss: 9.8572e-05 - accuracy: 1.3197e-06
# Epoch 45: val_loss did not improve from 0.00009
# 370/370 [==============================] - 15s 40ms/step - loss: 9.8572e-05 - accuracy: 1.3197e-06 - val_loss: 9.7513e-05 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.2049e-04 - accuracy: 1.3233e-06
# Epoch 46: val_loss improved from 0.00009 to 0.00008, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 40ms/step - loss: 1.2036e-04 - accuracy: 1.3197e-06 - val_loss: 8.3252e-05 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.3182e-04 - accuracy: 1.3233e-06
# Epoch 47: val_loss did not improve from 0.00008
# 370/370 [==============================] - 15s 40ms/step - loss: 1.3179e-04 - accuracy: 1.3197e-06 - val_loss: 9.4575e-05 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.0682e-04 - accuracy: 1.3233e-06
# Epoch 48: val_loss did not improve from 0.00008
# 370/370 [==============================] - 15s 40ms/step - loss: 1.0677e-04 - accuracy: 1.3197e-06 - val_loss: 1.1152e-04 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 370/370 [==============================] - ETA: 0s - loss: 1.0376e-04 - accuracy: 1.3197e-06
# Epoch 49: val_loss improved from 0.00008 to 0.00008, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 15s 40ms/step - loss: 1.0376e-04 - accuracy: 1.3197e-06 - val_loss: 8.1797e-05 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.0953e-04 - accuracy: 1.3233e-06
# Epoch 50: val_loss did not improve from 0.00008
# 370/370 [==============================] - 15s 40ms/step - loss: 1.0943e-04 - accuracy: 1.3197e-06 - val_loss: 8.5683e-05 - val_accuracy: 0.0000e+00
# Execution time 1547.9874 seconds

# %%
#Compute predicted values
prediction_test = TCN_AE.predict(scaled_X_test)
print(prediction_test.shape)


# # Create a StandardScaler object


plt.plot(t,prediction_test[50],label = 'prediction')
plt.plot(t,scaled_y_test[50], label = 'ground truth')
plt.legend()
plt.show()
# Out:
# 24/24 [==============================] - 3s 13ms/step
# (740, 512, 1)

# %%
r2_test = r2_score(scaled_y_test.reshape(-1), prediction_test.reshape(-1))
print(r2_test)

r2_test_set = [r2_score(scaled_y_test[i].reshape(-1), prediction_test[i].reshape(-1)) for i in range(len(scaled_y_test))]
print(len(r2_test_set))
# Out:
# 0.9965735406851265
# 740

# %%
# Here we find how many R^2 values are above a particular threshold
above = np.sum(np.array(r2_test_set) > 0.90)/740 * 100
print('$R^{2}$ above 90 :',above)

above1 = np.sum(np.array(r2_test_set) > 0.95)/740 * 100
print('$R^{2}$ above 95 :',above1)
# Out:
# $R^{2}$ above 90 : 100.0
# $R^{2}$ above 95 : 100.0

# %%
plt.figure(figsize=(8, 6))  # Adjust the width and height as needed


plt.plot(omega_y_test, r2_test_set, '*', markersize=4, color='g')
# plt.plot(ω_test, r2_test_set, '.', color='red')
# Plot highlighted points in red

for i in [2, 100, 250, 600]:
    plt.plot(omega_y_test[i], r2_test_set[i], 'X',markersize=9, color='purple')


for _ in np.unique(np.round(np.abs(E[:, np.newaxis] - E), 4)):
    plt.axvline(_, c='y', alpha=0.3)
# plt.axhline(r2_test, color='blue', linestyle='--')  # Plot the horizontal line for r2_test
# plt.text(0.14, r2_test, f"Avg. $R^{2}$ = {r2_test:.4}", color='blue',fontsize=12,weight='bold', va='bottom', ha='left')  # Display the value of r2_test on the plot
plt.xlabel(r"$\omega$",fontsize=15)
plt.ylabel(r"$R^2$",fontsize=15)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
# plt.title("$\omega$ vs. $R^2$ score")
#plt.title("Amplitude = 1", fontsize = 14)
# plt.savefig('R2_Omega_v4_1.png')
plt.savefig('outputs/A1.pdf', dpi=1000, bbox_inches='tight')
plt.show()

# %%
from matplotlib import rcParams

rcParams['font.weight'] = 'bold'
rcParams['font.size'] = 17
labels = ['a', 'b', 'c', 'd']

plt.figure(figsize=(20, 20), dpi=300)
arr =  np.array([2, 100, 250, 600])
j=0
for i in arr:
    plt.subplot(2, 2, j+1)
    plt.plot(t,prediction_test[i, :], label = "pred",color = 'green', linewidth=3)
    plt.plot(t, scaled_y_test[ i, :], label = "target", color = 'blue', linewidth=3  )
    plt.plot( t, scaled_X_test[i, :],'--', label = "input", color = 'orange', linewidth=3 )
    #plt.plot( t, F0 * np.sin(ω_train[i] * t),'--', label = "input",linewidth=4 )
    plt.legend(loc='upper right')
    #plt.title("ω = {}".format(omega_y_test[i]),fontsize=22)
    plt.xlabel("Time",fontsize=22)
    plt.xticks(fontsize = 18)
    plt.yticks(fontsize = 18)
#     plt.ylabel("Expectation Value of Magnetization",  fontsize=27)
    plt.annotate(labels[j], xy=(0.05, 0.95), xycoords='axes fraction', fontsize=25,
                 ha='center', va='center',
                 bbox=dict(boxstyle='circle', fc='w', ec='k', lw=1, alpha=0.7))
    j=j+1

plt.savefig('outputs/Achaotic25TEST.pdf', dpi=700, bbox_inches='tight')
plt.show()
