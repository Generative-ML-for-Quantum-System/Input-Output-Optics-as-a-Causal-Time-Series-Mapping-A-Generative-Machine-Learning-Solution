# %% [markdown]
# ### Case 1: Modeling the input $\to$ output relation for the transverse Ising model (Hamiltonian below) based on a pre-calculated data set for $\mathcal{D}(A = 1)$ of the input $h^{i}(t) = A \sin\left(\omega^{(i)} t \right)$,
# $\mathcal{D}(A) = \left\{  \mathbf{h}^{(i)} \to \mathbf{Y}^{(i)} \right\}_{i=1}^n$
#
# \begin{equation}
# \begin{split}
#     \hat{H}_{\textit{t}} = & -\frac{1}{2}  h(t) \sum ^{N}_{n=1}\hat{\sigma} _{x}\left( n\right) -\frac{1}{2}\sum ^{N-1}_{n=1} J_{z}^{\left( n\right) }\hat{\sigma} _{z}\left( n\right) \hat{ \sigma} _{z}\left( n+1\right) \\ & - \frac{1}{2} J_{z}^{\left( N\right) }\hat{\sigma} _{z}\left( N\right) \hat{ \sigma} _{z}\left( 1\right),
# \end{split}
# \end{equation}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from qutip import *
from tcn import TCN, tcn_full_summary
from tqdm import tqdm
import time

from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D,Dense
from tensorflow.keras.layers import Input, Conv1D, Conv1DTranspose, BatchNormalization

from keras.models import Model
import seaborn as sns

from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score,r2_score
from keras.losses import Huber
import keras.backend as K

from utilis import QuCal, pre_processing, plot_losses
from model import TCN_autoencoder
# Out:
# 2025-01-27 04:08:26.167922: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-27 04:08:26.311323: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
Y = np.load('../dataset/Data_Y.npy', allow_pickle=True)
Y.shape
# Out:
# (3700, 512, 1)

# %%
full_ω, t, E = QuCal()
# Out:
# lowest frequency for the data:  4.260000000000001
# number of frewuencies: 3700

# %%
scaled_X_train, scaled_y_train,scaled_X_test,scaled_y_test, omega_y_test = pre_processing(Y , full_ω,t, F0 = 1 )
# Out:
# 100%|███████████████████████████████████| 3700/3700 [00:00<00:00, 124356.34it/s]
# omega values for input data:  (3700,)
# x data : (3700, 512)
# scaled_X_train:  (2960, 512, 1)
# scaled_y_train:  (2960, 512, 1)
# scaled_X_test:  (740, 512, 1)
# scaled_y_test:  (740, 512, 1)
# scaled_X_train max:  1.0
# scaled_X_train min:  3.661721e-11
# scaled_y_train max:  1.0
# scaled_y_train min :  0.0

# %%
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0"])
def swish_activation(x, beta=1.2):
    return x * K.sigmoid(beta * x)

# def Autoencoder(input_size = 512, f1 = 5,f2 = 5,lf = 3,CNN_out = True):
    
#     # Encoder
#     input_data = Input(shape=(input_size, 1))  # Assuming one channel for simplicity
#     encoded = Conv1D(5, kernel_size=3, activation=swish_activation, padding='same')(input_data)
#     encoded = MaxPooling1D(pool_size=2)(encoded)
#     encoded = Conv1D(5, kernel_size=3, activation=swish_activation, padding='same')(encoded)
#     encoded = MaxPooling1D(pool_size=2)(encoded)

    
#     # bottle neck
#     encoded = Conv1D(3, kernel_size=3, activation=swish_activation, padding='same')(encoded)

#     # Decoder
#     decoded = Conv1D(5, kernel_size=3, activation=swish_activation, padding='same')(encoded)
#     decoded = UpSampling1D(size=2)(decoded)
#     decoded = Conv1D(5, kernel_size=3, activation=swish_activation, padding='same')(decoded)
#     decoded = UpSampling1D(size=2)(decoded)
#     if CNN_out:
#         decoded = Conv1D(1, kernel_size=3, activation=swish_activation, padding='same')(decoded)
#     else:
#         decoded = Dense(1)(decoded)
#     # Autoencoder model
#     autoencoder = Model(input_data, decoded)
#     return autoencoder


def Autoencoder(input_size = 512):
    
    # Encoder
    input_data = Input(shape=(input_size, 1))  # Assuming one channel for simplicity
#     encoded = Conv1D(128, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(input_data)
#     encoded = MaxPooling1D(pool_size=2)(encoded)
#     encoded = Conv1D(64, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(encoded)
#     encoded = MaxPooling1D(pool_size=2)(encoded)
    encoded = Conv1D(32, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(input_data)
    encoded = MaxPooling1D(pool_size=2)(encoded)
    encoded = Conv1D(16, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(encoded)
    encoded = MaxPooling1D(pool_size=2)(encoded)
    encoded = Conv1D(8, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(encoded)
    encoded = MaxPooling1D(pool_size=2)(encoded)
    
    # bottle neck
    encoded = Conv1D(6, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(encoded)

    # Decoder
    decoded = Conv1D(8, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(encoded)
    decoded = UpSampling1D(size=2)(decoded)
    decoded = Conv1D(16, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(decoded)
    decoded = UpSampling1D(size=2)(decoded)
    decoded = Conv1D(32, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(decoded)
    decoded = UpSampling1D(size=2)(decoded)
#     decoded = Conv1D(64, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(decoded)
#     decoded = UpSampling1D(size=2)(decoded)
#     decoded = Conv1D(128, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(decoded)
#     decoded = UpSampling1D(size=2)(decoded)
    decoded = Conv1D(1, kernel_size=3, activation=swish_activation,kernel_initializer='he_normal', padding='same')(decoded)

    # Autoencoder model
    autoencoder = Model(input_data, decoded)
    return autoencoder

with mirrored_strategy.scope():
    

    CNN_AE = Autoencoder(input_size=512)
    #Compile the model
    CNN_AE.compile(optimizer=Adam(learning_rate = 0.001), loss=Huber(delta=1.0), metrics=['accuracy'])



#Define a callback to save the best model
checkpoint_filepath = 'outputs/best_1d_cnn_model_v3_bkp.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

#Display the model architecture
CNN_AE.summary()
# Out:
# 2025-01-27 04:08:40.124851: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-27 04:08:40.591220: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46614 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:1d:00.0, compute capability: 8.6
# 2025-01-27 04:08:40.591914: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46614 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:1e:00.0, compute capability: 8.6
# 2025-01-27 04:08:40.592444: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46614 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:1f:00.0, compute capability: 8.6
# 2025-01-27 04:08:40.592949: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 46614 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:20:00.0, compute capability: 8.6
# 2025-01-27 04:08:40.593467: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 46614 MB memory:  -> device: 4, name: NVIDIA RTX A6000, pci bus id: 0000:21:00.0, compute capability: 8.6
# 2025-01-27 04:08:40.593973: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 46614 MB memory:  -> device: 5, name: NVIDIA RTX A6000, pci bus id: 0000:22:00.0, compute capability: 8.6
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512, 1)]          0
#
#  conv1d (Conv1D)             (None, 512, 32)           128
#
#  max_pooling1d (MaxPooling1D  (None, 256, 32)          0
#  )
#
#  conv1d_1 (Conv1D)           (None, 256, 16)           1552
#
#  max_pooling1d_1 (MaxPooling  (None, 128, 16)          0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 128, 8)            392
#
#  max_pooling1d_2 (MaxPooling  (None, 64, 8)            0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 64, 6)             150
#
#  conv1d_4 (Conv1D)           (None, 64, 8)             152
#
#  up_sampling1d (UpSampling1D  (None, 128, 8)           0
#  )
#
#  conv1d_5 (Conv1D)           (None, 128, 16)           400
#
#  up_sampling1d_1 (UpSampling  (None, 256, 16)          0
#  1D)
#
#  conv1d_6 (Conv1D)           (None, 256, 32)           1568
#
#  up_sampling1d_2 (UpSampling  (None, 512, 32)          0
#  1D)
#
#  conv1d_7 (Conv1D)           (None, 512, 1)            97
#
# =================================================================
# Total params: 4,439
# Trainable params: 4,439
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ##### Train the model
tic = time.perf_counter()
for n in ([7,6,5,4,3]):  
    # training in a cycle with increasing batch size  . IF i increase the size to 10 from 7 then the train process just stops after 5th cycle and this is because of the GPU memory issue.

    batch_size = 2**n  
    
    history = CNN_AE.fit(scaled_X_train, scaled_y_train,
        epochs=50,
        batch_size=batch_size,
        validation_data=(scaled_X_test, scaled_y_test),callbacks=[model_checkpoint_callback])
    
    loss_save = history.history['loss']
    val_loss_save = history.history['val_loss']
    if n in ([6,5,4,3]):
        
        loss_sum = np.concatenate((loss_sum, loss_save), axis = 0)
        val_loss_sum = np.concatenate((val_loss_sum, val_loss_save), axis = 0)
    else:
   
        loss_sum = loss_save
        val_loss_sum = val_loss_save  

    plot_losses(loss_sum,val_loss_sum)

toc = time.perf_counter()
print(f"Execution time {toc - tic:0.4f} seconds")
# Out:
# Epoch 1/50
# 2025-01-27 04:08:46.205731: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8801
# 24/24 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 1.3197e-06
# Epoch 1: val_loss improved from inf to 0.02764, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 8s 109ms/step - loss: 0.0640 - accuracy: 1.3197e-06 - val_loss: 0.0276 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0272 - accuracy: 6.5984e-07
# Epoch 2: val_loss improved from 0.02764 to 0.02605, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 33ms/step - loss: 0.0272 - accuracy: 6.5984e-07 - val_loss: 0.0260 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0260 - accuracy: 6.9358e-07
# Epoch 3: val_loss improved from 0.02605 to 0.02542, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0260 - accuracy: 6.5984e-07 - val_loss: 0.0254 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0257 - accuracy: 0.0000e+00
# Epoch 4: val_loss improved from 0.02542 to 0.02516, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0257 - accuracy: 6.5984e-07 - val_loss: 0.0252 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0254 - accuracy: 6.9358e-07
# Epoch 5: val_loss improved from 0.02516 to 0.02490, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0254 - accuracy: 6.5984e-07 - val_loss: 0.0249 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0252 - accuracy: 6.9358e-07
# Epoch 6: val_loss improved from 0.02490 to 0.02473, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0252 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 0.0000e+00
# Epoch 7: val_loss improved from 0.02473 to 0.02452, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0249 - accuracy: 6.9358e-07
# Epoch 8: val_loss improved from 0.02452 to 0.02438, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0249 - accuracy: 6.9358e-07
# Epoch 9: val_loss did not improve from 0.02438
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0248 - accuracy: 6.9358e-07
# Epoch 10: val_loss did not improve from 0.02438
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0248 - accuracy: 6.9358e-07
# Epoch 11: val_loss improved from 0.02438 to 0.02431, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0247 - accuracy: 6.9358e-07
# Epoch 12: val_loss improved from 0.02431 to 0.02418, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0246 - accuracy: 6.9358e-07
# Epoch 13: val_loss did not improve from 0.02418
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0247 - accuracy: 6.9358e-07
# Epoch 14: val_loss improved from 0.02418 to 0.02409, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0246 - accuracy: 6.9358e-07
# Epoch 15: val_loss improved from 0.02409 to 0.02405, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0246 - accuracy: 6.9358e-07
# Epoch 16: val_loss did not improve from 0.02405
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0246 - accuracy: 6.9358e-07
# Epoch 17: val_loss improved from 0.02405 to 0.02402, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0245 - accuracy: 6.9358e-07
# Epoch 18: val_loss improved from 0.02402 to 0.02397, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0245 - accuracy: 6.9358e-07
# Epoch 19: val_loss did not improve from 0.02397
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 6.5984e-07
# Epoch 20: val_loss improved from 0.02397 to 0.02394, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0244 - accuracy: 6.5984e-07 - val_loss: 0.0239 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0245 - accuracy: 6.9358e-07
# Epoch 21: val_loss improved from 0.02394 to 0.02390, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0244 - accuracy: 6.5984e-07 - val_loss: 0.0239 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0245 - accuracy: 6.9358e-07
# Epoch 22: val_loss did not improve from 0.02390
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0245 - accuracy: 6.9358e-07
# Epoch 23: val_loss did not improve from 0.02390
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0244 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0246 - accuracy: 1.3872e-06
# Epoch 24: val_loss improved from 0.02390 to 0.02383, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0246 - accuracy: 1.3197e-06 - val_loss: 0.0238 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0244 - accuracy: 6.9358e-07
# Epoch 25: val_loss improved from 0.02383 to 0.02372, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0244 - accuracy: 6.5984e-07 - val_loss: 0.0237 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0243 - accuracy: 1.3872e-06
# Epoch 26: val_loss improved from 0.02372 to 0.02370, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0243 - accuracy: 1.3197e-06 - val_loss: 0.0237 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0243 - accuracy: 6.9358e-07
# Epoch 27: val_loss improved from 0.02370 to 0.02364, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0243 - accuracy: 6.5984e-07 - val_loss: 0.0236 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0241 - accuracy: 6.9358e-07
# Epoch 28: val_loss improved from 0.02364 to 0.02362, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0241 - accuracy: 6.5984e-07 - val_loss: 0.0236 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0240 - accuracy: 6.9358e-07
# Epoch 29: val_loss improved from 0.02362 to 0.02356, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0240 - accuracy: 6.5984e-07 - val_loss: 0.0236 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0240 - accuracy: 6.9358e-07
# Epoch 30: val_loss improved from 0.02356 to 0.02345, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0240 - accuracy: 6.5984e-07 - val_loss: 0.0235 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0240 - accuracy: 6.9358e-07
# Epoch 31: val_loss improved from 0.02345 to 0.02337, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0239 - accuracy: 6.5984e-07 - val_loss: 0.0234 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0239 - accuracy: 6.9358e-07
# Epoch 32: val_loss improved from 0.02337 to 0.02328, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0239 - accuracy: 6.5984e-07 - val_loss: 0.0233 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0237 - accuracy: 6.9358e-07
# Epoch 33: val_loss did not improve from 0.02328
# 24/24 [==============================] - 1s 28ms/step - loss: 0.0238 - accuracy: 6.5984e-07 - val_loss: 0.0233 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0238 - accuracy: 6.9358e-07
# Epoch 34: val_loss improved from 0.02328 to 0.02322, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0238 - accuracy: 6.5984e-07 - val_loss: 0.0232 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0237 - accuracy: 6.9358e-07
# Epoch 35: val_loss improved from 0.02322 to 0.02312, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0237 - accuracy: 6.5984e-07 - val_loss: 0.0231 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0236 - accuracy: 1.3872e-06
# Epoch 36: val_loss improved from 0.02312 to 0.02306, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0237 - accuracy: 1.3197e-06 - val_loss: 0.0231 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0237 - accuracy: 1.3872e-06
# Epoch 37: val_loss did not improve from 0.02306
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0236 - accuracy: 1.3197e-06 - val_loss: 0.0232 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0236 - accuracy: 6.9358e-07
# Epoch 38: val_loss improved from 0.02306 to 0.02300, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0236 - accuracy: 6.5984e-07 - val_loss: 0.0230 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0236 - accuracy: 6.9358e-07
# Epoch 39: val_loss did not improve from 0.02300
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0236 - accuracy: 6.5984e-07 - val_loss: 0.0232 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0236 - accuracy: 6.9358e-07
# Epoch 40: val_loss improved from 0.02300 to 0.02294, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0236 - accuracy: 6.5984e-07 - val_loss: 0.0229 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0235 - accuracy: 1.3872e-06
# Epoch 41: val_loss did not improve from 0.02294
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0235 - accuracy: 1.3197e-06 - val_loss: 0.0232 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0236 - accuracy: 1.3872e-06
# Epoch 42: val_loss improved from 0.02294 to 0.02291, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0235 - accuracy: 1.3197e-06 - val_loss: 0.0229 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0235 - accuracy: 1.3872e-06
# Epoch 43: val_loss improved from 0.02291 to 0.02284, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0235 - accuracy: 1.3197e-06 - val_loss: 0.0228 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0234 - accuracy: 6.9358e-07
# Epoch 44: val_loss did not improve from 0.02284
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0234 - accuracy: 6.5984e-07 - val_loss: 0.0231 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0235 - accuracy: 6.9358e-07
# Epoch 45: val_loss did not improve from 0.02284
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0235 - accuracy: 6.5984e-07 - val_loss: 0.0230 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0234 - accuracy: 6.9358e-07
# Epoch 46: val_loss improved from 0.02284 to 0.02276, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0235 - accuracy: 6.5984e-07 - val_loss: 0.0228 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0234 - accuracy: 1.3872e-06
# Epoch 47: val_loss did not improve from 0.02276
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0228 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0233 - accuracy: 1.3872e-06
# Epoch 48: val_loss did not improve from 0.02276
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0229 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0233 - accuracy: 1.3872e-06
# Epoch 49: val_loss improved from 0.02276 to 0.02271, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0233 - accuracy: 6.9358e-07
# Epoch 50: val_loss did not improve from 0.02271
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0228 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 1.3197e-06
# Epoch 1: val_loss improved from 0.02271 to 0.02270, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 29ms/step - loss: 0.0234 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 1.3269e-06
# Epoch 2: val_loss improved from 0.02270 to 0.02261, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 1.3269e-06
# Epoch 3: val_loss did not improve from 0.02261
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 1.3269e-06
# Epoch 4: val_loss improved from 0.02261 to 0.02243, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0231 - accuracy: 1.3197e-06 - val_loss: 0.0224 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 1.3269e-06
# Epoch 5: val_loss improved from 0.02243 to 0.02236, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0230 - accuracy: 1.3197e-06 - val_loss: 0.0224 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 1.3269e-06
# Epoch 6: val_loss improved from 0.02236 to 0.02233, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0230 - accuracy: 1.3197e-06 - val_loss: 0.0223 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0229 - accuracy: 1.3269e-06
# Epoch 7: val_loss did not improve from 0.02233
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0229 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0229 - accuracy: 1.3269e-06
# Epoch 8: val_loss improved from 0.02233 to 0.02230, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0229 - accuracy: 1.3197e-06 - val_loss: 0.0223 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 1.3269e-06
# Epoch 9: val_loss improved from 0.02230 to 0.02219, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0228 - accuracy: 1.3197e-06 - val_loss: 0.0222 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0228 - accuracy: 1.3269e-06
# Epoch 10: val_loss improved from 0.02219 to 0.02210, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0228 - accuracy: 1.3197e-06 - val_loss: 0.0221 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 1.3269e-06
# Epoch 11: val_loss improved from 0.02210 to 0.02202, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 27ms/step - loss: 0.0227 - accuracy: 1.3197e-06 - val_loss: 0.0220 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 1.3269e-06
# Epoch 12: val_loss improved from 0.02202 to 0.02196, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0227 - accuracy: 1.3197e-06 - val_loss: 0.0220 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 1.3269e-06
# Epoch 13: val_loss improved from 0.02196 to 0.02192, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0226 - accuracy: 1.3197e-06 - val_loss: 0.0219 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 1.3269e-06
# Epoch 14: val_loss did not improve from 0.02192
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0226 - accuracy: 1.3197e-06 - val_loss: 0.0220 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0226 - accuracy: 1.3269e-06
# Epoch 15: val_loss improved from 0.02192 to 0.02187, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0226 - accuracy: 1.3197e-06 - val_loss: 0.0219 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 1.3269e-06
# Epoch 16: val_loss did not improve from 0.02187
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0225 - accuracy: 1.3197e-06 - val_loss: 0.0219 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 1.3269e-06
# Epoch 17: val_loss improved from 0.02187 to 0.02182, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0225 - accuracy: 1.3197e-06 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 1.3269e-06
# Epoch 18: val_loss did not improve from 0.02182
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0225 - accuracy: 1.3197e-06 - val_loss: 0.0219 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 1.3269e-06
# Epoch 19: val_loss improved from 0.02182 to 0.02181, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0225 - accuracy: 1.3197e-06 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 1.3269e-06
# Epoch 20: val_loss did not improve from 0.02181
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0224 - accuracy: 1.3197e-06 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 1.3269e-06
# Epoch 21: val_loss improved from 0.02181 to 0.02178, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0224 - accuracy: 1.3197e-06 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 1.3269e-06
# Epoch 22: val_loss did not improve from 0.02178
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0224 - accuracy: 1.3197e-06 - val_loss: 0.0219 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0225 - accuracy: 1.3269e-06
# Epoch 23: val_loss did not improve from 0.02178
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0224 - accuracy: 1.3197e-06 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 1.3269e-06
# Epoch 24: val_loss did not improve from 0.02178
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0224 - accuracy: 1.3197e-06 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 1.3269e-06
# Epoch 25: val_loss improved from 0.02178 to 0.02171, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 1.3269e-06
# Epoch 26: val_loss improved from 0.02171 to 0.02167, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 1.3269e-06
# Epoch 27: val_loss did not improve from 0.02167
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 1.3269e-06
# Epoch 28: val_loss did not improve from 0.02167
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 1.3197e-06
# Epoch 29: val_loss improved from 0.02167 to 0.02167, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 1.3269e-06
# Epoch 30: val_loss improved from 0.02167 to 0.02165, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 31: val_loss improved from 0.02165 to 0.02160, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 1.3269e-06
# Epoch 32: val_loss did not improve from 0.02160
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 1.3269e-06
# Epoch 33: val_loss improved from 0.02160 to 0.02157, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 34: val_loss did not improve from 0.02157
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0222 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0223 - accuracy: 1.3269e-06
# Epoch 35: val_loss did not improve from 0.02157
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0223 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 36: val_loss did not improve from 0.02157
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0222 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 37: val_loss improved from 0.02157 to 0.02155, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0222 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 38: val_loss did not improve from 0.02155
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0222 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 39: val_loss did not improve from 0.02155
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0222 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 40: val_loss improved from 0.02155 to 0.02155, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0222 - accuracy: 1.3197e-06 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 41: val_loss improved from 0.02155 to 0.02154, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0222 - accuracy: 1.3197e-06 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 42: val_loss improved from 0.02154 to 0.02151, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0222 - accuracy: 1.3197e-06 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0221 - accuracy: 1.3197e-06
# Epoch 43: val_loss did not improve from 0.02151
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0218 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 44: val_loss improved from 0.02151 to 0.02149, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0222 - accuracy: 1.3197e-06 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3269e-06
# Epoch 45: val_loss improved from 0.02149 to 0.02145, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3269e-06
# Epoch 46: val_loss did not improve from 0.02145
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0222 - accuracy: 1.3269e-06
# Epoch 47: val_loss did not improve from 0.02145
# 47/47 [==============================] - 1s 24ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3269e-06
# Epoch 48: val_loss did not improve from 0.02145
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3269e-06
# Epoch 49: val_loss did not improve from 0.02145
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3269e-06
# Epoch 50: val_loss improved from 0.02145 to 0.02142, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 47/47 [==============================] - 1s 26ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3269e-06
# Epoch 1: val_loss did not improve from 0.02142
# 93/93 [==============================] - 2s 25ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0217 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3414e-06
# Epoch 2: val_loss did not improve from 0.02142
# 93/93 [==============================] - 2s 23ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0215 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3414e-06
# Epoch 3: val_loss did not improve from 0.02142
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0216 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3414e-06
# Epoch 4: val_loss did not improve from 0.02142
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3414e-06
# Epoch 5: val_loss did not improve from 0.02142
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3414e-06
# Epoch 6: val_loss did not improve from 0.02142
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3414e-06
# Epoch 7: val_loss improved from 0.02142 to 0.02140, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0221 - accuracy: 1.3414e-06
# Epoch 8: val_loss did not improve from 0.02140
# 93/93 [==============================] - 2s 23ms/step - loss: 0.0221 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 1.3414e-06
# Epoch 9: val_loss improved from 0.02140 to 0.02137, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 25ms/step - loss: 0.0220 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 1.3414e-06
# Epoch 10: val_loss improved from 0.02137 to 0.02135, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0220 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 1.3414e-06
# Epoch 11: val_loss improved from 0.02135 to 0.02135, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0220 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 1.3414e-06
# Epoch 12: val_loss improved from 0.02135 to 0.02133, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0220 - accuracy: 1.3197e-06 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 1.3414e-06
# Epoch 13: val_loss improved from 0.02133 to 0.02131, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0220 - accuracy: 1.3197e-06 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 1.3414e-06
# Epoch 14: val_loss did not improve from 0.02131
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0220 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0220 - accuracy: 1.3414e-06
# Epoch 15: val_loss did not improve from 0.02131
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0220 - accuracy: 1.3197e-06 - val_loss: 0.0214 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 16: val_loss did not improve from 0.02131
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0219 - accuracy: 1.3197e-06 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 17: val_loss improved from 0.02131 to 0.02130, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0219 - accuracy: 1.3197e-06 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 18: val_loss improved from 0.02130 to 0.02125, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0219 - accuracy: 1.3197e-06 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 19: val_loss improved from 0.02125 to 0.02125, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0219 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 20: val_loss did not improve from 0.02125
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0219 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 21: val_loss did not improve from 0.02125
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0219 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 22: val_loss did not improve from 0.02125
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0219 - accuracy: 1.3197e-06 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 23: val_loss improved from 0.02125 to 0.02123, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0219 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 24: val_loss improved from 0.02123 to 0.02122, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 1.3414e-06
# Epoch 25: val_loss did not improve from 0.02122
# 93/93 [==============================] - 2s 23ms/step - loss: 0.0219 - accuracy: 1.3197e-06 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 26: val_loss improved from 0.02122 to 0.02122, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 26ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 1.3414e-06
# Epoch 27: val_loss did not improve from 0.02122
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 6.7072e-07
# Epoch 28: val_loss improved from 0.02122 to 0.02119, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 1.3414e-06
# Epoch 29: val_loss improved from 0.02119 to 0.02118, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0219 - accuracy: 1.3414e-06
# Epoch 30: val_loss improved from 0.02118 to 0.02117, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 1.3414e-06
# Epoch 31: val_loss did not improve from 0.02117
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 6.7072e-07
# Epoch 32: val_loss improved from 0.02117 to 0.02116, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 33: val_loss did not improve from 0.02116
# 93/93 [==============================] - 2s 23ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 1.3414e-06
# Epoch 34: val_loss improved from 0.02116 to 0.02116, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 1.3414e-06
# Epoch 35: val_loss improved from 0.02116 to 0.02115, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 36: val_loss did not improve from 0.02115
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 1.3414e-06
# Epoch 37: val_loss improved from 0.02115 to 0.02112, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0218 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 38: val_loss did not improve from 0.02112
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 39: val_loss did not improve from 0.02112
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 40: val_loss did not improve from 0.02112
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0212 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0218 - accuracy: 1.3414e-06
# Epoch 41: val_loss improved from 0.02112 to 0.02111, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 42: val_loss did not improve from 0.02111
# 93/93 [==============================] - 2s 23ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 43: val_loss did not improve from 0.02111
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 44: val_loss did not improve from 0.02111
# 93/93 [==============================] - 2s 23ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0213 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 45: val_loss improved from 0.02111 to 0.02109, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 46: val_loss improved from 0.02109 to 0.02106, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3269e-06
# Epoch 47: val_loss did not improve from 0.02106
# 93/93 [==============================] - 2s 23ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 48: val_loss improved from 0.02106 to 0.02103, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0210 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3414e-06
# Epoch 49: val_loss did not improve from 0.02103
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0211 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0216 - accuracy: 1.3414e-06
# Epoch 50: val_loss improved from 0.02103 to 0.02101, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 93/93 [==============================] - 2s 24ms/step - loss: 0.0216 - accuracy: 1.3197e-06 - val_loss: 0.0210 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 1.3269e-06
# Epoch 1: val_loss did not improve from 0.02101
# 185/185 [==============================] - 4s 24ms/step - loss: 0.0217 - accuracy: 1.3197e-06 - val_loss: 0.0210 - val_accuracy: 0.0000e+00
# ...
# 185/185 [==============================] - 4s 24ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 1.3269e-06
# Epoch 48: val_loss did not improve from 0.02061
# 185/185 [==============================] - 4s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 1.3269e-06
# Epoch 49: val_loss did not improve from 0.02061
# 185/185 [==============================] - 4s 24ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 1.3269e-06
# Epoch 50: val_loss did not improve from 0.02061
# 185/185 [==============================] - 4s 24ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 1.3197e-06
# Epoch 1: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 24ms/step - loss: 0.0214 - accuracy: 1.3197e-06 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 1.3197e-06
# Epoch 2: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0214 - accuracy: 1.3197e-06 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 3: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 4: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 5: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0208 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 6: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 7: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 8: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0208 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 9: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 10: val_loss improved from 0.02061 to 0.02061, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0213 - accuracy: 1.3269e-06
# Epoch 11: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 12: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 13: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 14: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 15: val_loss did not improve from 0.02061
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 16: val_loss improved from 0.02061 to 0.02060, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 370/370 [==============================] - 9s 24ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 17: val_loss improved from 0.02060 to 0.02057, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 1.3269e-06
# Epoch 18: val_loss did not improve from 0.02057
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 19: val_loss did not improve from 0.02057
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 20: val_loss improved from 0.02057 to 0.02056, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 370/370 [==============================] - 9s 24ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 21: val_loss did not improve from 0.02056
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0207 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 22: val_loss did not improve from 0.02056
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 1.3197e-06
# Epoch 23: val_loss did not improve from 0.02056
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0213 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 24: val_loss did not improve from 0.02056
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 25: val_loss did not improve from 0.02056
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 26: val_loss improved from 0.02056 to 0.02055, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 27: val_loss did not improve from 0.02055
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 28: val_loss did not improve from 0.02055
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 29: val_loss did not improve from 0.02055
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0212 - accuracy: 1.3269e-06
# Epoch 30: val_loss did not improve from 0.02055
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 31: val_loss did not improve from 0.02055
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 32: val_loss did not improve from 0.02055
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 33: val_loss did not improve from 0.02055
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 34: val_loss did not improve from 0.02055
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 35: val_loss improved from 0.02055 to 0.02054, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 36: val_loss did not improve from 0.02054
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 37: val_loss did not improve from 0.02054
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 38: val_loss did not improve from 0.02054
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 39: val_loss did not improve from 0.02054
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 40: val_loss did not improve from 0.02054
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 41: val_loss improved from 0.02054 to 0.02053, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 42: val_loss did not improve from 0.02053
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 43: val_loss did not improve from 0.02053
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0206 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 44: val_loss improved from 0.02053 to 0.02052, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 45: val_loss did not improve from 0.02052
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 46: val_loss did not improve from 0.02052
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 47: val_loss did not improve from 0.02052
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 48: val_loss did not improve from 0.02052
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 49: val_loss improved from 0.02052 to 0.02052, saving model to outputs/best_1d_cnn_model_v3_bkp.h5
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 1.3197e-06
# Epoch 50: val_loss did not improve from 0.02052
# 370/370 [==============================] - 9s 23ms/step - loss: 0.0212 - accuracy: 1.3197e-06 - val_loss: 0.0205 - val_accuracy: 0.0000e+00
# Execution time 865.5468 seconds

# %%
#Compute predicted values
prediction_test = CNN_AE.predict(scaled_X_test)
print(prediction_test.shape)


# # Create a StandardScaler object


plt.plot(t,prediction_test[50],label = 'prediction')
plt.plot(t,scaled_y_test[50], label = 'ground truth')
plt.legend()
plt.show()
# Out:
# 24/24 [==============================] - 1s 6ms/step
# (740, 512, 1)

# %%
r2_test = r2_score(scaled_y_test.reshape(-1), prediction_test.reshape(-1))
print(r2_test)

r2_test_set = [r2_score(scaled_y_test[i].reshape(-1), prediction_test[i].reshape(-1)) for i in range(len(scaled_y_test))]
print(len(r2_test_set))
# Out:
# 0.1788725508910589
# 740

# %%
above = np.sum(np.array(r2_test_set) > 0.90)/740 * 100
print('$R^{2}$ above 90 :',above)

above1 = np.sum(np.array(r2_test_set) > 0.95)/740 * 100
print('$R^{2}$ above 95 :',above1)
# Out:
# $R^{2}$ above 90 : 6.351351351351352
# $R^{2}$ above 95 : 0.6756756756756757

# %%
plt.figure(figsize=(8, 6))  # Adjust the width and height as needed


plt.plot(omega_y_test, r2_test_set, '*', markersize=4, color='g')
# plt.plot(ω_test, r2_test_set, '.', color='red')
# Plot highlighted points in red

for i in [2, 100, 250, 600]:
    plt.plot(omega_y_test[i], r2_test_set[i], 'X',markersize=9, color='purple')


for _ in np.unique(np.round(np.abs(E[:, np.newaxis] - E), 4)):
    plt.axvline(_, c='y', alpha=0.3)
# plt.axhline(r2_test, color='blue', linestyle='--')  # Plot the horizontal line for r2_test
# plt.text(0.14, r2_test, f"Avg. $R^{2}$ = {r2_test:.4}", color='blue',fontsize=12,weight='bold', va='bottom', ha='left')  # Display the value of r2_test on the plot
plt.xlabel(r"$\omega$",fontsize=15)
plt.ylabel(r"$R^2$",fontsize=15)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
# plt.title("$\omega$ vs. $R^2$ score")
#plt.title("Amplitude = 1", fontsize = 14)
# plt.savefig('R2_Omega_v4_1.png')
plt.savefig('outputs/A1_CNN_v4.pdf', dpi=1000, bbox_inches='tight')
plt.show()

# %%
from matplotlib import rcParams

rcParams['font.weight'] = 'bold'
rcParams['font.size'] = 17
labels = ['a', 'b', 'c', 'd']

plt.figure(figsize=(20, 20), dpi=300)
arr =  np.array([2, 100, 250, 600])
j=0
for i in arr:
    plt.subplot(2, 2, j+1)
    plt.plot(t,prediction_test[i, :], label = "pred",color = 'green', linewidth=3)
    plt.plot(t, scaled_y_test[ i, :], label = "target", color = 'blue', linewidth=3  )
    plt.plot( t, scaled_X_test[i, :],'--', label = "input", color = 'orange', linewidth=3 )
    #plt.plot( t, F0 * np.sin(ω_train[i] * t),'--', label = "input",linewidth=4 )
    plt.legend(loc='upper right')
    #plt.title("ω = {}".format(omega_y_test[i]),fontsize=22)
    plt.xlabel("Time",fontsize=22)
    plt.xticks(fontsize = 18)
    plt.yticks(fontsize = 18)
#     plt.ylabel("Expectation Value of Magnetization",  fontsize=27)
    plt.annotate(labels[j], xy=(0.05, 0.95), xycoords='axes fraction', fontsize=25,
                 ha='center', va='center',
                 bbox=dict(boxstyle='circle', fc='w', ec='k', lw=1, alpha=0.7))
    j=j+1

# plt.savefig('outputs/Achaotic25TEST.pdf', dpi=700, bbox_inches='tight')
plt.show()
