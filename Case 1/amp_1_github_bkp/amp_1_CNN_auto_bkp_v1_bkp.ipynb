# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from qutip import *
from tcn import TCN, tcn_full_summary
from tqdm import tqdm
import time

from keras.layers import Input, Conv1D, MaxPooling1D, UpSampling1D,Dense
from keras.models import Model
import seaborn as sns

from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score,r2_score
from keras.losses import Huber
import keras.backend as K

from utilis import QuCal, pre_processing, plot_losses
from model import TCN_autoencoder
# Out:
# 2025-01-27 05:03:53.131228: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-27 05:03:53.271394: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
Y = np.load('../dataset/Data_Y.npy', allow_pickle=True)
Y.shape
# Out:
# (3700, 512, 1)

# %%
full_ω, t, E = QuCal()
# Out:
# lowest frequency for the data:  4.260000000000001
# number of frewuencies: 3700

# %%
scaled_X_train, scaled_y_train,scaled_X_test,scaled_y_test, omega_y_test = pre_processing(Y , full_ω,t, F0 = 1 )
# Out:
# 100%|███████████████████████████████████| 3700/3700 [00:00<00:00, 176855.86it/s]
# omega values for input data:  (3700,)
# x data : (3700, 512)
# scaled_X_train:  (2960, 512, 1)
# scaled_y_train:  (2960, 512, 1)
# scaled_X_test:  (740, 512, 1)
# scaled_y_test:  (740, 512, 1)
# scaled_X_train max:  1.0
# scaled_X_train min:  3.661721e-11
# scaled_y_train max:  1.0
# scaled_y_train min :  0.0

# %%
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0"])
def swish_activation(x, beta=1.2):
    return x * K.sigmoid(beta * x)

def Autoencoder(input_size = 512, f1 = 5,f2 = 5,lf = 3,CNN_out = True):
    
    # Encoder
    input_data = Input(shape=(input_size, 1))  # Assuming one channel for simplicity
    encoded = Conv1D(5, kernel_size=3, activation=swish_activation, padding='same')(input_data)
    encoded = MaxPooling1D(pool_size=2)(encoded)
    encoded = Conv1D(5, kernel_size=3, activation=swish_activation, padding='same')(encoded)
    encoded = MaxPooling1D(pool_size=2)(encoded)

    
    # bottle neck
    encoded = Conv1D(3, kernel_size=3, activation=swish_activation, padding='same')(encoded)

    # Decoder
    decoded = Conv1D(5, kernel_size=3, activation=swish_activation, padding='same')(encoded)
    decoded = UpSampling1D(size=2)(decoded)
    decoded = Conv1D(5, kernel_size=3, activation=swish_activation, padding='same')(decoded)
    decoded = UpSampling1D(size=2)(decoded)
    if CNN_out:
        decoded = Conv1D(1, kernel_size=3, activation=swish_activation, padding='same')(decoded)
    else:
        decoded = Dense(1)(decoded)
    # Autoencoder model
    autoencoder = Model(input_data, decoded)
    return autoencoder

with mirrored_strategy.scope():
    

    CNN_AE = Autoencoder(input_size=512,f1 = 5,f2 = 5, lf = 3,CNN_out = True)
    #Compile the model
    CNN_AE.compile(optimizer=Adam(learning_rate = 0.001), loss=Huber(delta=1.0), metrics=['accuracy'])



#Define a callback to save the best model
checkpoint_filepath = 'outputs/best_1d_cnn_model_v1_bkp.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

#Display the model architecture
CNN_AE.summary()
# Out:
# 2025-01-27 05:04:05.368929: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-27 05:04:05.849653: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46614 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:1d:00.0, compute capability: 8.6
# 2025-01-27 05:04:05.850393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46614 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:1e:00.0, compute capability: 8.6
# 2025-01-27 05:04:05.850938: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46614 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:1f:00.0, compute capability: 8.6
# 2025-01-27 05:04:05.851458: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 46614 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:20:00.0, compute capability: 8.6
# 2025-01-27 05:04:05.851972: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 46614 MB memory:  -> device: 4, name: NVIDIA RTX A6000, pci bus id: 0000:21:00.0, compute capability: 8.6
# 2025-01-27 05:04:05.852465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 46614 MB memory:  -> device: 5, name: NVIDIA RTX A6000, pci bus id: 0000:22:00.0, compute capability: 8.6
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512, 1)]          0
#
#  conv1d (Conv1D)             (None, 512, 5)            20
#
#  max_pooling1d (MaxPooling1D  (None, 256, 5)           0
#  )
#
#  conv1d_1 (Conv1D)           (None, 256, 5)            80
#
#  max_pooling1d_1 (MaxPooling  (None, 128, 5)           0
#  1D)
#
#  conv1d_2 (Conv1D)           (None, 128, 3)            48
#
#  conv1d_3 (Conv1D)           (None, 128, 5)            50
#
#  up_sampling1d (UpSampling1D  (None, 256, 5)           0
#  )
#
#  conv1d_4 (Conv1D)           (None, 256, 5)            80
#
#  up_sampling1d_1 (UpSampling  (None, 512, 5)           0
#  1D)
#
#  conv1d_5 (Conv1D)           (None, 512, 1)            16
#
# =================================================================
# Total params: 294
# Trainable params: 294
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ##### Train the model
tic = time.perf_counter()
for n in ([7,6,5,4,3]):  
    # training in a cycle with increasing batch size  . IF i increase the size to 10 from 7 then the train process just stops after 5th cycle and this is because of the GPU memory issue.

    batch_size = 2**n  
    
    history = CNN_AE.fit(scaled_X_train, scaled_y_train,
        epochs=50,
        batch_size=batch_size,
        validation_data=(scaled_X_test, scaled_y_test),callbacks=[model_checkpoint_callback])
    
    loss_save = history.history['loss']
    val_loss_save = history.history['val_loss']
    if n in ([6,5,4,3]):
        
        loss_sum = np.concatenate((loss_sum, loss_save), axis = 0)
        val_loss_sum = np.concatenate((val_loss_sum, val_loss_save), axis = 0)
    else:
   
        loss_sum = loss_save
        val_loss_sum = val_loss_save  

    plot_losses(loss_sum,val_loss_sum)

toc = time.perf_counter()
print(f"Execution time {toc - tic:0.4f} seconds")
# Out:
# Epoch 1/50
# 2025-01-27 05:04:11.202526: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8801
# 24/24 [==============================] - ETA: 0s - loss: 0.1196 - accuracy: 6.5984e-07
# Epoch 1: val_loss improved from inf to 0.10141, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 7s 93ms/step - loss: 0.1196 - accuracy: 6.5984e-07 - val_loss: 0.1014 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0759 - accuracy: 6.5984e-07
# Epoch 2: val_loss improved from 0.10141 to 0.03956, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0759 - accuracy: 6.5984e-07 - val_loss: 0.0396 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0342 - accuracy: 1.3872e-06
# Epoch 3: val_loss improved from 0.03956 to 0.03081, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0341 - accuracy: 1.3197e-06 - val_loss: 0.0308 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0296 - accuracy: 1.3872e-06
# Epoch 4: val_loss improved from 0.03081 to 0.02839, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0295 - accuracy: 1.3197e-06 - val_loss: 0.0284 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0276 - accuracy: 1.3872e-06
# Epoch 5: val_loss improved from 0.02839 to 0.02679, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0275 - accuracy: 1.3197e-06 - val_loss: 0.0268 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0264 - accuracy: 1.3872e-06
# Epoch 6: val_loss improved from 0.02679 to 0.02585, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0264 - accuracy: 1.3197e-06 - val_loss: 0.0258 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0257 - accuracy: 1.3269e-06
# Epoch 7: val_loss improved from 0.02585 to 0.02526, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0257 - accuracy: 1.3197e-06 - val_loss: 0.0253 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0253 - accuracy: 1.3872e-06
# Epoch 8: val_loss improved from 0.02526 to 0.02496, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0253 - accuracy: 1.3197e-06 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 1.3872e-06
# Epoch 9: val_loss improved from 0.02496 to 0.02486, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0252 - accuracy: 1.3197e-06 - val_loss: 0.0249 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0252 - accuracy: 6.9358e-07
# Epoch 10: val_loss improved from 0.02486 to 0.02485, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0252 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 6.9358e-07
# Epoch 11: val_loss improved from 0.02485 to 0.02482, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0252 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0252 - accuracy: 6.9358e-07
# Epoch 12: val_loss improved from 0.02482 to 0.02482, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0252 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 6.9358e-07
# Epoch 13: val_loss improved from 0.02482 to 0.02481, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 1.3872e-06
# Epoch 14: val_loss did not improve from 0.02481
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0251 - accuracy: 1.3197e-06 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 1.3872e-06
# Epoch 15: val_loss did not improve from 0.02481
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0251 - accuracy: 1.3197e-06 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0252 - accuracy: 6.6343e-07
# Epoch 16: val_loss improved from 0.02481 to 0.02480, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0252 - accuracy: 6.9358e-07
# Epoch 17: val_loss improved from 0.02480 to 0.02480, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0252 - accuracy: 1.3872e-06
# Epoch 18: val_loss improved from 0.02480 to 0.02479, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0251 - accuracy: 1.3197e-06 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0252 - accuracy: 6.9358e-07
# Epoch 19: val_loss did not improve from 0.02479
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0252 - accuracy: 6.9358e-07
# Epoch 20: val_loss improved from 0.02479 to 0.02478, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0251 - accuracy: 6.6343e-07
# Epoch 21: val_loss did not improve from 0.02478
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 6.9358e-07
# Epoch 22: val_loss did not improve from 0.02478
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 1.3872e-06
# Epoch 23: val_loss improved from 0.02478 to 0.02478, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0251 - accuracy: 1.3197e-06 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 6.9358e-07
# Epoch 24: val_loss did not improve from 0.02478
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 6.9358e-07
# Epoch 25: val_loss did not improve from 0.02478
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 6.9358e-07
# Epoch 26: val_loss improved from 0.02478 to 0.02476, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 6.5984e-07
# Epoch 27: val_loss improved from 0.02476 to 0.02476, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 6.5984e-07
# Epoch 28: val_loss improved from 0.02476 to 0.02475, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0251 - accuracy: 6.6343e-07
# Epoch 29: val_loss did not improve from 0.02475
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 6.9358e-07
# Epoch 30: val_loss did not improve from 0.02475
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 6.9358e-07
# Epoch 31: val_loss improved from 0.02475 to 0.02474, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0251 - accuracy: 6.6343e-07
# Epoch 32: val_loss did not improve from 0.02474
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 6.9358e-07
# Epoch 33: val_loss did not improve from 0.02474
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 1.3872e-06
# Epoch 34: val_loss improved from 0.02474 to 0.02473, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0251 - accuracy: 1.3197e-06 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 6.9358e-07
# Epoch 35: val_loss improved from 0.02473 to 0.02473, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 6.9358e-07
# Epoch 36: val_loss did not improve from 0.02473
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0248 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0251 - accuracy: 6.9358e-07
# Epoch 37: val_loss improved from 0.02473 to 0.02472, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 27ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 38: val_loss improved from 0.02472 to 0.02471, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0251 - accuracy: 6.6343e-07
# Epoch 39: val_loss did not improve from 0.02471
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 6.9358e-07
# Epoch 40: val_loss improved from 0.02471 to 0.02471, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0251 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 6.9358e-07
# Epoch 41: val_loss improved from 0.02471 to 0.02470, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0251 - accuracy: 1.3197e-06 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0251 - accuracy: 1.3269e-06
# Epoch 42: val_loss did not improve from 0.02470
# 24/24 [==============================] - 1s 23ms/step - loss: 0.0250 - accuracy: 1.3197e-06 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 43: val_loss did not improve from 0.02470
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 6.9358e-07
# Epoch 44: val_loss improved from 0.02470 to 0.02469, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 26ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 6.9358e-07
# Epoch 45: val_loss improved from 0.02469 to 0.02469, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 46: val_loss improved from 0.02469 to 0.02468, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 0.0000e+00
# Epoch 47: val_loss did not improve from 0.02468
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0249 - accuracy: 6.9358e-07
# Epoch 48: val_loss did not improve from 0.02468
# 24/24 [==============================] - 1s 24ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 22/24 [==========================>...] - ETA: 0s - loss: 0.0250 - accuracy: 6.9358e-07
# Epoch 49: val_loss improved from 0.02468 to 0.02467, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 50: val_loss improved from 0.02467 to 0.02466, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 24/24 [==============================] - 1s 25ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 1: val_loss improved from 0.02466 to 0.02465, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 25ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 2: val_loss improved from 0.02465 to 0.02464, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0251 - accuracy: 6.6343e-07
# Epoch 3: val_loss did not improve from 0.02464
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 4: val_loss did not improve from 0.02464
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 5: val_loss improved from 0.02464 to 0.02463, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 6.5984e-07
# Epoch 6: val_loss improved from 0.02463 to 0.02461, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 1.3197e-06
# Epoch 7: val_loss improved from 0.02461 to 0.02461, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0250 - accuracy: 1.3197e-06 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0250 - accuracy: 6.6343e-07
# Epoch 8: val_loss improved from 0.02461 to 0.02459, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 6.6343e-07
# Epoch 9: val_loss improved from 0.02459 to 0.02459, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0250 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 6.6343e-07
# Epoch 10: val_loss improved from 0.02459 to 0.02458, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 6.5984e-07
# Epoch 11: val_loss did not improve from 0.02458
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 1.3269e-06
# Epoch 12: val_loss improved from 0.02458 to 0.02455, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0249 - accuracy: 1.3197e-06 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 6.6343e-07
# Epoch 13: val_loss did not improve from 0.02455
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 6.6343e-07
# Epoch 14: val_loss did not improve from 0.02455
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0247 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 6.5984e-07
# Epoch 15: val_loss improved from 0.02455 to 0.02453, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 6.5984e-07
# Epoch 16: val_loss did not improve from 0.02453
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 6.6343e-07
# Epoch 17: val_loss did not improve from 0.02453
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0246 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 6.6343e-07
# Epoch 18: val_loss did not improve from 0.02453
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 19: val_loss improved from 0.02453 to 0.02452, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 20: val_loss improved from 0.02452 to 0.02451, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 6.5984e-07
# Epoch 21: val_loss improved from 0.02451 to 0.02448, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 1.3269e-06
# Epoch 22: val_loss improved from 0.02448 to 0.02448, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0248 - accuracy: 1.3197e-06 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0249 - accuracy: 6.6343e-07
# Epoch 23: val_loss did not improve from 0.02448
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0249 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 45/47 [===========================>..] - ETA: 0s - loss: 0.0248 - accuracy: 1.3563e-06
# Epoch 24: val_loss improved from 0.02448 to 0.02444, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0248 - accuracy: 1.3197e-06 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 25: val_loss did not improve from 0.02444
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 26: val_loss improved from 0.02444 to 0.02443, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 27: val_loss did not improve from 0.02443
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 6.5984e-07
# Epoch 28: val_loss improved from 0.02443 to 0.02441, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 29: val_loss did not improve from 0.02441
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 30: val_loss did not improve from 0.02441
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 1.3197e-06
# Epoch 31: val_loss did not improve from 0.02441
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0248 - accuracy: 1.3197e-06 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 32: val_loss did not improve from 0.02441
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 33: val_loss did not improve from 0.02441
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 34: val_loss improved from 0.02441 to 0.02436, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 35: val_loss did not improve from 0.02436
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0248 - accuracy: 6.6343e-07
# Epoch 36: val_loss improved from 0.02436 to 0.02436, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 37: val_loss did not improve from 0.02436
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 38: val_loss did not improve from 0.02436
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 44/47 [===========================>..] - ETA: 0s - loss: 0.0248 - accuracy: 6.9358e-07
# Epoch 39: val_loss improved from 0.02436 to 0.02435, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0248 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 40: val_loss did not improve from 0.02435
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 41: val_loss improved from 0.02435 to 0.02434, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 42: val_loss improved from 0.02434 to 0.02430, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 6.5984e-07
# Epoch 43: val_loss improved from 0.02430 to 0.02429, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 44: val_loss did not improve from 0.02429
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 1.3269e-06
# Epoch 45: val_loss improved from 0.02429 to 0.02427, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0247 - accuracy: 1.3197e-06 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 0.0000e+00
# Epoch 46: val_loss improved from 0.02427 to 0.02427, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 47: val_loss did not improve from 0.02427
# 47/47 [==============================] - 1s 21ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 6.5984e-07
# Epoch 48: val_loss did not improve from 0.02427
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 49: val_loss did not improve from 0.02427
# 47/47 [==============================] - 1s 22ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.6343e-07
# Epoch 50: val_loss improved from 0.02427 to 0.02425, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 47/47 [==============================] - 1s 23ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 6.5984e-07
# Epoch 1: val_loss did not improve from 0.02425
# 93/93 [==============================] - 2s 22ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0245 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 2: val_loss did not improve from 0.02425
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 3: val_loss improved from 0.02425 to 0.02421, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0247 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.6343e-07
# Epoch 4: val_loss did not improve from 0.02421
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 5: val_loss did not improve from 0.02421
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.7072e-07
# Epoch 6: val_loss improved from 0.02421 to 0.02418, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 7: val_loss did not improve from 0.02418
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.7072e-07
# Epoch 8: val_loss improved from 0.02418 to 0.02418, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 9: val_loss did not improve from 0.02418
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.6343e-07
# Epoch 10: val_loss improved from 0.02418 to 0.02415, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.6343e-07
# Epoch 11: val_loss did not improve from 0.02415
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 12: val_loss did not improve from 0.02415
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0247 - accuracy: 6.7072e-07
# Epoch 13: val_loss improved from 0.02415 to 0.02413, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 14: val_loss did not improve from 0.02413
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 15: val_loss did not improve from 0.02413
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 16: val_loss did not improve from 0.02413
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.6343e-07
# Epoch 17: val_loss improved from 0.02413 to 0.02412, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.6343e-07
# Epoch 18: val_loss did not improve from 0.02412
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 19: val_loss improved from 0.02412 to 0.02412, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.7072e-07
# Epoch 20: val_loss did not improve from 0.02412
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.6343e-07
# Epoch 21: val_loss did not improve from 0.02412
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.6343e-07
# Epoch 22: val_loss improved from 0.02412 to 0.02411, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 23: val_loss did not improve from 0.02411
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 24: val_loss did not improve from 0.02411
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 25: val_loss did not improve from 0.02411
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.7072e-07
# Epoch 26: val_loss improved from 0.02411 to 0.02410, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 6.5984e-07
# Epoch 27: val_loss did not improve from 0.02410
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0244 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.6343e-07
# Epoch 28: val_loss did not improve from 0.02410
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0243 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 29: val_loss improved from 0.02410 to 0.02410, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 30: val_loss did not improve from 0.02410
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.7072e-07
# Epoch 31: val_loss did not improve from 0.02410
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 32: val_loss improved from 0.02410 to 0.02408, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.7072e-07
# Epoch 33: val_loss did not improve from 0.02408
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.7072e-07
# Epoch 34: val_loss improved from 0.02408 to 0.02407, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 1.3414e-06
# Epoch 35: val_loss did not improve from 0.02407
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 1.3197e-06 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0246 - accuracy: 6.6343e-07
# Epoch 36: val_loss improved from 0.02407 to 0.02406, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 1.3197e-06
# Epoch 37: val_loss did not improve from 0.02406
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 1.3197e-06 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 6.5984e-07
# Epoch 38: val_loss did not improve from 0.02406
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0246 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 1.3269e-06
# Epoch 39: val_loss did not improve from 0.02406
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 1.3197e-06 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 40: val_loss did not improve from 0.02406
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 6.5984e-07
# Epoch 41: val_loss did not improve from 0.02406
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 42: val_loss did not improve from 0.02406
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 43: val_loss improved from 0.02406 to 0.02405, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 44: val_loss did not improve from 0.02405
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 45: val_loss did not improve from 0.02405
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 46: val_loss did not improve from 0.02405
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.7072e-07
# Epoch 47: val_loss did not improve from 0.02405
# 93/93 [==============================] - 2s 20ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.7072e-07
# Epoch 48: val_loss did not improve from 0.02405
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 91/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.7072e-07
# Epoch 49: val_loss did not improve from 0.02405
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 50: val_loss improved from 0.02405 to 0.02404, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 93/93 [==============================] - 2s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# Epoch 1: val_loss did not improve from 0.02404
# 185/185 [==============================] - 4s 21ms/step - loss: 0.0245 - accuracy: 6.5984e-07 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 1.3269e-06
# Epoch 2: val_loss did not improve from 0.02404
# 185/185 [==============================] - 4s 20ms/step - loss: 0.0245 - accuracy: 1.3197e-06 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 1.3197e-06
# Epoch 3: val_loss did not improve from 0.02404
# 185/185 [==============================] - 4s 20ms/step - loss: 0.0245 - accuracy: 1.3197e-06 - val_loss: 0.0241 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0245 - accuracy: 6.6343e-07
# ...
# 185/185 [==============================] - 4s 20ms/step - loss: 0.0244 - accuracy: 6.5984e-07 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 1/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0244 - accuracy: 1.3269e-06
# Epoch 1: val_loss did not improve from 0.02383
# 370/370 [==============================] - 8s 20ms/step - loss: 0.0244 - accuracy: 1.3197e-06 - val_loss: 0.0240 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0244 - accuracy: 1.3269e-06
# Epoch 2: val_loss improved from 0.02383 to 0.02374, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0244 - accuracy: 1.3197e-06 - val_loss: 0.0237 - val_accuracy: 0.0000e+00
# Epoch 3/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0244 - accuracy: 6.5984e-07
# Epoch 3: val_loss did not improve from 0.02374
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0244 - accuracy: 6.5984e-07 - val_loss: 0.0242 - val_accuracy: 0.0000e+00
# Epoch 4/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0243 - accuracy: 6.5984e-07
# Epoch 4: val_loss did not improve from 0.02374
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0243 - accuracy: 6.5984e-07 - val_loss: 0.0238 - val_accuracy: 0.0000e+00
# Epoch 5/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0242 - accuracy: 1.3269e-06
# Epoch 5: val_loss did not improve from 0.02374
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0242 - accuracy: 1.3197e-06 - val_loss: 0.0238 - val_accuracy: 0.0000e+00
# Epoch 6/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 6.5984e-07
# Epoch 6: val_loss improved from 0.02374 to 0.02341, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0242 - accuracy: 6.5984e-07 - val_loss: 0.0234 - val_accuracy: 0.0000e+00
# Epoch 7/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0240 - accuracy: 1.3197e-06
# Epoch 7: val_loss improved from 0.02341 to 0.02339, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0240 - accuracy: 1.3197e-06 - val_loss: 0.0234 - val_accuracy: 0.0000e+00
# Epoch 8/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 6.5984e-07
# Epoch 8: val_loss improved from 0.02339 to 0.02319, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0239 - accuracy: 6.5984e-07 - val_loss: 0.0232 - val_accuracy: 0.0000e+00
# Epoch 9/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 1.3197e-06
# Epoch 9: val_loss improved from 0.02319 to 0.02315, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0238 - accuracy: 1.3197e-06 - val_loss: 0.0231 - val_accuracy: 0.0000e+00
# Epoch 10/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 1.3197e-06
# Epoch 10: val_loss did not improve from 0.02315
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0237 - accuracy: 1.3197e-06 - val_loss: 0.0233 - val_accuracy: 0.0000e+00
# Epoch 11/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 1.3269e-06
# Epoch 11: val_loss improved from 0.02315 to 0.02301, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0237 - accuracy: 1.3197e-06 - val_loss: 0.0230 - val_accuracy: 0.0000e+00
# Epoch 12/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 1.3269e-06
# Epoch 12: val_loss improved from 0.02301 to 0.02294, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0236 - accuracy: 1.3197e-06 - val_loss: 0.0229 - val_accuracy: 0.0000e+00
# Epoch 13/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 1.3197e-06
# Epoch 13: val_loss did not improve from 0.02294
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0236 - accuracy: 1.3197e-06 - val_loss: 0.0237 - val_accuracy: 0.0000e+00
# Epoch 14/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 1.3197e-06
# Epoch 14: val_loss improved from 0.02294 to 0.02283, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0236 - accuracy: 1.3197e-06 - val_loss: 0.0228 - val_accuracy: 0.0000e+00
# Epoch 15/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 1.3197e-06
# Epoch 15: val_loss improved from 0.02283 to 0.02277, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0235 - accuracy: 1.3197e-06 - val_loss: 0.0228 - val_accuracy: 0.0000e+00
# Epoch 16/50
# 369/370 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 1.3233e-06
# Epoch 16: val_loss improved from 0.02277 to 0.02274, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0234 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 17/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 1.3197e-06
# Epoch 17: val_loss did not improve from 0.02274
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0234 - accuracy: 1.3197e-06 - val_loss: 0.0231 - val_accuracy: 0.0000e+00
# Epoch 18/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 1.3197e-06
# Epoch 18: val_loss improved from 0.02274 to 0.02273, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0234 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 19/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 1.3269e-06
# Epoch 19: val_loss improved from 0.02273 to 0.02270, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 20/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 1.3269e-06
# Epoch 20: val_loss improved from 0.02270 to 0.02265, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 21/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 1.3197e-06
# Epoch 21: val_loss did not improve from 0.02265
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 22/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 1.3269e-06
# Epoch 22: val_loss did not improve from 0.02265
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 23/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 1.3197e-06
# Epoch 23: val_loss did not improve from 0.02265
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0230 - val_accuracy: 0.0000e+00
# Epoch 24/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 1.3197e-06
# Epoch 24: val_loss improved from 0.02265 to 0.02259, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 25/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 25: val_loss improved from 0.02259 to 0.02258, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 26/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 1.3269e-06
# Epoch 26: val_loss improved from 0.02258 to 0.02257, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 27/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 1.3269e-06
# Epoch 27: val_loss did not improve from 0.02257
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 28/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 1.3197e-06
# Epoch 28: val_loss improved from 0.02257 to 0.02257, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0233 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 29/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 29: val_loss did not improve from 0.02257
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 30/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 30: val_loss improved from 0.02257 to 0.02255, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 31/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 31: val_loss did not improve from 0.02255
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 32/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 32: val_loss improved from 0.02255 to 0.02252, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 33/50
# 369/370 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 1.3233e-06
# Epoch 33: val_loss improved from 0.02252 to 0.02251, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 34/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 34: val_loss did not improve from 0.02251
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 35/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 1.3269e-06
# Epoch 35: val_loss did not improve from 0.02251
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 36/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 1.3269e-06
# Epoch 36: val_loss did not improve from 0.02251
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 37/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 37: val_loss did not improve from 0.02251
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0227 - val_accuracy: 0.0000e+00
# Epoch 38/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 38: val_loss improved from 0.02251 to 0.02249, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 39/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 1.3269e-06
# Epoch 39: val_loss improved from 0.02249 to 0.02248, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0231 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 40/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 40: val_loss did not improve from 0.02248
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 41/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 41: val_loss did not improve from 0.02248
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 42/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0232 - accuracy: 1.3269e-06
# Epoch 42: val_loss did not improve from 0.02248
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0226 - val_accuracy: 0.0000e+00
# Epoch 43/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 1.3197e-06
# Epoch 43: val_loss improved from 0.02248 to 0.02248, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0231 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 44/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 1.3197e-06
# Epoch 44: val_loss did not improve from 0.02248
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0231 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 45/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 45: val_loss did not improve from 0.02248
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 46/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 1.3197e-06
# Epoch 46: val_loss did not improve from 0.02248
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0232 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 47/50
# 368/370 [============================>.] - ETA: 0s - loss: 0.0231 - accuracy: 1.3269e-06
# Epoch 47: val_loss did not improve from 0.02248
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0231 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 48/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 1.3197e-06
# Epoch 48: val_loss improved from 0.02248 to 0.02246, saving model to outputs/best_1d_cnn_model_v1_bkp.h5
# 370/370 [==============================] - 8s 20ms/step - loss: 0.0231 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 49/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 1.3197e-06
# Epoch 49: val_loss did not improve from 0.02246
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0231 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Epoch 50/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 1.3197e-06
# Epoch 50: val_loss did not improve from 0.02246
# 370/370 [==============================] - 7s 20ms/step - loss: 0.0231 - accuracy: 1.3197e-06 - val_loss: 0.0225 - val_accuracy: 0.0000e+00
# Execution time 747.6524 seconds

# %%
#Compute predicted values
prediction_test = CNN_AE.predict(scaled_X_test)
print(prediction_test.shape)


# # Create a StandardScaler object


plt.plot(t,prediction_test[50],label = 'prediction')
plt.plot(t,scaled_y_test[50], label = 'ground truth')
plt.legend()
plt.show()
# Out:
# 24/24 [==============================] - 1s 6ms/step
# (740, 512, 1)

# %%
r2_test = r2_score(scaled_y_test.reshape(-1), prediction_test.reshape(-1))
print(r2_test)

r2_test_set = [r2_score(scaled_y_test[i].reshape(-1), prediction_test[i].reshape(-1)) for i in range(len(scaled_y_test))]
print(len(r2_test_set))
# Out:
# 0.10174946598401757
# 740

# %%
above = np.sum(np.array(r2_test_set) > 0.90)/740 * 100
print('$R^{2}$ above 90 :',above)

above1 = np.sum(np.array(r2_test_set) > 0.95)/740 * 100
print('$R^{2}$ above 95 :',above1)
# Out:
# $R^{2}$ above 90 : 0.0
# $R^{2}$ above 95 : 0.0

# %%
plt.figure(figsize=(8, 6))  # Adjust the width and height as needed


plt.plot(omega_y_test, r2_test_set, '*', markersize=4, color='g')
# plt.plot(ω_test, r2_test_set, '.', color='red')
# Plot highlighted points in red

for i in [2, 100, 250, 600]:
    plt.plot(omega_y_test[i], r2_test_set[i], 'X',markersize=9, color='purple')


for _ in np.unique(np.round(np.abs(E[:, np.newaxis] - E), 4)):
    plt.axvline(_, c='y', alpha=0.3)
# plt.axhline(r2_test, color='blue', linestyle='--')  # Plot the horizontal line for r2_test
# plt.text(0.14, r2_test, f"Avg. $R^{2}$ = {r2_test:.4}", color='blue',fontsize=12,weight='bold', va='bottom', ha='left')  # Display the value of r2_test on the plot
plt.xlabel(r"$\omega$",fontsize=15)
plt.ylabel(r"$R^2$",fontsize=15)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
# plt.title("$\omega$ vs. $R^2$ score")
#plt.title("Amplitude = 1", fontsize = 14)
# plt.savefig('R2_Omega_v4_1.png')
plt.savefig('outputs/A1_CNN_v1.pdf', dpi=1000, bbox_inches='tight')
plt.show()

# %%
from matplotlib import rcParams

rcParams['font.weight'] = 'bold'
rcParams['font.size'] = 17
labels = ['a', 'b', 'c', 'd']

plt.figure(figsize=(20, 20), dpi=300)
arr =  np.array([2, 100, 250, 600])
j=0
for i in arr:
    plt.subplot(2, 2, j+1)
    plt.plot(t,prediction_test[i, :], label = "pred",color = 'green', linewidth=3)
    plt.plot(t, scaled_y_test[ i, :], label = "target", color = 'blue', linewidth=3  )
    plt.plot( t, scaled_X_test[i, :],'--', label = "input", color = 'orange', linewidth=3 )
    #plt.plot( t, F0 * np.sin(ω_train[i] * t),'--', label = "input",linewidth=4 )
    plt.legend(loc='upper right')
    #plt.title("ω = {}".format(omega_y_test[i]),fontsize=22)
    plt.xlabel("Time",fontsize=22)
    plt.xticks(fontsize = 18)
    plt.yticks(fontsize = 18)
#     plt.ylabel("Expectation Value of Magnetization",  fontsize=27)
    plt.annotate(labels[j], xy=(0.05, 0.95), xycoords='axes fraction', fontsize=25,
                 ha='center', va='center',
                 bbox=dict(boxstyle='circle', fc='w', ec='k', lw=1, alpha=0.7))
    j=j+1

# plt.savefig('outputs/Achaotic25TEST.pdf', dpi=700, bbox_inches='tight')
plt.show()
