# %% [markdown]
# ### Case 2: For Amplitude (A) = 10.  VAE model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from qutip import *
from tcn import TCN, tcn_full_summary
from tqdm import tqdm
import time

from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score,r2_score
from keras.losses import Huber
import keras.backend as K

from utilis import QuCal, pre_processing, plot_losses
from model import TCN_VAE_AE
# Out:
# 2025-03-11 07:28:22.178761: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-11 07:28:22.289515: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
Y = np.load('../dataset/Data_Y.npy', allow_pickle=True)
Y.shape
# Out:
# (3700, 512, 1)

# %%
full_ω, t, E = QuCal()
# Out:
# lowest frequency for the data:  4.260000000000001
# number of frewuencies: 3700

# %%
scaled_X_train, scaled_y_train,scaled_X_test,scaled_y_test, omega_y_test = pre_processing(Y , full_ω,t, F0 = 10 )
# Out:
# 100%|███████████████████████████████████| 3700/3700 [00:00<00:00, 164459.85it/s]
# omega values for input data:  (3700,)
# x data : (3700, 512)
# scaled_X_train:  (2960, 512, 1)
# scaled_y_train:  (2960, 512, 1)
# scaled_X_test:  (740, 512, 1)
# scaled_y_test:  (740, 512, 1)
# scaled_X_train max:  1.0
# scaled_X_train min:  3.661732e-11
# scaled_y_train max:  1.0
# scaled_y_train min :  0.0006483385

# %%
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0"])

with mirrored_strategy.scope():
    

    TCN_AE = TCN_VAE_AE(input_size=512, f1=12, f2=12,f3 = 10, latent_dim=10,max_pool = 2,dilation = [2,4,8])
    #Compile the model
    TCN_AE.compile(optimizer=Adam(learning_rate = 0.001), loss=Huber(delta=1.0))



#Define a callback to save the best model
checkpoint_filepath = 'outputs/best_1d_tcn_VAE_model_v10_bkp.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

#Display the model architecture
TCN_AE.summary()
# Out:
# 2025-03-11 07:28:36.879434: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-03-11 07:28:37.358647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46614 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:1d:00.0, compute capability: 8.6
# 2025-03-11 07:28:37.359368: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46614 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:1e:00.0, compute capability: 8.6
# 2025-03-11 07:28:37.359922: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46614 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:1f:00.0, compute capability: 8.6
# 2025-03-11 07:28:37.360412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 46614 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:20:00.0, compute capability: 8.6
# 2025-03-11 07:28:37.361004: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 46614 MB memory:  -> device: 4, name: NVIDIA RTX A6000, pci bus id: 0000:21:00.0, compute capability: 8.6
# 2025-03-11 07:28:37.361540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 46614 MB memory:  -> device: 5, name: NVIDIA RTX A6000, pci bus id: 0000:22:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 1)]     0           []
#
#  tcn (TCN)                      (None, 512, 12)      2292        ['input_1[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 256, 12)      0           ['tcn[0][0]']
#
#  tcn_1 (TCN)                    (None, 256, 12)      2664        ['max_pooling1d[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 128, 12)     0           ['tcn_1[0][0]']
#
#  tcn_2 (TCN)                    (None, 128, 10)      2050        ['max_pooling1d_1[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 64, 10)      0           ['tcn_2[0][0]']
#
#  flatten (Flatten)              (None, 640)          0           ['max_pooling1d_2[0][0]']
#
#  dense (Dense)                  (None, 10)           6410        ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 10)           6410        ['flatten[0][0]']
#
#  lambda (Lambda)                (None, 10)           0           ['dense[0][0]',
#                                                                   'dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 640)          7040        ['lambda[0][0]']
#
#  reshape (Reshape)              (None, 64, 10)       0           ['dense_2[0][0]']
#
#  tcn_3 (TCN)                    (None, 64, 10)       1860        ['reshape[0][0]']
#
#  up_sampling1d (UpSampling1D)   (None, 128, 10)      0           ['tcn_3[0][0]']
#
#  tcn_4 (TCN)                    (None, 128, 12)      2724        ['up_sampling1d[0][0]']
#
#  up_sampling1d_1 (UpSampling1D)  (None, 256, 12)     0           ['tcn_4[0][0]']
#
#  tcn_5 (TCN)                    (None, 256, 12)      2664        ['up_sampling1d_1[0][0]']
#
#  up_sampling1d_2 (UpSampling1D)  (None, 512, 12)     0           ['tcn_5[0][0]']
#
#  dense_3 (Dense)                (None, 512, 1)       13          ['up_sampling1d_2[0][0]']
#
# ==================================================================================================
# Total params: 34,127
# Trainable params: 34,127
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# ##### Train the model
tic = time.perf_counter()
for n in ([7,6,5,4,3]):  
    # training in a cycle with increasing batch size  . IF i increase the size to 10 from 7 then the train process just stops after 5th cycle and this is because of the GPU memory issue.

    batch_size = 2**n  
    
    history = TCN_AE.fit(scaled_X_train, scaled_y_train,
        epochs=50,
        batch_size=batch_size,
        validation_data=(scaled_X_test, scaled_y_test),callbacks=[model_checkpoint_callback])
    
    loss_save = history.history['loss']
    val_loss_save = history.history['val_loss']
    if n in ([6,5,4,3]):
        
        loss_sum = np.concatenate((loss_sum, loss_save), axis = 0)
        val_loss_sum = np.concatenate((val_loss_sum, val_loss_save), axis = 0)
    else:
   
        loss_sum = loss_save
        val_loss_sum = val_loss_save  

    plot_losses(loss_sum,val_loss_sum)

toc = time.perf_counter()
print(f"Execution time {toc - tic:0.4f} seconds")
# Out:
# Epoch 1/50
# 2025-03-11 07:28:48.661470: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8801
# 2025-03-11 07:28:49.348076: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:648] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 24/24 [==============================] - ETA: 0s - loss: 0.2038
# Epoch 1: val_loss improved from inf to 0.07333, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 14s 176ms/step - loss: 0.2038 - val_loss: 0.0733
# Epoch 2/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0384
# Epoch 2: val_loss improved from 0.07333 to 0.02005, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0384 - val_loss: 0.0200
# Epoch 3/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0201
# Epoch 3: val_loss improved from 0.02005 to 0.01888, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0201 - val_loss: 0.0189
# Epoch 4/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 4: val_loss improved from 0.01888 to 0.01857, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0193 - val_loss: 0.0186
# Epoch 5/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0189
# Epoch 5: val_loss improved from 0.01857 to 0.01850, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0189 - val_loss: 0.0185
# Epoch 6/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0190
# Epoch 6: val_loss improved from 0.01850 to 0.01834, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0189 - val_loss: 0.0183
# Epoch 7/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0187
# Epoch 7: val_loss improved from 0.01834 to 0.01818, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0187 - val_loss: 0.0182
# Epoch 8/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0186
# Epoch 8: val_loss improved from 0.01818 to 0.01815, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0186 - val_loss: 0.0181
# Epoch 9/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0185
# Epoch 9: val_loss improved from 0.01815 to 0.01806, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0186 - val_loss: 0.0181
# Epoch 10/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0185
# Epoch 10: val_loss improved from 0.01806 to 0.01794, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0185 - val_loss: 0.0179
# Epoch 11/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0183
# Epoch 11: val_loss improved from 0.01794 to 0.01787, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0184 - val_loss: 0.0179
# Epoch 12/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0183
# Epoch 12: val_loss improved from 0.01787 to 0.01776, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0183 - val_loss: 0.0178
# Epoch 13/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0181
# Epoch 13: val_loss improved from 0.01776 to 0.01761, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0181 - val_loss: 0.0176
# Epoch 14/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0180
# Epoch 14: val_loss did not improve from 0.01761
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0180 - val_loss: 0.0176
# Epoch 15/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0180
# Epoch 15: val_loss improved from 0.01761 to 0.01742, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0180 - val_loss: 0.0174
# Epoch 16/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0178
# Epoch 16: val_loss improved from 0.01742 to 0.01721, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0178 - val_loss: 0.0172
# Epoch 17/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0177
# Epoch 17: val_loss improved from 0.01721 to 0.01703, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0177 - val_loss: 0.0170
# Epoch 18/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0175
# Epoch 18: val_loss improved from 0.01703 to 0.01693, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0175 - val_loss: 0.0169
# Epoch 19/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0173
# Epoch 19: val_loss improved from 0.01693 to 0.01674, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0173 - val_loss: 0.0167
# Epoch 20/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0172
# Epoch 20: val_loss improved from 0.01674 to 0.01662, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0172 - val_loss: 0.0166
# Epoch 21/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0170
# Epoch 21: val_loss improved from 0.01662 to 0.01654, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0170 - val_loss: 0.0165
# Epoch 22/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0169
# Epoch 22: val_loss improved from 0.01654 to 0.01652, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0169 - val_loss: 0.0165
# Epoch 23/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0168
# Epoch 23: val_loss improved from 0.01652 to 0.01626, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 24/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0167
# Epoch 24: val_loss improved from 0.01626 to 0.01617, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 25/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0166
# Epoch 25: val_loss improved from 0.01617 to 0.01610, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0166 - val_loss: 0.0161
# Epoch 26/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0165
# Epoch 26: val_loss improved from 0.01610 to 0.01610, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0165 - val_loss: 0.0161
# Epoch 27/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0165
# Epoch 27: val_loss improved from 0.01610 to 0.01601, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0165 - val_loss: 0.0160
# Epoch 28/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0165
# Epoch 28: val_loss improved from 0.01601 to 0.01593, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0165 - val_loss: 0.0159
# Epoch 29/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0164
# Epoch 29: val_loss did not improve from 0.01593
# 24/24 [==============================] - 1s 48ms/step - loss: 0.0164 - val_loss: 0.0160
# Epoch 30/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0163
# Epoch 30: val_loss improved from 0.01593 to 0.01578, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0163 - val_loss: 0.0158
# Epoch 31/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0162
# Epoch 31: val_loss did not improve from 0.01578
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0162 - val_loss: 0.0158
# Epoch 32/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0161
# Epoch 32: val_loss did not improve from 0.01578
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0161 - val_loss: 0.0159
# Epoch 33/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0161
# Epoch 33: val_loss improved from 0.01578 to 0.01571, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0161 - val_loss: 0.0157
# Epoch 34/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0160
# Epoch 34: val_loss improved from 0.01571 to 0.01551, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0160 - val_loss: 0.0155
# Epoch 35/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0161
# Epoch 35: val_loss improved from 0.01551 to 0.01543, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0161 - val_loss: 0.0154
# Epoch 36/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0158
# Epoch 36: val_loss improved from 0.01543 to 0.01533, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0158 - val_loss: 0.0153
# Epoch 37/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0157
# Epoch 37: val_loss improved from 0.01533 to 0.01495, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0158 - val_loss: 0.0150
# Epoch 38/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0156
# Epoch 38: val_loss did not improve from 0.01495
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0156 - val_loss: 0.0151
# Epoch 39/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0152
# Epoch 39: val_loss improved from 0.01495 to 0.01460, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0152 - val_loss: 0.0146
# Epoch 40/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0146
# Epoch 40: val_loss improved from 0.01460 to 0.01381, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0145 - val_loss: 0.0138
# Epoch 41/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0129
# Epoch 41: val_loss improved from 0.01381 to 0.01170, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0129 - val_loss: 0.0117
# Epoch 42/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0102
# Epoch 42: val_loss improved from 0.01170 to 0.00873, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0102 - val_loss: 0.0087
# Epoch 43/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0078
# Epoch 43: val_loss improved from 0.00873 to 0.00710, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0078 - val_loss: 0.0071
# Epoch 44/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0064
# Epoch 44: val_loss improved from 0.00710 to 0.00605, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0064 - val_loss: 0.0061
# Epoch 45/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0056
# Epoch 45: val_loss improved from 0.00605 to 0.00533, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0055 - val_loss: 0.0053
# Epoch 46/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0050
# Epoch 46: val_loss improved from 0.00533 to 0.00489, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0050 - val_loss: 0.0049
# Epoch 47/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0047
# Epoch 47: val_loss improved from 0.00489 to 0.00454, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 48/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0043
# Epoch 48: val_loss improved from 0.00454 to 0.00422, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0043 - val_loss: 0.0042
# Epoch 49/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0039
# Epoch 49: val_loss improved from 0.00422 to 0.00398, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0039 - val_loss: 0.0040
# Epoch 50/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0037
# Epoch 50: val_loss improved from 0.00398 to 0.00368, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 1/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 1: val_loss improved from 0.00368 to 0.00319, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 3s 55ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 2/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0029
# Epoch 2: val_loss improved from 0.00319 to 0.00281, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 3s 57ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 3/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 3: val_loss improved from 0.00281 to 0.00248, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 4/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0022
# Epoch 4: val_loss improved from 0.00248 to 0.00220, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 5/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0019
# Epoch 5: val_loss improved from 0.00220 to 0.00198, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 6/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0017
# Epoch 6: val_loss improved from 0.00198 to 0.00179, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 7/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0015
# Epoch 7: val_loss improved from 0.00179 to 0.00160, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 8/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 8: val_loss improved from 0.00160 to 0.00148, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 9/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 9: val_loss improved from 0.00148 to 0.00129, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 10/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 10: val_loss improved from 0.00129 to 0.00120, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 11/50
# 47/47 [==============================] - ETA: 0s - loss: 9.9485e-04
# Epoch 11: val_loss improved from 0.00120 to 0.00109, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 48ms/step - loss: 9.9485e-04 - val_loss: 0.0011
# Epoch 12/50
# 47/47 [==============================] - ETA: 0s - loss: 8.9439e-04
# Epoch 12: val_loss improved from 0.00109 to 0.00097, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 3s 54ms/step - loss: 8.9439e-04 - val_loss: 9.6778e-04
# Epoch 13/50
# 47/47 [==============================] - ETA: 0s - loss: 8.2513e-04
# Epoch 13: val_loss improved from 0.00097 to 0.00090, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 53ms/step - loss: 8.2513e-04 - val_loss: 9.0015e-04
# Epoch 14/50
# 47/47 [==============================] - ETA: 0s - loss: 7.6390e-04
# Epoch 14: val_loss improved from 0.00090 to 0.00084, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 7.6390e-04 - val_loss: 8.3876e-04
# Epoch 15/50
# 47/47 [==============================] - ETA: 0s - loss: 7.0564e-04
# Epoch 15: val_loss improved from 0.00084 to 0.00077, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 7.0564e-04 - val_loss: 7.6510e-04
# Epoch 16/50
# 47/47 [==============================] - ETA: 0s - loss: 6.4744e-04
# Epoch 16: val_loss improved from 0.00077 to 0.00070, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 6.4744e-04 - val_loss: 6.9622e-04
# Epoch 17/50
# 47/47 [==============================] - ETA: 0s - loss: 5.9709e-04
# Epoch 17: val_loss improved from 0.00070 to 0.00064, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 5.9709e-04 - val_loss: 6.4142e-04
# Epoch 18/50
# 47/47 [==============================] - ETA: 0s - loss: 5.5016e-04
# Epoch 18: val_loss improved from 0.00064 to 0.00059, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 5.5016e-04 - val_loss: 5.9184e-04
# Epoch 19/50
# 47/47 [==============================] - ETA: 0s - loss: 5.2002e-04
# Epoch 19: val_loss improved from 0.00059 to 0.00058, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 5.2002e-04 - val_loss: 5.8088e-04
# Epoch 20/50
# 47/47 [==============================] - ETA: 0s - loss: 4.8524e-04
# Epoch 20: val_loss improved from 0.00058 to 0.00053, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 4.8524e-04 - val_loss: 5.2606e-04
# Epoch 21/50
# 47/47 [==============================] - ETA: 0s - loss: 4.5875e-04
# Epoch 21: val_loss improved from 0.00053 to 0.00048, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 4.5875e-04 - val_loss: 4.8395e-04
# Epoch 22/50
# 47/47 [==============================] - ETA: 0s - loss: 4.2680e-04
# Epoch 22: val_loss improved from 0.00048 to 0.00046, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 4.2680e-04 - val_loss: 4.6213e-04
# Epoch 23/50
# 47/47 [==============================] - ETA: 0s - loss: 4.0926e-04
# Epoch 23: val_loss improved from 0.00046 to 0.00044, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 4.0926e-04 - val_loss: 4.4251e-04
# Epoch 24/50
# 47/47 [==============================] - ETA: 0s - loss: 3.8969e-04
# Epoch 24: val_loss improved from 0.00044 to 0.00042, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 49ms/step - loss: 3.8969e-04 - val_loss: 4.2080e-04
# Epoch 25/50
# 47/47 [==============================] - ETA: 0s - loss: 3.7433e-04
# Epoch 25: val_loss improved from 0.00042 to 0.00041, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 53ms/step - loss: 3.7433e-04 - val_loss: 4.0547e-04
# Epoch 26/50
# 46/47 [============================>.] - ETA: 0s - loss: 3.6016e-04
# Epoch 26: val_loss improved from 0.00041 to 0.00039, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 3.6041e-04 - val_loss: 3.8547e-04
# Epoch 27/50
# 47/47 [==============================] - ETA: 0s - loss: 3.4779e-04
# Epoch 27: val_loss improved from 0.00039 to 0.00037, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 3.4779e-04 - val_loss: 3.7183e-04
# Epoch 28/50
# 47/47 [==============================] - ETA: 0s - loss: 3.3550e-04
# Epoch 28: val_loss improved from 0.00037 to 0.00037, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 3.3550e-04 - val_loss: 3.6538e-04
# Epoch 29/50
# 47/47 [==============================] - ETA: 0s - loss: 3.2579e-04
# Epoch 29: val_loss improved from 0.00037 to 0.00036, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 3.2579e-04 - val_loss: 3.5589e-04
# Epoch 30/50
# 47/47 [==============================] - ETA: 0s - loss: 3.1990e-04
# Epoch 30: val_loss improved from 0.00036 to 0.00034, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 3.1990e-04 - val_loss: 3.3943e-04
# Epoch 31/50
# 47/47 [==============================] - ETA: 0s - loss: 3.0724e-04
# Epoch 31: val_loss improved from 0.00034 to 0.00033, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 3.0724e-04 - val_loss: 3.2883e-04
# Epoch 32/50
# 47/47 [==============================] - ETA: 0s - loss: 3.0072e-04
# Epoch 32: val_loss improved from 0.00033 to 0.00033, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 3.0072e-04 - val_loss: 3.2631e-04
# Epoch 33/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.9203e-04
# Epoch 33: val_loss improved from 0.00033 to 0.00031, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 2.9203e-04 - val_loss: 3.1293e-04
# Epoch 34/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.8559e-04
# Epoch 34: val_loss improved from 0.00031 to 0.00030, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 2.8575e-04 - val_loss: 3.0492e-04
# Epoch 35/50
# 47/47 [==============================] - ETA: 0s - loss: 2.7898e-04
# Epoch 35: val_loss improved from 0.00030 to 0.00029, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 2.7898e-04 - val_loss: 2.9343e-04
# Epoch 36/50
# 47/47 [==============================] - ETA: 0s - loss: 2.7210e-04
# Epoch 36: val_loss improved from 0.00029 to 0.00029, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 2.7210e-04 - val_loss: 2.8927e-04
# Epoch 37/50
# 47/47 [==============================] - ETA: 0s - loss: 2.6637e-04
# Epoch 37: val_loss improved from 0.00029 to 0.00029, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 2.6637e-04 - val_loss: 2.8774e-04
# Epoch 38/50
# 47/47 [==============================] - ETA: 0s - loss: 2.6175e-04
# Epoch 38: val_loss improved from 0.00029 to 0.00027, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 2.6175e-04 - val_loss: 2.7292e-04
# Epoch 39/50
# 47/47 [==============================] - ETA: 0s - loss: 2.5239e-04
# Epoch 39: val_loss improved from 0.00027 to 0.00027, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 2.5239e-04 - val_loss: 2.7087e-04
# Epoch 40/50
# 47/47 [==============================] - ETA: 0s - loss: 2.4885e-04
# Epoch 40: val_loss improved from 0.00027 to 0.00026, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 2.4885e-04 - val_loss: 2.6485e-04
# Epoch 41/50
# 47/47 [==============================] - ETA: 0s - loss: 2.4266e-04
# Epoch 41: val_loss improved from 0.00026 to 0.00026, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 2.4266e-04 - val_loss: 2.5522e-04
# Epoch 42/50
# 47/47 [==============================] - ETA: 0s - loss: 2.3861e-04
# Epoch 42: val_loss did not improve from 0.00026
# 47/47 [==============================] - 2s 46ms/step - loss: 2.3861e-04 - val_loss: 2.6036e-04
# Epoch 43/50
# 47/47 [==============================] - ETA: 0s - loss: 2.3333e-04
# Epoch 43: val_loss improved from 0.00026 to 0.00025, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 2.3333e-04 - val_loss: 2.4990e-04
# Epoch 44/50
# 47/47 [==============================] - ETA: 0s - loss: 2.2839e-04
# Epoch 44: val_loss improved from 0.00025 to 0.00024, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 2.2839e-04 - val_loss: 2.4189e-04
# Epoch 45/50
# 47/47 [==============================] - ETA: 0s - loss: 2.2349e-04
# Epoch 45: val_loss did not improve from 0.00024
# 47/47 [==============================] - 2s 46ms/step - loss: 2.2349e-04 - val_loss: 2.4302e-04
# Epoch 46/50
# 47/47 [==============================] - ETA: 0s - loss: 2.2120e-04
# Epoch 46: val_loss improved from 0.00024 to 0.00024, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 2.2120e-04 - val_loss: 2.4110e-04
# Epoch 47/50
# 47/47 [==============================] - ETA: 0s - loss: 2.1791e-04
# Epoch 47: val_loss improved from 0.00024 to 0.00023, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 2.1791e-04 - val_loss: 2.2857e-04
# Epoch 48/50
# 47/47 [==============================] - ETA: 0s - loss: 2.1358e-04
# Epoch 48: val_loss improved from 0.00023 to 0.00022, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 2.1358e-04 - val_loss: 2.2352e-04
# Epoch 49/50
# 47/47 [==============================] - ETA: 0s - loss: 2.0879e-04
# Epoch 49: val_loss improved from 0.00022 to 0.00022, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 47/47 [==============================] - 2s 50ms/step - loss: 2.0879e-04 - val_loss: 2.1997e-04
# Epoch 50/50
# 46/47 [============================>.] - ETA: 0s - loss: 2.0668e-04
# Epoch 50: val_loss did not improve from 0.00022
# 47/47 [==============================] - 2s 47ms/step - loss: 2.0654e-04 - val_loss: 2.2232e-04
# Epoch 1/50
# 92/93 [============================>.] - ETA: 0s - loss: 2.1036e-04
# Epoch 1: val_loss did not improve from 0.00022
# 93/93 [==============================] - 4s 47ms/step - loss: 2.1028e-04 - val_loss: 2.3445e-04
# Epoch 2/50
# 93/93 [==============================] - ETA: 0s - loss: 2.0409e-04
# Epoch 2: val_loss did not improve from 0.00022
# 93/93 [==============================] - 4s 46ms/step - loss: 2.0409e-04 - val_loss: 2.2000e-04
# Epoch 3/50
# 93/93 [==============================] - ETA: 0s - loss: 2.0438e-04
# Epoch 3: val_loss improved from 0.00022 to 0.00021, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 2.0438e-04 - val_loss: 2.0638e-04
# Epoch 4/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.9981e-04
# Epoch 4: val_loss did not improve from 0.00021
# 93/93 [==============================] - 4s 44ms/step - loss: 1.9956e-04 - val_loss: 2.1466e-04
# Epoch 5/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.8920e-04
# Epoch 5: val_loss improved from 0.00021 to 0.00021, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 1.8918e-04 - val_loss: 2.0637e-04
# Epoch 6/50
# 93/93 [==============================] - ETA: 0s - loss: 1.8265e-04
# Epoch 6: val_loss improved from 0.00021 to 0.00019, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 1.8265e-04 - val_loss: 1.8763e-04
# Epoch 7/50
# 93/93 [==============================] - ETA: 0s - loss: 1.7561e-04
# Epoch 7: val_loss improved from 0.00019 to 0.00018, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 1.7561e-04 - val_loss: 1.8482e-04
# Epoch 8/50
# 93/93 [==============================] - ETA: 0s - loss: 1.7355e-04
# Epoch 8: val_loss improved from 0.00018 to 0.00018, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 48ms/step - loss: 1.7355e-04 - val_loss: 1.8318e-04
# Epoch 9/50
# 93/93 [==============================] - ETA: 0s - loss: 1.7423e-04
# Epoch 9: val_loss improved from 0.00018 to 0.00018, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 1.7423e-04 - val_loss: 1.8025e-04
# Epoch 10/50
# 93/93 [==============================] - ETA: 0s - loss: 1.6944e-04
# Epoch 10: val_loss improved from 0.00018 to 0.00017, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 1.6944e-04 - val_loss: 1.7166e-04
# Epoch 11/50
# 93/93 [==============================] - ETA: 0s - loss: 1.6335e-04
# Epoch 11: val_loss did not improve from 0.00017
# 93/93 [==============================] - 4s 45ms/step - loss: 1.6335e-04 - val_loss: 1.8496e-04
# Epoch 12/50
# 93/93 [==============================] - ETA: 0s - loss: 1.6279e-04
# Epoch 12: val_loss improved from 0.00017 to 0.00016, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 1.6279e-04 - val_loss: 1.6313e-04
# Epoch 13/50
# 93/93 [==============================] - ETA: 0s - loss: 1.5612e-04
# Epoch 13: val_loss did not improve from 0.00016
# 93/93 [==============================] - 4s 46ms/step - loss: 1.5612e-04 - val_loss: 1.7574e-04
# Epoch 14/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.5554e-04
# Epoch 14: val_loss improved from 0.00016 to 0.00016, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 1.5595e-04 - val_loss: 1.6179e-04
# Epoch 15/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.5437e-04
# Epoch 15: val_loss improved from 0.00016 to 0.00016, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 1.5466e-04 - val_loss: 1.5971e-04
# Epoch 16/50
# 93/93 [==============================] - ETA: 0s - loss: 1.4790e-04
# Epoch 16: val_loss improved from 0.00016 to 0.00015, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 1.4790e-04 - val_loss: 1.5320e-04
# Epoch 17/50
# 93/93 [==============================] - ETA: 0s - loss: 1.4510e-04
# Epoch 17: val_loss did not improve from 0.00015
# 93/93 [==============================] - 4s 44ms/step - loss: 1.4510e-04 - val_loss: 1.5859e-04
# Epoch 18/50
# 93/93 [==============================] - ETA: 0s - loss: 1.4497e-04
# Epoch 18: val_loss did not improve from 0.00015
# 93/93 [==============================] - 4s 45ms/step - loss: 1.4497e-04 - val_loss: 1.7126e-04
# Epoch 19/50
# 93/93 [==============================] - ETA: 0s - loss: 1.4451e-04
# Epoch 19: val_loss did not improve from 0.00015
# 93/93 [==============================] - 4s 46ms/step - loss: 1.4451e-04 - val_loss: 1.6335e-04
# Epoch 20/50
# 93/93 [==============================] - ETA: 0s - loss: 1.4240e-04
# Epoch 20: val_loss did not improve from 0.00015
# 93/93 [==============================] - 4s 46ms/step - loss: 1.4240e-04 - val_loss: 1.5372e-04
# Epoch 21/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.4239e-04
# Epoch 21: val_loss improved from 0.00015 to 0.00015, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 1.4254e-04 - val_loss: 1.4701e-04
# Epoch 22/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.3870e-04
# Epoch 22: val_loss did not improve from 0.00015
# 93/93 [==============================] - 4s 45ms/step - loss: 1.3868e-04 - val_loss: 1.4835e-04
# Epoch 23/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.3858e-04
# Epoch 23: val_loss improved from 0.00015 to 0.00014, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 48ms/step - loss: 1.3854e-04 - val_loss: 1.3835e-04
# Epoch 24/50
# 93/93 [==============================] - ETA: 0s - loss: 1.4146e-04
# Epoch 24: val_loss did not improve from 0.00014
# 93/93 [==============================] - 4s 45ms/step - loss: 1.4146e-04 - val_loss: 1.6386e-04
# Epoch 25/50
# 93/93 [==============================] - ETA: 0s - loss: 1.3863e-04
# Epoch 25: val_loss did not improve from 0.00014
# 93/93 [==============================] - 4s 44ms/step - loss: 1.3863e-04 - val_loss: 1.4325e-04
# Epoch 26/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.2666e-04
# Epoch 26: val_loss improved from 0.00014 to 0.00014, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 1.2659e-04 - val_loss: 1.3610e-04
# Epoch 27/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.2995e-04
# Epoch 27: val_loss improved from 0.00014 to 0.00014, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 48ms/step - loss: 1.2996e-04 - val_loss: 1.3528e-04
# Epoch 28/50
# 93/93 [==============================] - ETA: 0s - loss: 1.2232e-04
# Epoch 28: val_loss improved from 0.00014 to 0.00014, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 45ms/step - loss: 1.2232e-04 - val_loss: 1.3527e-04
# Epoch 29/50
# 93/93 [==============================] - ETA: 0s - loss: 1.2768e-04
# Epoch 29: val_loss improved from 0.00014 to 0.00013, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 1.2768e-04 - val_loss: 1.3219e-04
# Epoch 30/50
# 93/93 [==============================] - ETA: 0s - loss: 1.2412e-04
# Epoch 30: val_loss improved from 0.00013 to 0.00013, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 1.2412e-04 - val_loss: 1.3070e-04
# Epoch 31/50
# 93/93 [==============================] - ETA: 0s - loss: 1.2749e-04
# Epoch 31: val_loss did not improve from 0.00013
# 93/93 [==============================] - 4s 45ms/step - loss: 1.2749e-04 - val_loss: 1.4164e-04
# Epoch 32/50
# 93/93 [==============================] - ETA: 0s - loss: 1.2534e-04
# Epoch 32: val_loss improved from 0.00013 to 0.00013, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 1.2534e-04 - val_loss: 1.2849e-04
# Epoch 33/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.1699e-04
# Epoch 33: val_loss improved from 0.00013 to 0.00013, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 1.1683e-04 - val_loss: 1.2515e-04
# Epoch 34/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.1734e-04
# Epoch 34: val_loss did not improve from 0.00013
# 93/93 [==============================] - 4s 45ms/step - loss: 1.1759e-04 - val_loss: 1.6287e-04
# Epoch 35/50
# 93/93 [==============================] - ETA: 0s - loss: 1.2391e-04
# Epoch 35: val_loss did not improve from 0.00013
# 93/93 [==============================] - 4s 44ms/step - loss: 1.2391e-04 - val_loss: 1.2883e-04
# Epoch 36/50
# 93/93 [==============================] - ETA: 0s - loss: 1.1368e-04
# Epoch 36: val_loss improved from 0.00013 to 0.00012, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 47ms/step - loss: 1.1368e-04 - val_loss: 1.2404e-04
# Epoch 37/50
# 93/93 [==============================] - ETA: 0s - loss: 1.1280e-04
# Epoch 37: val_loss improved from 0.00012 to 0.00012, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 1.1280e-04 - val_loss: 1.2038e-04
# Epoch 38/50
# 93/93 [==============================] - ETA: 0s - loss: 1.2779e-04
# Epoch 38: val_loss did not improve from 0.00012
# 93/93 [==============================] - 4s 45ms/step - loss: 1.2779e-04 - val_loss: 1.5212e-04
# Epoch 39/50
# 93/93 [==============================] - ETA: 0s - loss: 1.1620e-04
# Epoch 39: val_loss improved from 0.00012 to 0.00011, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 1.1620e-04 - val_loss: 1.1409e-04
# Epoch 40/50
# 93/93 [==============================] - ETA: 0s - loss: 1.1145e-04
# Epoch 40: val_loss did not improve from 0.00011
# 93/93 [==============================] - 4s 44ms/step - loss: 1.1145e-04 - val_loss: 1.3845e-04
# Epoch 41/50
# 92/93 [============================>.] - ETA: 0s - loss: 1.1576e-04
# Epoch 41: val_loss did not improve from 0.00011
# 93/93 [==============================] - 4s 44ms/step - loss: 1.1579e-04 - val_loss: 1.1632e-04
# Epoch 42/50
# 93/93 [==============================] - ETA: 0s - loss: 1.0644e-04
# Epoch 42: val_loss improved from 0.00011 to 0.00011, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 1.0644e-04 - val_loss: 1.0768e-04
# Epoch 43/50
# 93/93 [==============================] - ETA: 0s - loss: 1.0759e-04
# Epoch 43: val_loss did not improve from 0.00011
# 93/93 [==============================] - 4s 44ms/step - loss: 1.0759e-04 - val_loss: 1.1733e-04
# Epoch 44/50
# 93/93 [==============================] - ETA: 0s - loss: 1.0689e-04
# Epoch 44: val_loss did not improve from 0.00011
# 93/93 [==============================] - 4s 44ms/step - loss: 1.0689e-04 - val_loss: 1.1418e-04
# Epoch 45/50
# 93/93 [==============================] - ETA: 0s - loss: 1.0437e-04
# Epoch 45: val_loss did not improve from 0.00011
# 93/93 [==============================] - 4s 44ms/step - loss: 1.0437e-04 - val_loss: 1.1255e-04
# Epoch 46/50
# 93/93 [==============================] - ETA: 0s - loss: 1.0621e-04
# Epoch 46: val_loss did not improve from 0.00011
# 93/93 [==============================] - 4s 45ms/step - loss: 1.0621e-04 - val_loss: 1.1537e-04
# Epoch 47/50
# 93/93 [==============================] - ETA: 0s - loss: 1.0656e-04
# Epoch 47: val_loss did not improve from 0.00011
# 93/93 [==============================] - 4s 44ms/step - loss: 1.0656e-04 - val_loss: 1.1192e-04
# Epoch 48/50
# 93/93 [==============================] - ETA: 0s - loss: 1.1157e-04
# Epoch 48: val_loss did not improve from 0.00011
# 93/93 [==============================] - 4s 45ms/step - loss: 1.1157e-04 - val_loss: 1.1686e-04
# Epoch 49/50
# 93/93 [==============================] - ETA: 0s - loss: 1.1024e-04
# Epoch 49: val_loss did not improve from 0.00011
# 93/93 [==============================] - 4s 45ms/step - loss: 1.1024e-04 - val_loss: 1.1559e-04
# Epoch 50/50
# 93/93 [==============================] - ETA: 0s - loss: 1.0280e-04
# Epoch 50: val_loss improved from 0.00011 to 0.00010, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 93/93 [==============================] - 4s 46ms/step - loss: 1.0280e-04 - val_loss: 1.0216e-04
# Epoch 1/50
# 185/185 [==============================] - ETA: 0s - loss: 2.5624e-04
# Epoch 1: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 44ms/step - loss: 2.5624e-04 - val_loss: 1.3910e-04
# Epoch 2/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0851e-04
# Epoch 2: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 44ms/step - loss: 1.0851e-04 - val_loss: 1.0706e-04
# Epoch 3/50
# 185/185 [==============================] - ETA: 0s - loss: 1.1198e-04
# Epoch 3: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 43ms/step - loss: 1.1198e-04 - val_loss: 1.4076e-04
# Epoch 4/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0752e-04
# Epoch 4: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 44ms/step - loss: 1.0752e-04 - val_loss: 1.1242e-04
# Epoch 5/50
# 185/185 [==============================] - ETA: 0s - loss: 1.1730e-04
# Epoch 5: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 44ms/step - loss: 1.1730e-04 - val_loss: 1.4573e-04
# Epoch 6/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0569e-04
# Epoch 6: val_loss improved from 0.00010 to 0.00010, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 1.0569e-04 - val_loss: 1.0170e-04
# Epoch 7/50
# 184/185 [============================>.] - ETA: 0s - loss: 1.0686e-04
# Epoch 7: val_loss did not improve from 0.00010
# 185/185 [==============================] - 9s 46ms/step - loss: 1.0681e-04 - val_loss: 1.0944e-04
# Epoch 8/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0784e-04
# Epoch 8: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 43ms/step - loss: 1.0784e-04 - val_loss: 1.0210e-04
# Epoch 9/50
# 185/185 [==============================] - ETA: 0s - loss: 1.5286e-04
# Epoch 9: val_loss improved from 0.00010 to 0.00010, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 1.5286e-04 - val_loss: 9.8945e-05
# Epoch 10/50
# 185/185 [==============================] - ETA: 0s - loss: 9.7749e-05
# Epoch 10: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 44ms/step - loss: 9.7749e-05 - val_loss: 1.0053e-04
# Epoch 11/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0154e-04
# Epoch 11: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 44ms/step - loss: 1.0154e-04 - val_loss: 1.0878e-04
# Epoch 12/50
# 184/185 [============================>.] - ETA: 0s - loss: 9.9342e-05
# Epoch 12: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 46ms/step - loss: 9.9273e-05 - val_loss: 1.0076e-04
# Epoch 13/50
# 184/185 [============================>.] - ETA: 0s - loss: 1.1053e-04
# Epoch 13: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 45ms/step - loss: 1.1054e-04 - val_loss: 1.3184e-04
# Epoch 14/50
# 184/185 [============================>.] - ETA: 0s - loss: 9.8688e-05
# Epoch 14: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 46ms/step - loss: 9.8646e-05 - val_loss: 1.0164e-04
# Epoch 15/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0829e-04
# Epoch 15: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 45ms/step - loss: 1.0829e-04 - val_loss: 9.9182e-05
# Epoch 16/50
# 184/185 [============================>.] - ETA: 0s - loss: 9.3921e-05
# Epoch 16: val_loss improved from 0.00010 to 0.00010, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 185/185 [==============================] - 9s 46ms/step - loss: 9.3913e-05 - val_loss: 9.7995e-05
# Epoch 17/50
# 185/185 [==============================] - ETA: 0s - loss: 1.1031e-04
# Epoch 17: val_loss improved from 0.00010 to 0.00010, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 1.1031e-04 - val_loss: 9.7588e-05
# Epoch 18/50
# 185/185 [==============================] - ETA: 0s - loss: 1.1107e-04
# Epoch 18: val_loss did not improve from 0.00010
# 185/185 [==============================] - 9s 47ms/step - loss: 1.1107e-04 - val_loss: 1.0283e-04
# Epoch 19/50
# 185/185 [==============================] - ETA: 0s - loss: 9.5003e-05
# Epoch 19: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 46ms/step - loss: 9.5003e-05 - val_loss: 1.0474e-04
# Epoch 20/50
# 185/185 [==============================] - ETA: 0s - loss: 1.1529e-04
# Epoch 20: val_loss did not improve from 0.00010
# 185/185 [==============================] - 8s 45ms/step - loss: 1.1529e-04 - val_loss: 1.2965e-04
# Epoch 21/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0148e-04
# Epoch 21: val_loss improved from 0.00010 to 0.00010, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 185/185 [==============================] - 8s 46ms/step - loss: 1.0148e-04 - val_loss: 9.6434e-05
# Epoch 22/50
# 185/185 [==============================] - ETA: 0s - loss: 9.2293e-05
# Epoch 22: val_loss improved from 0.00010 to 0.00009, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 9.2293e-05 - val_loss: 9.0575e-05
# Epoch 23/50
# 184/185 [============================>.] - ETA: 0s - loss: 9.3642e-05
# Epoch 23: val_loss did not improve from 0.00009
# 185/185 [==============================] - 8s 44ms/step - loss: 9.3578e-05 - val_loss: 1.4231e-04
# Epoch 24/50
# 184/185 [============================>.] - ETA: 0s - loss: 9.6629e-05
# Epoch 24: val_loss did not improve from 0.00009
# 185/185 [==============================] - 8s 44ms/step - loss: 9.6618e-05 - val_loss: 9.4559e-05
# Epoch 25/50
# 184/185 [============================>.] - ETA: 0s - loss: 9.3172e-05
# Epoch 25: val_loss did not improve from 0.00009
# 185/185 [==============================] - 9s 46ms/step - loss: 9.3374e-05 - val_loss: 1.3140e-04
# Epoch 26/50
# 184/185 [============================>.] - ETA: 0s - loss: 1.3935e-04
# Epoch 26: val_loss did not improve from 0.00009
# 185/185 [==============================] - 9s 46ms/step - loss: 1.3932e-04 - val_loss: 9.6571e-05
# Epoch 27/50
# 184/185 [============================>.] - ETA: 0s - loss: 8.3526e-05
# Epoch 27: val_loss did not improve from 0.00009
# 185/185 [==============================] - 9s 46ms/step - loss: 8.3628e-05 - val_loss: 1.0286e-04
# Epoch 28/50
# 185/185 [==============================] - ETA: 0s - loss: 8.7548e-05
# Epoch 28: val_loss did not improve from 0.00009
# 185/185 [==============================] - 9s 46ms/step - loss: 8.7548e-05 - val_loss: 9.9228e-05
# Epoch 29/50
# 185/185 [==============================] - ETA: 0s - loss: 9.2166e-05
# Epoch 29: val_loss did not improve from 0.00009
# 185/185 [==============================] - 8s 46ms/step - loss: 9.2166e-05 - val_loss: 9.1488e-05
# Epoch 30/50
# 185/185 [==============================] - ETA: 0s - loss: 8.9630e-05
# Epoch 30: val_loss improved from 0.00009 to 0.00008, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 8.9630e-05 - val_loss: 8.3208e-05
# Epoch 31/50
# 184/185 [============================>.] - ETA: 0s - loss: 8.7710e-05
# Epoch 31: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 45ms/step - loss: 8.7827e-05 - val_loss: 9.8193e-05
# Epoch 32/50
# 185/185 [==============================] - ETA: 0s - loss: 9.9914e-05
# ...
# Epoch 33: val_loss improved from 0.00008 to 0.00008, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 185/185 [==============================] - 8s 44ms/step - loss: 8.3845e-05 - val_loss: 7.8024e-05
# Epoch 34/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0140e-04
# Epoch 34: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 45ms/step - loss: 1.0140e-04 - val_loss: 1.0915e-04
# Epoch 35/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0405e-04
# Epoch 35: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 44ms/step - loss: 1.0405e-04 - val_loss: 9.0576e-05
# Epoch 36/50
# 185/185 [==============================] - ETA: 0s - loss: 8.5243e-05
# Epoch 36: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 43ms/step - loss: 8.5243e-05 - val_loss: 8.4943e-05
# Epoch 37/50
# 185/185 [==============================] - ETA: 0s - loss: 7.7139e-05
# Epoch 37: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 45ms/step - loss: 7.7139e-05 - val_loss: 7.9480e-05
# Epoch 38/50
# 184/185 [============================>.] - ETA: 0s - loss: 7.5847e-05
# Epoch 38: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 44ms/step - loss: 7.6025e-05 - val_loss: 9.1550e-05
# Epoch 39/50
# 185/185 [==============================] - ETA: 0s - loss: 1.3881e-04
# Epoch 39: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 45ms/step - loss: 1.3881e-04 - val_loss: 2.0428e-04
# Epoch 40/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0623e-04
# Epoch 40: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 45ms/step - loss: 1.0623e-04 - val_loss: 8.3851e-05
# Epoch 41/50
# 185/185 [==============================] - ETA: 0s - loss: 7.3786e-05
# Epoch 41: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 45ms/step - loss: 7.3786e-05 - val_loss: 7.9992e-05
# Epoch 42/50
# 185/185 [==============================] - ETA: 0s - loss: 7.5991e-05
# Epoch 42: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 46ms/step - loss: 7.5991e-05 - val_loss: 8.2981e-05
# Epoch 43/50
# 185/185 [==============================] - ETA: 0s - loss: 8.2353e-05
# Epoch 43: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 45ms/step - loss: 8.2353e-05 - val_loss: 9.1301e-05
# Epoch 44/50
# 185/185 [==============================] - ETA: 0s - loss: 8.3682e-05
# Epoch 44: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 44ms/step - loss: 8.3682e-05 - val_loss: 8.0048e-05
# Epoch 45/50
# 185/185 [==============================] - ETA: 0s - loss: 1.0432e-04
# Epoch 45: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 43ms/step - loss: 1.0432e-04 - val_loss: 1.0010e-04
# Epoch 46/50
# 185/185 [==============================] - ETA: 0s - loss: 7.5670e-05
# Epoch 46: val_loss did not improve from 0.00008
# 185/185 [==============================] - 8s 44ms/step - loss: 7.5670e-05 - val_loss: 8.3381e-05
# Epoch 47/50
# 185/185 [==============================] - ETA: 0s - loss: 7.5196e-05
# Epoch 47: val_loss improved from 0.00008 to 0.00007, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 185/185 [==============================] - 8s 45ms/step - loss: 7.5196e-05 - val_loss: 6.8934e-05
# Epoch 48/50
# 185/185 [==============================] - ETA: 0s - loss: 9.0389e-05
# Epoch 48: val_loss did not improve from 0.00007
# 185/185 [==============================] - 8s 44ms/step - loss: 9.0389e-05 - val_loss: 1.6198e-04
# Epoch 49/50
# 185/185 [==============================] - ETA: 0s - loss: 8.2169e-05
# Epoch 49: val_loss did not improve from 0.00007
# 185/185 [==============================] - 8s 44ms/step - loss: 8.2169e-05 - val_loss: 7.2120e-05
# Epoch 50/50
# 185/185 [==============================] - ETA: 0s - loss: 7.6359e-05
# Epoch 50: val_loss did not improve from 0.00007
# 185/185 [==============================] - 8s 44ms/step - loss: 7.6359e-05 - val_loss: 8.3474e-05
# Epoch 1/50
# 369/370 [============================>.] - ETA: 0s - loss: 5.3335e-04
# Epoch 1: val_loss did not improve from 0.00007
# 370/370 [==============================] - 16s 44ms/step - loss: 5.3216e-04 - val_loss: 1.4138e-04
# Epoch 2/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.0628e-04
# Epoch 2: val_loss did not improve from 0.00007
# 370/370 [==============================] - 17s 45ms/step - loss: 1.0622e-04 - val_loss: 9.1138e-05
# Epoch 3/50
# 370/370 [==============================] - ETA: 0s - loss: 8.1052e-05
# Epoch 3: val_loss did not improve from 0.00007
# 370/370 [==============================] - 17s 46ms/step - loss: 8.1052e-05 - val_loss: 7.8981e-05
# Epoch 4/50
# 370/370 [==============================] - ETA: 0s - loss: 7.7175e-05
# Epoch 4: val_loss did not improve from 0.00007
# 370/370 [==============================] - 17s 46ms/step - loss: 7.7175e-05 - val_loss: 9.0008e-05
# Epoch 5/50
# 369/370 [============================>.] - ETA: 0s - loss: 8.4899e-05
# Epoch 5: val_loss did not improve from 0.00007
# 370/370 [==============================] - 17s 45ms/step - loss: 8.4917e-05 - val_loss: 9.4858e-05
# Epoch 6/50
# 370/370 [==============================] - ETA: 0s - loss: 9.2833e-05
# Epoch 6: val_loss did not improve from 0.00007
# 370/370 [==============================] - 17s 45ms/step - loss: 9.2833e-05 - val_loss: 7.9043e-05
# Epoch 7/50
# 370/370 [==============================] - ETA: 0s - loss: 1.0508e-04
# Epoch 7: val_loss did not improve from 0.00007
# 370/370 [==============================] - 17s 45ms/step - loss: 1.0508e-04 - val_loss: 3.2646e-04
# Epoch 8/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.0603e-04
# Epoch 8: val_loss did not improve from 0.00007
# 370/370 [==============================] - 16s 44ms/step - loss: 1.0592e-04 - val_loss: 7.4661e-05
# Epoch 9/50
# 369/370 [============================>.] - ETA: 0s - loss: 7.2544e-05
# Epoch 9: val_loss improved from 0.00007 to 0.00007, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 370/370 [==============================] - 16s 44ms/step - loss: 7.2545e-05 - val_loss: 6.7381e-05
# Epoch 10/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.0560e-04
# Epoch 10: val_loss did not improve from 0.00007
# 370/370 [==============================] - 16s 44ms/step - loss: 1.0550e-04 - val_loss: 7.2633e-05
# Epoch 11/50
# 369/370 [============================>.] - ETA: 0s - loss: 8.1432e-05
# Epoch 11: val_loss did not improve from 0.00007
# 370/370 [==============================] - 16s 44ms/step - loss: 8.1420e-05 - val_loss: 8.4005e-05
# Epoch 12/50
# 369/370 [============================>.] - ETA: 0s - loss: 9.5817e-05
# Epoch 12: val_loss did not improve from 0.00007
# 370/370 [==============================] - 16s 44ms/step - loss: 9.5965e-05 - val_loss: 1.8577e-04
# Epoch 13/50
# 369/370 [============================>.] - ETA: 0s - loss: 8.7802e-05
# Epoch 13: val_loss did not improve from 0.00007
# 370/370 [==============================] - 16s 43ms/step - loss: 8.7757e-05 - val_loss: 8.3042e-05
# Epoch 14/50
# 369/370 [============================>.] - ETA: 0s - loss: 8.0913e-05
# Epoch 14: val_loss did not improve from 0.00007
# 370/370 [==============================] - 17s 45ms/step - loss: 8.0899e-05 - val_loss: 8.1788e-05
# Epoch 15/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.0028e-04
# Epoch 15: val_loss did not improve from 0.00007
# 370/370 [==============================] - 17s 45ms/step - loss: 1.0033e-04 - val_loss: 1.0493e-04
# Epoch 16/50
# 370/370 [==============================] - ETA: 0s - loss: 7.6256e-05
# Epoch 16: val_loss did not improve from 0.00007
# 370/370 [==============================] - 17s 46ms/step - loss: 7.6256e-05 - val_loss: 7.1848e-05
# Epoch 17/50
# 370/370 [==============================] - ETA: 0s - loss: 6.9680e-05
# Epoch 17: val_loss improved from 0.00007 to 0.00006, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 370/370 [==============================] - 16s 44ms/step - loss: 6.9680e-05 - val_loss: 6.1766e-05
# Epoch 18/50
# 370/370 [==============================] - ETA: 0s - loss: 9.2893e-05
# Epoch 18: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 44ms/step - loss: 9.2893e-05 - val_loss: 1.0124e-04
# Epoch 19/50
# 370/370 [==============================] - ETA: 0s - loss: 9.2874e-05
# Epoch 19: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 44ms/step - loss: 9.2874e-05 - val_loss: 9.5052e-05
# Epoch 20/50
# 369/370 [============================>.] - ETA: 0s - loss: 7.3620e-05
# Epoch 20: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 44ms/step - loss: 7.3600e-05 - val_loss: 6.9801e-05
# Epoch 21/50
# 370/370 [==============================] - ETA: 0s - loss: 6.8800e-05
# Epoch 21: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 45ms/step - loss: 6.8800e-05 - val_loss: 7.9861e-05
# Epoch 22/50
# 370/370 [==============================] - ETA: 0s - loss: 8.0228e-05
# Epoch 22: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 46ms/step - loss: 8.0228e-05 - val_loss: 1.0769e-04
# Epoch 23/50
# 369/370 [============================>.] - ETA: 0s - loss: 8.9361e-05
# Epoch 23: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 45ms/step - loss: 8.9290e-05 - val_loss: 6.3634e-05
# Epoch 24/50
# 369/370 [============================>.] - ETA: 0s - loss: 8.4318e-05
# Epoch 24: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 45ms/step - loss: 8.4289e-05 - val_loss: 7.2289e-05
# Epoch 25/50
# 369/370 [============================>.] - ETA: 0s - loss: 7.4729e-05
# Epoch 25: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 44ms/step - loss: 7.4680e-05 - val_loss: 6.4575e-05
# Epoch 26/50
# 370/370 [==============================] - ETA: 0s - loss: 7.5448e-05
# Epoch 26: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 45ms/step - loss: 7.5448e-05 - val_loss: 1.6514e-04
# Epoch 27/50
# 369/370 [============================>.] - ETA: 0s - loss: 8.6999e-05
# Epoch 27: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 43ms/step - loss: 8.6927e-05 - val_loss: 6.3154e-05
# Epoch 28/50
# 370/370 [==============================] - ETA: 0s - loss: 5.8230e-05
# Epoch 28: val_loss improved from 0.00006 to 0.00006, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 370/370 [==============================] - 17s 45ms/step - loss: 5.8230e-05 - val_loss: 6.1264e-05
# Epoch 29/50
# 369/370 [============================>.] - ETA: 0s - loss: 8.8212e-05
# Epoch 29: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 46ms/step - loss: 8.8169e-05 - val_loss: 6.9067e-05
# Epoch 30/50
# 369/370 [============================>.] - ETA: 0s - loss: 6.4597e-05
# Epoch 30: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 44ms/step - loss: 6.4629e-05 - val_loss: 7.5422e-05
# Epoch 31/50
# 370/370 [==============================] - ETA: 0s - loss: 8.8339e-05
# Epoch 31: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 44ms/step - loss: 8.8339e-05 - val_loss: 6.2609e-05
# Epoch 32/50
# 369/370 [============================>.] - ETA: 0s - loss: 5.6462e-05
# Epoch 32: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 46ms/step - loss: 5.6468e-05 - val_loss: 6.3085e-05
# Epoch 33/50
# 370/370 [==============================] - ETA: 0s - loss: 6.4540e-05
# Epoch 33: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 46ms/step - loss: 6.4540e-05 - val_loss: 6.6617e-05
# Epoch 34/50
# 370/370 [==============================] - ETA: 0s - loss: 6.1491e-05
# Epoch 34: val_loss improved from 0.00006 to 0.00006, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 6.1491e-05 - val_loss: 5.6083e-05
# Epoch 35/50
# 369/370 [============================>.] - ETA: 0s - loss: 9.2098e-05
# Epoch 35: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 46ms/step - loss: 9.2001e-05 - val_loss: 6.5053e-05
# Epoch 36/50
# 369/370 [============================>.] - ETA: 0s - loss: 6.1089e-05
# Epoch 36: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 44ms/step - loss: 6.1067e-05 - val_loss: 5.6995e-05
# Epoch 37/50
# 369/370 [============================>.] - ETA: 0s - loss: 7.0737e-05
# Epoch 37: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 46ms/step - loss: 7.0832e-05 - val_loss: 8.0735e-05
# Epoch 38/50
# 369/370 [============================>.] - ETA: 0s - loss: 6.7812e-05
# Epoch 38: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 46ms/step - loss: 6.7795e-05 - val_loss: 6.4109e-05
# Epoch 39/50
# 370/370 [==============================] - ETA: 0s - loss: 7.3178e-05
# Epoch 39: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 46ms/step - loss: 7.3178e-05 - val_loss: 6.5144e-05
# Epoch 40/50
# 370/370 [==============================] - ETA: 0s - loss: 7.4320e-05
# Epoch 40: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 45ms/step - loss: 7.4320e-05 - val_loss: 6.0048e-05
# Epoch 41/50
# 369/370 [============================>.] - ETA: 0s - loss: 6.7386e-05
# Epoch 41: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 45ms/step - loss: 6.7546e-05 - val_loss: 1.5070e-04
# Epoch 42/50
# 369/370 [============================>.] - ETA: 0s - loss: 7.7732e-05
# Epoch 42: val_loss improved from 0.00006 to 0.00006, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 7.7674e-05 - val_loss: 5.5066e-05
# Epoch 43/50
# 369/370 [============================>.] - ETA: 0s - loss: 5.3809e-05
# Epoch 43: val_loss did not improve from 0.00006
# 370/370 [==============================] - 17s 46ms/step - loss: 5.3819e-05 - val_loss: 6.6689e-05
# Epoch 44/50
# 369/370 [============================>.] - ETA: 0s - loss: 6.9918e-05
# Epoch 44: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 44ms/step - loss: 6.9884e-05 - val_loss: 6.0347e-05
# Epoch 45/50
# 369/370 [============================>.] - ETA: 0s - loss: 5.8172e-05
# Epoch 45: val_loss did not improve from 0.00006
# 370/370 [==============================] - 16s 44ms/step - loss: 5.8232e-05 - val_loss: 6.3705e-05
# Epoch 46/50
# 370/370 [==============================] - ETA: 0s - loss: 7.0689e-05
# Epoch 46: val_loss improved from 0.00006 to 0.00005, saving model to outputs/best_1d_tcn_VAE_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 7.0689e-05 - val_loss: 5.4173e-05
# Epoch 47/50
# 369/370 [============================>.] - ETA: 0s - loss: 6.8523e-05
# Epoch 47: val_loss did not improve from 0.00005
# 370/370 [==============================] - 17s 45ms/step - loss: 6.8511e-05 - val_loss: 6.6497e-05
# Epoch 48/50
# 370/370 [==============================] - ETA: 0s - loss: 6.1695e-05
# Epoch 48: val_loss did not improve from 0.00005
# 370/370 [==============================] - 17s 46ms/step - loss: 6.1695e-05 - val_loss: 5.6977e-05
# Epoch 49/50
# 369/370 [============================>.] - ETA: 0s - loss: 6.3584e-05
# Epoch 49: val_loss did not improve from 0.00005
# 370/370 [==============================] - 16s 44ms/step - loss: 6.3574e-05 - val_loss: 5.5405e-05
# Epoch 50/50
# 369/370 [============================>.] - ETA: 0s - loss: 8.0505e-05
# Epoch 50: val_loss did not improve from 0.00005
# 370/370 [==============================] - 16s 43ms/step - loss: 8.0525e-05 - val_loss: 7.4065e-05
# Execution time 1662.9414 seconds

# %%
#Compute predicted values
prediction_test = TCN_AE.predict(scaled_X_test)
print(prediction_test.shape)


# # Create a StandardScaler object


plt.plot(t,prediction_test[50],label = 'prediction')
plt.plot(t,scaled_y_test[50], label = 'ground truth')
plt.legend()
plt.show()
# Out:
# 24/24 [==============================] - 3s 15ms/step
# (740, 512, 1)

# %%
r2_test = r2_score(scaled_y_test.reshape(-1), prediction_test.reshape(-1))
print(r2_test)

r2_test_set = [r2_score(scaled_y_test[i].reshape(-1), prediction_test[i].reshape(-1)) for i in range(len(scaled_y_test))]
print(len(r2_test_set))
# Out:
# 0.9956470539410148
# 740

# %%
above = np.sum(np.array(r2_test_set) > 0.90)/740 * 100
print('$R^{2}$ above 90 :',above)

above1 = np.sum(np.array(r2_test_set) > 0.95)/740 * 100
print('$R^{2}$ above 95 :',above1)
# Out:
# $R^{2}$ above 90 : 97.97297297297297
# $R^{2}$ above 95 : 91.21621621621621

# %%
plt.figure(figsize=(8, 6))  # Adjust the width and height as needed


plt.plot(omega_y_test, r2_test_set, '*', markersize=4, color='g')
# plt.plot(ω_test, r2_test_set, '.', color='red')
# Plot highlighted points in red

for i in [2, 100, 250, 600]:
    plt.plot(omega_y_test[i], r2_test_set[i], 'X',markersize=9, color='purple')


for _ in np.unique(np.round(np.abs(E[:, np.newaxis] - E), 4)):
    plt.axvline(_, c='y', alpha=0.3)
# plt.axhline(r2_test, color='blue', linestyle='--')  # Plot the horizontal line for r2_test
# plt.text(0.14, r2_test, f"Avg. $R^{2}$ = {r2_test:.4}", color='blue',fontsize=12,weight='bold', va='bottom', ha='left')  # Display the value of r2_test on the plot
plt.xlabel(r"$\omega$",fontsize=15)
plt.ylabel(r"$R^2$",fontsize=15)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
# plt.title("$\omega$ vs. $R^2$ score")
#plt.title("Amplitude = 1", fontsize = 14)
# plt.savefig('R2_Omega_v4_1.png')
plt.savefig('outputs/vae_A1.pdf', dpi=1000, bbox_inches='tight')
plt.show()

# %%
from matplotlib import rcParams

rcParams['font.weight'] = 'bold'
rcParams['font.size'] = 17
labels = ['a', 'b', 'c', 'd']

plt.figure(figsize=(20, 20), dpi=300)
arr =  np.array([2, 100, 250, 600])
j=0
for i in arr:
    plt.subplot(2, 2, j+1)
    plt.plot(t,prediction_test[i, :], label = "pred",color = 'green', linewidth=3)
    plt.plot(t, scaled_y_test[ i, :], label = "target", color = 'blue', linewidth=3  )
    plt.plot( t, scaled_X_test[i, :],'--', label = "input", color = 'orange', linewidth=3 )
    #plt.plot( t, F0 * np.sin(ω_train[i] * t),'--', label = "input",linewidth=4 )
    plt.legend(loc='upper right')
    #plt.title("ω = {}".format(omega_y_test[i]),fontsize=22)
    plt.xlabel("Time",fontsize=22)
    plt.xticks(fontsize = 18)
    plt.yticks(fontsize = 18)
#     plt.ylabel("Expectation Value of Magnetization",  fontsize=27)
    plt.annotate(labels[j], xy=(0.05, 0.95), xycoords='axes fraction', fontsize=25,
                 ha='center', va='center',
                 bbox=dict(boxstyle='circle', fc='w', ec='k', lw=1, alpha=0.7))
    j=j+1

plt.savefig('outputs/vae_Achaotic10TEST.pdf', dpi=700, bbox_inches='tight')
plt.show()
