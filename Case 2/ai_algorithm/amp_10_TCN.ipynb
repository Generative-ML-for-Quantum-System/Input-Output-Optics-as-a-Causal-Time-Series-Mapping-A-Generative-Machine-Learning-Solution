# %% [markdown]
# ### Case 2: For Amplitude (A) = 10.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from qutip import *
from tcn import TCN, tcn_full_summary
from tqdm import tqdm
import time

from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score,r2_score
from keras.losses import Huber
import keras.backend as K

from utilis import QuCal, pre_processing, plot_losses
from model import TCN_autoencoder
# Out:
# 2025-02-04 17:31:21.797800: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-04 17:31:21.942442: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
Y = np.load('../dataset/Data_Y.npy', allow_pickle=True)
Y.shape
# Out:
# (3700, 512, 1)

# %%
full_ω, t, E = QuCal()
# Out:
# lowest frequency for the data:  4.260000000000001
# number of frewuencies: 3700

# %%
scaled_X_train, scaled_y_train,scaled_X_test,scaled_y_test, omega_y_test = pre_processing(Y , full_ω,t, F0 = 10 )
# Out:
# 100%|███████████████████████████████████| 3700/3700 [00:00<00:00, 190017.57it/s]
# omega values for input data:  (3700,)
# x data : (3700, 512)
# scaled_X_train:  (2960, 512, 1)
# scaled_y_train:  (2960, 512, 1)
# scaled_X_test:  (740, 512, 1)
# scaled_y_test:  (740, 512, 1)
# scaled_X_train max:  1.0
# scaled_X_train min:  3.661732e-11
# scaled_y_train max:  1.0
# scaled_y_train min :  0.0006483385

# %%
mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0"])

with mirrored_strategy.scope():
    

    TCN_AE = TCN_autoencoder(input_size=512,f1 = 12,f2 = 12,f3 = 10, lf = 10,latent_space_tcn = True,last_2_layer_dense = False)
    #Compile the model
    TCN_AE.compile(optimizer=Adam(learning_rate = 0.001), loss=Huber(delta=1.0))



#Define a callback to save the best model
checkpoint_filepath = 'outputs/best_1d_tcn_model_v10_bkp.h5'
model_checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_best_only=True,
    monitor='val_loss',
    mode='min',
    verbose=1
)

#Display the model architecture
TCN_AE.summary()
# Out:
# 2025-02-04 17:31:33.983566: I tensorflow/core/platform/cpu_feature_guard.cc:194] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-04 17:31:34.442672: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46614 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:1d:00.0, compute capability: 8.6
# 2025-02-04 17:31:34.443315: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 46614 MB memory:  -> device: 1, name: NVIDIA RTX A6000, pci bus id: 0000:1e:00.0, compute capability: 8.6
# 2025-02-04 17:31:34.443806: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 46614 MB memory:  -> device: 2, name: NVIDIA RTX A6000, pci bus id: 0000:1f:00.0, compute capability: 8.6
# 2025-02-04 17:31:34.444352: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 46614 MB memory:  -> device: 3, name: NVIDIA RTX A6000, pci bus id: 0000:20:00.0, compute capability: 8.6
# 2025-02-04 17:31:34.444888: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 46614 MB memory:  -> device: 4, name: NVIDIA RTX A6000, pci bus id: 0000:21:00.0, compute capability: 8.6
# 2025-02-04 17:31:34.445391: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1621] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 46614 MB memory:  -> device: 5, name: NVIDIA RTX A6000, pci bus id: 0000:22:00.0, compute capability: 8.6
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 512, 1)]          0
#
#  tcn (TCN)                   (None, 512, 12)           2292
#
#  max_pooling1d (MaxPooling1D  (None, 256, 12)          0
#  )
#
#  tcn_1 (TCN)                 (None, 256, 12)           2664
#
#  max_pooling1d_1 (MaxPooling  (None, 128, 12)          0
#  1D)
#
#  tcn_2 (TCN)                 (None, 128, 10)           2050
#
#  max_pooling1d_2 (MaxPooling  (None, 64, 10)           0
#  1D)
#
#  tcn_3 (TCN)                 (None, 64, 10)            1860
#
#  tcn_4 (TCN)                 (None, 64, 10)            1860
#
#  up_sampling1d (UpSampling1D  (None, 128, 10)          0
#  )
#
#  tcn_5 (TCN)                 (None, 128, 12)           2724
#
#  up_sampling1d_1 (UpSampling  (None, 256, 12)          0
#  1D)
#
#  tcn_6 (TCN)                 (None, 256, 12)           2664
#
#  up_sampling1d_2 (UpSampling  (None, 512, 12)          0
#  1D)
#
#  dense (Dense)               (None, 512, 1)            13
#
# =================================================================
# Total params: 16,127
# Trainable params: 16,127
# Non-trainable params: 0
# _________________________________________________________________

# %%
# ##### Train the model
tic = time.perf_counter()
for n in ([7,6,5,4,3]):  
    # training in a cycle with increasing batch size  . IF i increase the size to 10 from 7 then the train process just stops after 5th cycle and this is because of the GPU memory issue.

    batch_size = 2**n  
    
    history = TCN_AE.fit(scaled_X_train, scaled_y_train,
        epochs=50,
        batch_size=batch_size,
        validation_data=(scaled_X_test, scaled_y_test),callbacks=[model_checkpoint_callback])
    
    loss_save = history.history['loss']
    val_loss_save = history.history['val_loss']
    if n in ([6,5,4,3]):
        
        loss_sum = np.concatenate((loss_sum, loss_save), axis = 0)
        val_loss_sum = np.concatenate((val_loss_sum, val_loss_save), axis = 0)
    else:
   
        loss_sum = loss_save
        val_loss_sum = val_loss_save  

    plot_losses(loss_sum,val_loss_sum)

toc = time.perf_counter()
print(f"Execution time {toc - tic:0.4f} seconds")
# Out:
# Epoch 1/50
# 2025-02-04 17:31:46.373478: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8801
# 2025-02-04 17:31:47.069074: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:648] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 24/24 [==============================] - ETA: 0s - loss: 269.4861
# Epoch 1: val_loss improved from inf to 0.16253, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 15s 179ms/step - loss: 269.4861 - val_loss: 0.1625
# Epoch 2/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.1367
# Epoch 2: val_loss improved from 0.16253 to 0.10531, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.1365 - val_loss: 0.1053
# Epoch 3/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0800
# Epoch 3: val_loss improved from 0.10531 to 0.05097, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0798 - val_loss: 0.0510
# Epoch 4/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0340
# Epoch 4: val_loss improved from 0.05097 to 0.01986, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0339 - val_loss: 0.0199
# Epoch 5/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0193
# Epoch 5: val_loss improved from 0.01986 to 0.01885, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0193 - val_loss: 0.0189
# Epoch 6/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0191
# Epoch 6: val_loss improved from 0.01885 to 0.01856, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0191 - val_loss: 0.0186
# Epoch 7/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0190
# Epoch 7: val_loss improved from 0.01856 to 0.01852, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0190 - val_loss: 0.0185
# Epoch 8/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0190
# Epoch 8: val_loss improved from 0.01852 to 0.01849, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0190 - val_loss: 0.0185
# Epoch 9/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0189
# Epoch 9: val_loss improved from 0.01849 to 0.01845, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0189 - val_loss: 0.0185
# Epoch 10/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0189
# Epoch 10: val_loss improved from 0.01845 to 0.01842, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0189 - val_loss: 0.0184
# Epoch 11/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0189
# Epoch 11: val_loss improved from 0.01842 to 0.01839, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0189 - val_loss: 0.0184
# Epoch 12/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0188
# Epoch 12: val_loss improved from 0.01839 to 0.01835, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0188 - val_loss: 0.0183
# Epoch 13/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0188
# Epoch 13: val_loss improved from 0.01835 to 0.01831, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0188 - val_loss: 0.0183
# Epoch 14/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0187
# Epoch 14: val_loss improved from 0.01831 to 0.01828, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0188 - val_loss: 0.0183
# Epoch 15/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0187
# Epoch 15: val_loss improved from 0.01828 to 0.01824, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0187 - val_loss: 0.0182
# Epoch 16/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0187
# Epoch 16: val_loss improved from 0.01824 to 0.01820, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0187 - val_loss: 0.0182
# Epoch 17/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0186
# Epoch 17: val_loss improved from 0.01820 to 0.01817, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0186 - val_loss: 0.0182
# Epoch 18/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0186
# Epoch 18: val_loss improved from 0.01817 to 0.01813, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0186 - val_loss: 0.0181
# Epoch 19/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0185
# Epoch 19: val_loss improved from 0.01813 to 0.01809, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0186 - val_loss: 0.0181
# Epoch 20/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0185
# Epoch 20: val_loss improved from 0.01809 to 0.01806, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0185 - val_loss: 0.0181
# Epoch 21/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0185
# Epoch 21: val_loss improved from 0.01806 to 0.01802, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0185 - val_loss: 0.0180
# Epoch 22/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0185
# Epoch 22: val_loss improved from 0.01802 to 0.01798, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0185 - val_loss: 0.0180
# Epoch 23/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0184
# Epoch 23: val_loss improved from 0.01798 to 0.01794, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0184 - val_loss: 0.0179
# Epoch 24/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0184
# Epoch 24: val_loss improved from 0.01794 to 0.01791, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0184 - val_loss: 0.0179
# Epoch 25/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0184
# Epoch 25: val_loss improved from 0.01791 to 0.01787, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0183 - val_loss: 0.0179
# Epoch 26/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0183
# Epoch 26: val_loss improved from 0.01787 to 0.01783, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0183 - val_loss: 0.0178
# Epoch 27/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0183
# Epoch 27: val_loss improved from 0.01783 to 0.01779, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0183 - val_loss: 0.0178
# Epoch 28/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0183
# Epoch 28: val_loss improved from 0.01779 to 0.01775, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0182 - val_loss: 0.0178
# Epoch 29/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0182
# Epoch 29: val_loss improved from 0.01775 to 0.01771, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0182 - val_loss: 0.0177
# Epoch 30/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0182
# Epoch 30: val_loss improved from 0.01771 to 0.01767, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0182 - val_loss: 0.0177
# Epoch 31/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0181
# Epoch 31: val_loss improved from 0.01767 to 0.01764, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0181 - val_loss: 0.0176
# Epoch 32/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0181
# Epoch 32: val_loss improved from 0.01764 to 0.01761, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0181 - val_loss: 0.0176
# Epoch 33/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0180
# Epoch 33: val_loss improved from 0.01761 to 0.01755, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0180 - val_loss: 0.0175
# Epoch 34/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0180
# Epoch 34: val_loss improved from 0.01755 to 0.01750, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0180 - val_loss: 0.0175
# Epoch 35/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0179
# Epoch 35: val_loss improved from 0.01750 to 0.01744, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0179 - val_loss: 0.0174
# Epoch 36/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0179
# Epoch 36: val_loss did not improve from 0.01744
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0179 - val_loss: 0.0175
# Epoch 37/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0179
# Epoch 37: val_loss improved from 0.01744 to 0.01735, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0179 - val_loss: 0.0174
# Epoch 38/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0178
# Epoch 38: val_loss improved from 0.01735 to 0.01727, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0178 - val_loss: 0.0173
# Epoch 39/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0177
# Epoch 39: val_loss improved from 0.01727 to 0.01720, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0177 - val_loss: 0.0172
# Epoch 40/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0176
# Epoch 40: val_loss improved from 0.01720 to 0.01710, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0176 - val_loss: 0.0171
# Epoch 41/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0175
# Epoch 41: val_loss improved from 0.01710 to 0.01700, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0175 - val_loss: 0.0170
# Epoch 42/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0174
# Epoch 42: val_loss improved from 0.01700 to 0.01688, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0174 - val_loss: 0.0169
# Epoch 43/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0173
# Epoch 43: val_loss did not improve from 0.01688
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0173 - val_loss: 0.0169
# Epoch 44/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0172
# Epoch 44: val_loss improved from 0.01688 to 0.01668, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0172 - val_loss: 0.0167
# Epoch 45/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0171
# Epoch 45: val_loss improved from 0.01668 to 0.01664, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0171 - val_loss: 0.0166
# Epoch 46/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0171
# Epoch 46: val_loss did not improve from 0.01664
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0171 - val_loss: 0.0167
# Epoch 47/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0172
# Epoch 47: val_loss improved from 0.01664 to 0.01655, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0172 - val_loss: 0.0166
# Epoch 48/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0170
# Epoch 48: val_loss improved from 0.01655 to 0.01653, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0170 - val_loss: 0.0165
# Epoch 49/50
# 24/24 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 49: val_loss improved from 0.01653 to 0.01648, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0170 - val_loss: 0.0165
# Epoch 50/50
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0169
# Epoch 50: val_loss did not improve from 0.01648
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0169 - val_loss: 0.0165
# Epoch 1/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 1: val_loss improved from 0.01648 to 0.01646, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 3s 57ms/step - loss: 0.0170 - val_loss: 0.0165
# Epoch 2/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0170
# Epoch 2: val_loss improved from 0.01646 to 0.01640, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0170 - val_loss: 0.0164
# Epoch 3/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0170
# Epoch 3: val_loss did not improve from 0.01640
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0170 - val_loss: 0.0165
# Epoch 4/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0169
# Epoch 4: val_loss did not improve from 0.01640
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 5/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0169
# Epoch 5: val_loss improved from 0.01640 to 0.01636, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0169 - val_loss: 0.0164
# Epoch 6/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0169
# Epoch 6: val_loss improved from 0.01636 to 0.01632, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0169 - val_loss: 0.0163
# Epoch 7/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0169
# Epoch 7: val_loss improved from 0.01632 to 0.01630, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0169 - val_loss: 0.0163
# Epoch 8/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 8: val_loss did not improve from 0.01630
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0167 - val_loss: 0.0163
# Epoch 9/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 9: val_loss improved from 0.01630 to 0.01626, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 10/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 10: val_loss improved from 0.01626 to 0.01625, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0168 - val_loss: 0.0162
# Epoch 11/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 11: val_loss did not improve from 0.01625
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0168 - val_loss: 0.0164
# Epoch 12/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0169
# Epoch 12: val_loss did not improve from 0.01625
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0169 - val_loss: 0.0163
# Epoch 13/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 13: val_loss did not improve from 0.01625
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 14/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 14: val_loss did not improve from 0.01625
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0168 - val_loss: 0.0163
# Epoch 15/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 15: val_loss improved from 0.01625 to 0.01619, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0168 - val_loss: 0.0162
# Epoch 16/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 16: val_loss did not improve from 0.01619
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 17/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 17: val_loss did not improve from 0.01619
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0168 - val_loss: 0.0165
# Epoch 18/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 18: val_loss did not improve from 0.01619
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0167 - val_loss: 0.0163
# Epoch 19/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 19: val_loss improved from 0.01619 to 0.01613, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 51ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 20/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 20: val_loss did not improve from 0.01613
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0166 - val_loss: 0.0162
# Epoch 21/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 21: val_loss did not improve from 0.01613
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 22/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 22: val_loss did not improve from 0.01613
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 23/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 23: val_loss did not improve from 0.01613
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0167 - val_loss: 0.0163
# Epoch 24/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 24: val_loss improved from 0.01613 to 0.01612, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 25/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 25: val_loss did not improve from 0.01612
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0167 - val_loss: 0.0166
# Epoch 26/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 26: val_loss did not improve from 0.01612
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0166 - val_loss: 0.0161
# Epoch 27/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 27: val_loss improved from 0.01612 to 0.01609, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0167 - val_loss: 0.0161
# Epoch 28/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 28: val_loss did not improve from 0.01609
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0166 - val_loss: 0.0162
# Epoch 29/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0168
# Epoch 29: val_loss did not improve from 0.01609
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0168 - val_loss: 0.0164
# Epoch 30/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0166
# Epoch 30: val_loss did not improve from 0.01609
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0166 - val_loss: 0.0162
# Epoch 31/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 31: val_loss improved from 0.01609 to 0.01605, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0166 - val_loss: 0.0160
# Epoch 32/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 32: val_loss did not improve from 0.01605
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0166 - val_loss: 0.0162
# Epoch 33/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 33: val_loss did not improve from 0.01605
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0167 - val_loss: 0.0162
# Epoch 34/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 34: val_loss improved from 0.01605 to 0.01604, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0166 - val_loss: 0.0160
# Epoch 35/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 35: val_loss improved from 0.01604 to 0.01602, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0165 - val_loss: 0.0160
# Epoch 36/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 36: val_loss did not improve from 0.01602
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0165 - val_loss: 0.0161
# Epoch 37/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 37: val_loss did not improve from 0.01602
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0166 - val_loss: 0.0160
# Epoch 38/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 38: val_loss did not improve from 0.01602
# 47/47 [==============================] - 2s 50ms/step - loss: 0.0165 - val_loss: 0.0161
# Epoch 39/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 39: val_loss improved from 0.01602 to 0.01599, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 3s 54ms/step - loss: 0.0166 - val_loss: 0.0160
# Epoch 40/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 40: val_loss did not improve from 0.01599
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0165 - val_loss: 0.0161
# Epoch 41/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 41: val_loss did not improve from 0.01599
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0166 - val_loss: 0.0160
# Epoch 42/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 42: val_loss did not improve from 0.01599
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0164 - val_loss: 0.0160
# Epoch 43/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0167
# Epoch 43: val_loss did not improve from 0.01599
# 47/47 [==============================] - 2s 45ms/step - loss: 0.0167 - val_loss: 0.0164
# Epoch 44/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 44: val_loss improved from 0.01599 to 0.01594, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 53ms/step - loss: 0.0165 - val_loss: 0.0159
# Epoch 45/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 45: val_loss did not improve from 0.01594
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0165 - val_loss: 0.0161
# Epoch 46/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 46: val_loss did not improve from 0.01594
# 47/47 [==============================] - 2s 48ms/step - loss: 0.0165 - val_loss: 0.0163
# Epoch 47/50
# 46/47 [============================>.] - ETA: 0s - loss: 0.0167
# Epoch 47: val_loss improved from 0.01594 to 0.01593, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 3s 54ms/step - loss: 0.0167 - val_loss: 0.0159
# Epoch 48/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 48: val_loss did not improve from 0.01593
# 47/47 [==============================] - 2s 49ms/step - loss: 0.0165 - val_loss: 0.0161
# Epoch 49/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 49: val_loss improved from 0.01593 to 0.01590, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 3s 54ms/step - loss: 0.0164 - val_loss: 0.0159
# Epoch 50/50
# 47/47 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 50: val_loss improved from 0.01590 to 0.01589, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 47/47 [==============================] - 2s 52ms/step - loss: 0.0164 - val_loss: 0.0159
# Epoch 1/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 1: val_loss did not improve from 0.01589
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0164 - val_loss: 0.0163
# Epoch 2/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 2: val_loss did not improve from 0.01589
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0164 - val_loss: 0.0163
# Epoch 3/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 3: val_loss did not improve from 0.01589
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0165 - val_loss: 0.0160
# Epoch 4/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0165
# Epoch 4: val_loss improved from 0.01589 to 0.01582, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0165 - val_loss: 0.0158
# Epoch 5/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 5: val_loss did not improve from 0.01582
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0163 - val_loss: 0.0160
# Epoch 6/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 6: val_loss improved from 0.01582 to 0.01580, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 48ms/step - loss: 0.0164 - val_loss: 0.0158
# Epoch 7/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 7: val_loss improved from 0.01580 to 0.01578, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0163 - val_loss: 0.0158
# Epoch 8/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 8: val_loss did not improve from 0.01578
# 93/93 [==============================] - 4s 48ms/step - loss: 0.0164 - val_loss: 0.0164
# Epoch 9/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0166
# Epoch 9: val_loss improved from 0.01578 to 0.01577, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0166 - val_loss: 0.0158
# Epoch 10/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 10: val_loss improved from 0.01577 to 0.01576, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0163 - val_loss: 0.0158
# Epoch 11/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 11: val_loss did not improve from 0.01576
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0163 - val_loss: 0.0162
# Epoch 12/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 12: val_loss improved from 0.01576 to 0.01574, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 48ms/step - loss: 0.0163 - val_loss: 0.0157
# Epoch 13/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 13: val_loss did not improve from 0.01574
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0163 - val_loss: 0.0159
# Epoch 14/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 14: val_loss improved from 0.01574 to 0.01570, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0162 - val_loss: 0.0157
# Epoch 15/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 15: val_loss did not improve from 0.01570
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0162 - val_loss: 0.0158
# Epoch 16/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 16: val_loss did not improve from 0.01570
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0164 - val_loss: 0.0163
# Epoch 17/50
# 92/93 [============================>.] - ETA: 0s - loss: 0.0164
# Epoch 17: val_loss did not improve from 0.01570
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0163 - val_loss: 0.0162
# Epoch 18/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 18: val_loss did not improve from 0.01570
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0163 - val_loss: 0.0157
# Epoch 19/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 19: val_loss improved from 0.01570 to 0.01568, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0163 - val_loss: 0.0157
# Epoch 20/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 20: val_loss did not improve from 0.01568
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0162 - val_loss: 0.0162
# Epoch 21/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 21: val_loss did not improve from 0.01568
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0164 - val_loss: 0.0158
# Epoch 22/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 22: val_loss did not improve from 0.01568
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0163 - val_loss: 0.0157
# Epoch 23/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 23: val_loss did not improve from 0.01568
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0162 - val_loss: 0.0162
# Epoch 24/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 24: val_loss did not improve from 0.01568
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0163 - val_loss: 0.0157
# Epoch 25/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 25: val_loss improved from 0.01568 to 0.01562, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0163 - val_loss: 0.0156
# Epoch 26/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 26: val_loss did not improve from 0.01562
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0162 - val_loss: 0.0163
# Epoch 27/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 27: val_loss improved from 0.01562 to 0.01562, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0162 - val_loss: 0.0156
# Epoch 28/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 28: val_loss did not improve from 0.01562
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0163 - val_loss: 0.0156
# Epoch 29/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 29: val_loss did not improve from 0.01562
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0163 - val_loss: 0.0160
# Epoch 30/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 30: val_loss did not improve from 0.01562
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0164 - val_loss: 0.0159
# Epoch 31/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 31: val_loss did not improve from 0.01562
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0163 - val_loss: 0.0156
# Epoch 32/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0164
# Epoch 32: val_loss improved from 0.01562 to 0.01560, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 4s 48ms/step - loss: 0.0164 - val_loss: 0.0156
# Epoch 33/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 33: val_loss did not improve from 0.01560
# 93/93 [==============================] - 4s 45ms/step - loss: 0.0162 - val_loss: 0.0157
# Epoch 34/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 34: val_loss did not improve from 0.01560
# 93/93 [==============================] - 4s 48ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 35/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 35: val_loss did not improve from 0.01560
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0161 - val_loss: 0.0160
# Epoch 36/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 36: val_loss did not improve from 0.01560
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0161 - val_loss: 0.0159
# Epoch 37/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 37: val_loss did not improve from 0.01560
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0161 - val_loss: 0.0164
# Epoch 38/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 38: val_loss improved from 0.01560 to 0.01558, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 48ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 39/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 39: val_loss improved from 0.01558 to 0.01556, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 50ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 40/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 40: val_loss did not improve from 0.01556
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0161 - val_loss: 0.0161
# Epoch 41/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 41: val_loss did not improve from 0.01556
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0161 - val_loss: 0.0157
# Epoch 42/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 42: val_loss improved from 0.01556 to 0.01553, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0161 - val_loss: 0.0155
# Epoch 43/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 43: val_loss did not improve from 0.01553
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 44/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 44: val_loss did not improve from 0.01553
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0162 - val_loss: 0.0157
# Epoch 45/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 45: val_loss did not improve from 0.01553
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0160 - val_loss: 0.0156
# Epoch 46/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 46: val_loss did not improve from 0.01553
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0162 - val_loss: 0.0158
# Epoch 47/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 47: val_loss did not improve from 0.01553
# 93/93 [==============================] - 4s 47ms/step - loss: 0.0160 - val_loss: 0.0162
# Epoch 48/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0163
# Epoch 48: val_loss did not improve from 0.01553
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0163 - val_loss: 0.0159
# Epoch 49/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 49: val_loss improved from 0.01553 to 0.01553, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 93/93 [==============================] - 5s 49ms/step - loss: 0.0162 - val_loss: 0.0155
# Epoch 50/50
# 93/93 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 50: val_loss did not improve from 0.01553
# 93/93 [==============================] - 4s 46ms/step - loss: 0.0161 - val_loss: 0.0157
# Epoch 1/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 1: val_loss did not improve from 0.01553
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0162 - val_loss: 0.0158
# Epoch 2/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 2: val_loss improved from 0.01553 to 0.01546, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0161 - val_loss: 0.0155
# Epoch 3/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 3: val_loss did not improve from 0.01546
# 185/185 [==============================] - 9s 46ms/step - loss: 0.0161 - val_loss: 0.0156
# Epoch 4/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 4: val_loss improved from 0.01546 to 0.01542, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0160 - val_loss: 0.0154
# Epoch 5/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0162
# Epoch 5: val_loss did not improve from 0.01542
# 185/185 [==============================] - 8s 45ms/step - loss: 0.0162 - val_loss: 0.0158
# Epoch 6/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0160
# Epoch 6: val_loss did not improve from 0.01542
# 185/185 [==============================] - 8s 46ms/step - loss: 0.0160 - val_loss: 0.0155
# Epoch 7/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0161
# Epoch 7: val_loss improved from 0.01542 to 0.01533, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0161 - val_loss: 0.0153
# Epoch 8/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0159
# Epoch 8: val_loss did not improve from 0.01533
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0159 - val_loss: 0.0154
# Epoch 9/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0155
# Epoch 9: val_loss improved from 0.01533 to 0.01449, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0155 - val_loss: 0.0145
# Epoch 10/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0130
# Epoch 10: val_loss improved from 0.01449 to 0.00948, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0130 - val_loss: 0.0095
# Epoch 11/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0076
# Epoch 11: val_loss improved from 0.00948 to 0.00676, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0076 - val_loss: 0.0068
# Epoch 12/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0068
# Epoch 12: val_loss improved from 0.00676 to 0.00625, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 13/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0063
# Epoch 13: val_loss improved from 0.00625 to 0.00559, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 14/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0053
# Epoch 14: val_loss improved from 0.00559 to 0.00508, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 15/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0045
# Epoch 15: val_loss improved from 0.00508 to 0.00434, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0045 - val_loss: 0.0043
# Epoch 16/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0042
# Epoch 16: val_loss improved from 0.00434 to 0.00420, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 17/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0039
# Epoch 17: val_loss improved from 0.00420 to 0.00416, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0039 - val_loss: 0.0042
# Epoch 18/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0038
# Epoch 18: val_loss improved from 0.00416 to 0.00412, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0038 - val_loss: 0.0041
# Epoch 19/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0034
# Epoch 19: val_loss improved from 0.00412 to 0.00312, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 20/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0028
# Epoch 20: val_loss improved from 0.00312 to 0.00265, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 21/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0025
# Epoch 21: val_loss improved from 0.00265 to 0.00253, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 22/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0023
# Epoch 22: val_loss improved from 0.00253 to 0.00215, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 23/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0021
# Epoch 23: val_loss improved from 0.00215 to 0.00210, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 24/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0019
# Epoch 24: val_loss improved from 0.00210 to 0.00186, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 25/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0018
# Epoch 25: val_loss did not improve from 0.00186
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 26/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0016
# Epoch 26: val_loss improved from 0.00186 to 0.00185, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 27/50
# 184/185 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 27: val_loss improved from 0.00185 to 0.00137, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 28/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0013
# Epoch 28: val_loss did not improve from 0.00137
# 185/185 [==============================] - 8s 46ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 29/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 29: val_loss improved from 0.00137 to 0.00116, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 30/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 30: val_loss did not improve from 0.00116
# 185/185 [==============================] - 9s 46ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 31/50
# 185/185 [==============================] - ETA: 0s - loss: 0.0011
# Epoch 31: val_loss improved from 0.00116 to 0.00106, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 32/50
# 185/185 [==============================] - ETA: 0s - loss: 9.8872e-04
# Epoch 32: val_loss did not improve from 0.00106
# 185/185 [==============================] - 8s 46ms/step - loss: 9.8872e-04 - val_loss: 0.0011
# Epoch 33/50
# 185/185 [==============================] - ETA: 0s - loss: 8.9979e-04
# Epoch 33: val_loss improved from 0.00106 to 0.00096, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 8.9979e-04 - val_loss: 9.6424e-04
# Epoch 34/50
# 185/185 [==============================] - ETA: 0s - loss: 8.6462e-04
# Epoch 34: val_loss improved from 0.00096 to 0.00088, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 8.6462e-04 - val_loss: 8.8475e-04
# Epoch 35/50
# 184/185 [============================>.] - ETA: 0s - loss: 8.4404e-04
# Epoch 35: val_loss improved from 0.00088 to 0.00088, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 8.4486e-04 - val_loss: 8.7895e-04
# Epoch 36/50
# 185/185 [==============================] - ETA: 0s - loss: 8.0135e-04
# Epoch 36: val_loss improved from 0.00088 to 0.00083, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 8.0135e-04 - val_loss: 8.3163e-04
# Epoch 37/50
# 185/185 [==============================] - ETA: 0s - loss: 8.2784e-04
# Epoch 37: val_loss improved from 0.00083 to 0.00077, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 8.2784e-04 - val_loss: 7.6700e-04
# Epoch 38/50
# 185/185 [==============================] - ETA: 0s - loss: 6.8851e-04
# Epoch 38: val_loss improved from 0.00077 to 0.00070, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 6.8851e-04 - val_loss: 6.9746e-04
# Epoch 39/50
# 185/185 [==============================] - ETA: 0s - loss: 7.2928e-04
# Epoch 39: val_loss did not improve from 0.00070
# 185/185 [==============================] - 9s 47ms/step - loss: 7.2928e-04 - val_loss: 7.2171e-04
# Epoch 40/50
# 185/185 [==============================] - ETA: 0s - loss: 6.5757e-04
# Epoch 40: val_loss improved from 0.00070 to 0.00064, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 48ms/step - loss: 6.5757e-04 - val_loss: 6.4345e-04
# Epoch 41/50
# 185/185 [==============================] - ETA: 0s - loss: 6.3402e-04
# Epoch 41: val_loss did not improve from 0.00064
# 185/185 [==============================] - 8s 46ms/step - loss: 6.3402e-04 - val_loss: 6.9324e-04
# Epoch 42/50
# 185/185 [==============================] - ETA: 0s - loss: 5.9709e-04
# Epoch 42: val_loss did not improve from 0.00064
# 185/185 [==============================] - 9s 47ms/step - loss: 5.9709e-04 - val_loss: 6.8392e-04
# Epoch 43/50
# 185/185 [==============================] - ETA: 0s - loss: 5.7722e-04
# Epoch 43: val_loss improved from 0.00064 to 0.00062, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 5.7722e-04 - val_loss: 6.1770e-04
# Epoch 44/50
# 185/185 [==============================] - ETA: 0s - loss: 5.4926e-04
# Epoch 44: val_loss improved from 0.00062 to 0.00060, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 5.4926e-04 - val_loss: 5.9627e-04
# Epoch 45/50
# 185/185 [==============================] - ETA: 0s - loss: 5.7089e-04
# Epoch 45: val_loss improved from 0.00060 to 0.00055, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 5.7089e-04 - val_loss: 5.5492e-04
# Epoch 46/50
# 185/185 [==============================] - ETA: 0s - loss: 5.4316e-04
# Epoch 46: val_loss did not improve from 0.00055
# 185/185 [==============================] - 9s 46ms/step - loss: 5.4316e-04 - val_loss: 6.5423e-04
# Epoch 47/50
# 185/185 [==============================] - ETA: 0s - loss: 5.4393e-04
# Epoch 47: val_loss did not improve from 0.00055
# 185/185 [==============================] - 9s 46ms/step - loss: 5.4393e-04 - val_loss: 0.0012
# Epoch 48/50
# 185/185 [==============================] - ETA: 0s - loss: 5.4838e-04
# Epoch 48: val_loss did not improve from 0.00055
# 185/185 [==============================] - 9s 46ms/step - loss: 5.4838e-04 - val_loss: 5.7694e-04
# Epoch 49/50
# 185/185 [==============================] - ETA: 0s - loss: 5.3197e-04
# Epoch 49: val_loss improved from 0.00055 to 0.00047, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 185/185 [==============================] - 9s 47ms/step - loss: 5.3197e-04 - val_loss: 4.6601e-04
# Epoch 50/50
# 185/185 [==============================] - ETA: 0s - loss: 4.6242e-04
# Epoch 50: val_loss did not improve from 0.00047
# 185/185 [==============================] - 8s 46ms/step - loss: 4.6242e-04 - val_loss: 5.3338e-04
# Epoch 1/50
# 370/370 [==============================] - ETA: 0s - loss: 8.0327e-04
# Epoch 1: val_loss did not improve from 0.00047
# 370/370 [==============================] - 17s 46ms/step - loss: 8.0327e-04 - val_loss: 4.7557e-04
# Epoch 2/50
# 370/370 [==============================] - ETA: 0s - loss: 6.6128e-04
# Epoch 2: val_loss did not improve from 0.00047
# 370/370 [==============================] - 17s 46ms/step - loss: 6.6128e-04 - val_loss: 5.0146e-04
# Epoch 3/50
# 369/370 [============================>.] - ETA: 0s - loss: 4.9004e-04
# Epoch 3: val_loss did not improve from 0.00047
# 370/370 [==============================] - 17s 46ms/step - loss: 4.8969e-04 - val_loss: 4.9208e-04
# Epoch 4/50
# 369/370 [============================>.] - ETA: 0s - loss: 4.9376e-04
# Epoch 4: val_loss did not improve from 0.00047
# 370/370 [==============================] - 17s 46ms/step - loss: 4.9353e-04 - val_loss: 4.8156e-04
# Epoch 5/50
# 369/370 [============================>.] - ETA: 0s - loss: 0.0014
# Epoch 5: val_loss did not improve from 0.00047
# 370/370 [==============================] - 17s 46ms/step - loss: 0.0014 - val_loss: 0.0087
# Epoch 6/50
# 370/370 [==============================] - ETA: 0s - loss: 0.0012
# Epoch 6: val_loss did not improve from 0.00047
# 370/370 [==============================] - 17s 47ms/step - loss: 0.0012 - val_loss: 5.2621e-04
# Epoch 7/50
# 369/370 [============================>.] - ETA: 0s - loss: 4.5112e-04
# Epoch 7: val_loss improved from 0.00047 to 0.00042, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 4.5100e-04 - val_loss: 4.1607e-04
# Epoch 8/50
# 369/370 [============================>.] - ETA: 0s - loss: 4.0560e-04
# Epoch 8: val_loss improved from 0.00042 to 0.00041, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 4.0560e-04 - val_loss: 4.1388e-04
# Epoch 9/50
# 370/370 [==============================] - ETA: 0s - loss: 3.7515e-04
# Epoch 9: val_loss improved from 0.00041 to 0.00041, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 3.7515e-04 - val_loss: 4.0610e-04
# Epoch 10/50
# 369/370 [============================>.] - ETA: 0s - loss: 3.9673e-04
# Epoch 10: val_loss improved from 0.00041 to 0.00040, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 3.9650e-04 - val_loss: 4.0010e-04
# Epoch 11/50
# 370/370 [==============================] - ETA: 0s - loss: 3.7917e-04
# Epoch 11: val_loss improved from 0.00040 to 0.00034, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 3.7917e-04 - val_loss: 3.4394e-04
# Epoch 12/50
# 369/370 [============================>.] - ETA: 0s - loss: 4.6300e-04
# Epoch 12: val_loss did not improve from 0.00034
# 370/370 [==============================] - 17s 47ms/step - loss: 4.6297e-04 - val_loss: 4.2696e-04
# Epoch 13/50
# 370/370 [==============================] - ETA: 0s - loss: 3.2596e-04
# Epoch 13: val_loss improved from 0.00034 to 0.00031, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 3.2596e-04 - val_loss: 3.0849e-04
# Epoch 14/50
# 369/370 [============================>.] - ETA: 0s - loss: 3.3289e-04
# Epoch 14: val_loss did not improve from 0.00031
# 370/370 [==============================] - 17s 47ms/step - loss: 3.3265e-04 - val_loss: 3.1851e-04
# Epoch 15/50
# 369/370 [============================>.] - ETA: 0s - loss: 3.4179e-04
# Epoch 15: val_loss improved from 0.00031 to 0.00030, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 18s 47ms/step - loss: 3.4145e-04 - val_loss: 3.0129e-04
# Epoch 16/50
# 369/370 [============================>.] - ETA: 0s - loss: 3.1363e-04
# Epoch 16: val_loss did not improve from 0.00030
# 370/370 [==============================] - 17s 46ms/step - loss: 3.1345e-04 - val_loss: 3.3301e-04
# Epoch 17/50
# 369/370 [============================>.] - ETA: 0s - loss: 4.4264e-04
# Epoch 17: val_loss did not improve from 0.00030
# 370/370 [==============================] - 17s 45ms/step - loss: 4.4254e-04 - val_loss: 5.8213e-04
# Epoch 18/50
# 370/370 [==============================] - ETA: 0s - loss: 3.0124e-04
# Epoch 18: val_loss did not improve from 0.00030
# 370/370 [==============================] - 17s 46ms/step - loss: 3.0124e-04 - val_loss: 3.0855e-04
# Epoch 19/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.7743e-04
# Epoch 19: val_loss improved from 0.00030 to 0.00028, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 2.7735e-04 - val_loss: 2.7751e-04
# Epoch 20/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.6606e-04
# Epoch 20: val_loss improved from 0.00028 to 0.00025, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 2.6586e-04 - val_loss: 2.4655e-04
# Epoch 21/50
# 370/370 [==============================] - ETA: 0s - loss: 3.4866e-04
# Epoch 21: val_loss did not improve from 0.00025
# 370/370 [==============================] - 17s 46ms/step - loss: 3.4866e-04 - val_loss: 5.7690e-04
# Epoch 22/50
# 370/370 [==============================] - ETA: 0s - loss: 2.6866e-04
# Epoch 22: val_loss improved from 0.00025 to 0.00023, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 2.6866e-04 - val_loss: 2.3270e-04
# Epoch 23/50
# 370/370 [==============================] - ETA: 0s - loss: 2.9396e-04
# Epoch 23: val_loss did not improve from 0.00023
# 370/370 [==============================] - 17s 47ms/step - loss: 2.9396e-04 - val_loss: 2.4260e-04
# Epoch 24/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.7098e-04
# Epoch 24: val_loss improved from 0.00023 to 0.00022, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 2.7069e-04 - val_loss: 2.1795e-04
# Epoch 25/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.2466e-04
# Epoch 25: val_loss improved from 0.00022 to 0.00021, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 2.2482e-04 - val_loss: 2.1375e-04
# Epoch 26/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.2354e-04
# Epoch 26: val_loss did not improve from 0.00021
# 370/370 [==============================] - 17s 46ms/step - loss: 2.2356e-04 - val_loss: 2.2448e-04
# Epoch 27/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.1339e-04
# Epoch 27: val_loss did not improve from 0.00021
# 370/370 [==============================] - 17s 46ms/step - loss: 2.1325e-04 - val_loss: 2.6936e-04
# Epoch 28/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.4494e-04
# Epoch 28: val_loss improved from 0.00021 to 0.00021, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 2.4479e-04 - val_loss: 2.1304e-04
# Epoch 29/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.9205e-04
# Epoch 29: val_loss did not improve from 0.00021
# 370/370 [==============================] - 17s 46ms/step - loss: 2.9238e-04 - val_loss: 3.4630e-04
# Epoch 30/50
# 370/370 [==============================] - ETA: 0s - loss: 1.9414e-04
# Epoch 30: val_loss improved from 0.00021 to 0.00021, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 1.9414e-04 - val_loss: 2.0573e-04
# Epoch 31/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.8308e-04
# Epoch 31: val_loss improved from 0.00021 to 0.00017, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 1.8297e-04 - val_loss: 1.6786e-04
# Epoch 32/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.7765e-04
# Epoch 32: val_loss did not improve from 0.00017
# 370/370 [==============================] - 17s 45ms/step - loss: 2.7746e-04 - val_loss: 2.2033e-04
# Epoch 33/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.7806e-04
# Epoch 33: val_loss did not improve from 0.00017
# 370/370 [==============================] - 17s 45ms/step - loss: 1.7801e-04 - val_loss: 1.6869e-04
# Epoch 34/50
# 369/370 [============================>.] - ETA: 0s - loss: 2.0129e-04
# Epoch 34: val_loss did not improve from 0.00017
# 370/370 [==============================] - 17s 46ms/step - loss: 2.0219e-04 - val_loss: 2.5718e-04
# Epoch 35/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.7749e-04
# Epoch 35: val_loss improved from 0.00017 to 0.00017, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 1.7820e-04 - val_loss: 1.6728e-04
# Epoch 36/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.6538e-04
# Epoch 36: val_loss improved from 0.00017 to 0.00015, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 47ms/step - loss: 1.6538e-04 - val_loss: 1.5094e-04
# Epoch 37/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.9084e-04
# Epoch 37: val_loss did not improve from 0.00015
# 370/370 [==============================] - 17s 45ms/step - loss: 1.9074e-04 - val_loss: 1.6114e-04
# Epoch 38/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.6571e-04
# Epoch 38: val_loss did not improve from 0.00015
# 370/370 [==============================] - 17s 46ms/step - loss: 1.6557e-04 - val_loss: 1.5364e-04
# Epoch 39/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.8571e-04
# Epoch 39: val_loss did not improve from 0.00015
# 370/370 [==============================] - 17s 45ms/step - loss: 1.8565e-04 - val_loss: 1.6870e-04
# Epoch 40/50
# 370/370 [==============================] - ETA: 0s - loss: 1.7962e-04
# Epoch 40: val_loss improved from 0.00015 to 0.00015, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 1.7962e-04 - val_loss: 1.4529e-04
# Epoch 41/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.5500e-04
# Epoch 41: val_loss did not improve from 0.00015
# 370/370 [==============================] - 17s 46ms/step - loss: 1.5511e-04 - val_loss: 2.5197e-04
# Epoch 42/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.6083e-04
# Epoch 42: val_loss did not improve from 0.00015
# 370/370 [==============================] - 17s 46ms/step - loss: 1.6079e-04 - val_loss: 1.5503e-04
# Epoch 43/50
# 370/370 [==============================] - ETA: 0s - loss: 1.6536e-04
# Epoch 43: val_loss improved from 0.00015 to 0.00013, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 1.6536e-04 - val_loss: 1.2571e-04
# Epoch 44/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.8180e-04
# Epoch 44: val_loss did not improve from 0.00013
# 370/370 [==============================] - 17s 46ms/step - loss: 1.8157e-04 - val_loss: 1.5387e-04
# Epoch 45/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.2710e-04
# Epoch 45: val_loss did not improve from 0.00013
# 370/370 [==============================] - 17s 45ms/step - loss: 1.2708e-04 - val_loss: 1.5858e-04
# Epoch 46/50
# 370/370 [==============================] - ETA: 0s - loss: 1.4775e-04
# Epoch 46: val_loss did not improve from 0.00013
# 370/370 [==============================] - 17s 46ms/step - loss: 1.4775e-04 - val_loss: 1.8077e-04
# Epoch 47/50
# 370/370 [==============================] - ETA: 0s - loss: 1.7121e-04
# Epoch 47: val_loss did not improve from 0.00013
# 370/370 [==============================] - 17s 46ms/step - loss: 1.7121e-04 - val_loss: 1.3394e-04
# Epoch 48/50
# 370/370 [==============================] - ETA: 0s - loss: 1.3895e-04
# Epoch 48: val_loss did not improve from 0.00013
# 370/370 [==============================] - 17s 46ms/step - loss: 1.3895e-04 - val_loss: 1.5660e-04
# Epoch 49/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.7037e-04
# Epoch 49: val_loss improved from 0.00013 to 0.00011, saving model to outputs/best_1d_tcn_model_v10_bkp.h5
# 370/370 [==============================] - 17s 46ms/step - loss: 1.7027e-04 - val_loss: 1.1032e-04
# Epoch 50/50
# 369/370 [============================>.] - ETA: 0s - loss: 1.2012e-04
# Epoch 50: val_loss did not improve from 0.00011
# 370/370 [==============================] - 17s 46ms/step - loss: 1.2017e-04 - val_loss: 1.1305e-04
# Execution time 1713.3518 seconds

# %%
#Compute predicted values
prediction_test = TCN_AE.predict(scaled_X_test)
print(prediction_test.shape)


# # Create a StandardScaler object


plt.plot(t,prediction_test[50],label = 'prediction')
plt.plot(t,scaled_y_test[50], label = 'ground truth')
plt.legend()
plt.show()
# Out:
# 24/24 [==============================] - 3s 16ms/step
# (740, 512, 1)

# %%
r2_test = r2_score(scaled_y_test.reshape(-1), prediction_test.reshape(-1))
print(r2_test)

r2_test_set = [r2_score(scaled_y_test[i].reshape(-1), prediction_test[i].reshape(-1)) for i in range(len(scaled_y_test))]
print(len(r2_test_set))
# Out:
# 0.9933697658367786
# 740

# %%
above = np.sum(np.array(r2_test_set) > 0.90)/740 * 100
print('$R^{2}$ above 90 :',above)

above1 = np.sum(np.array(r2_test_set) > 0.95)/740 * 100
print('$R^{2}$ above 95 :',above1)
# Out:
# $R^{2}$ above 90 : 90.67567567567568
# $R^{2}$ above 95 : 72.83783783783784

# %%
plt.figure(figsize=(8, 6))  # Adjust the width and height as needed


plt.plot(omega_y_test, r2_test_set, '*', markersize=4, color='g')
# plt.plot(ω_test, r2_test_set, '.', color='red')
# Plot highlighted points in red

for i in [2, 100, 250, 600]:
    plt.plot(omega_y_test[i], r2_test_set[i], 'X',markersize=9, color='purple')


for _ in np.unique(np.round(np.abs(E[:, np.newaxis] - E), 4)):
    plt.axvline(_, c='y', alpha=0.3)
# plt.axhline(r2_test, color='blue', linestyle='--')  # Plot the horizontal line for r2_test
# plt.text(0.14, r2_test, f"Avg. $R^{2}$ = {r2_test:.4}", color='blue',fontsize=12,weight='bold', va='bottom', ha='left')  # Display the value of r2_test on the plot
plt.xlabel(r"$\omega$",fontsize=15)
plt.ylabel(r"$R^2$",fontsize=15)
plt.xticks(fontsize = 10)
plt.yticks(fontsize = 10)
# plt.title("$\omega$ vs. $R^2$ score")
#plt.title("Amplitude = 1", fontsize = 14)
# plt.savefig('R2_Omega_v4_1.png')
plt.savefig('outputs/A1.pdf', dpi=1000, bbox_inches='tight')
plt.show()

# %%
from matplotlib import rcParams

rcParams['font.weight'] = 'bold'
rcParams['font.size'] = 17
labels = ['a', 'b', 'c', 'd']

plt.figure(figsize=(20, 20), dpi=300)
arr =  np.array([2, 100, 250, 600])
j=0
for i in arr:
    plt.subplot(2, 2, j+1)
    plt.plot(t,prediction_test[i, :], label = "pred",color = 'green', linewidth=3)
    plt.plot(t, scaled_y_test[ i, :], label = "target", color = 'blue', linewidth=3  )
    plt.plot( t, scaled_X_test[i, :],'--', label = "input", color = 'orange', linewidth=3 )
    #plt.plot( t, F0 * np.sin(ω_train[i] * t),'--', label = "input",linewidth=4 )
    plt.legend(loc='upper right')
    #plt.title("ω = {}".format(omega_y_test[i]),fontsize=22)
    plt.xlabel("Time",fontsize=22)
    plt.xticks(fontsize = 18)
    plt.yticks(fontsize = 18)
#     plt.ylabel("Expectation Value of Magnetization",  fontsize=27)
    plt.annotate(labels[j], xy=(0.05, 0.95), xycoords='axes fraction', fontsize=25,
                 ha='center', va='center',
                 bbox=dict(boxstyle='circle', fc='w', ec='k', lw=1, alpha=0.7))
    j=j+1

plt.savefig('outputs/Achaotic25TEST.pdf', dpi=700, bbox_inches='tight')
plt.show()
